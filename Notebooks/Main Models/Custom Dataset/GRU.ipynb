# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='GRU_W2V_EL'))
    model.add(GRU(units=100, name='GRU_W2V'))
    model.add(Dense(units=1, activation='sigmoid', name='GRU_W2V_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
    fold = 1
    accuracies = []

    for train_index, val_index in skf.split(X_train_padded, y_train):
        print(f"Fold: {fold}")
        fold += 1

        X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/GRU/Word2vec/model10k_fold_{fold}.h5"
        checkpoint = ModelCheckpoint(
            checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
        )

        history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])
        
        plt.figure(figsize=(10, 5))  # Adjust figure size as desired
        plt.subplot(1, 2, 1)  # Create subplot for loss
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
    
        plt.subplot(1, 2, 2)  # Create subplot for accuracy
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
    
        plt.tight_layout()  # Adjust spacing between subplots
        plt.show()

        _, accuracy = model.evaluate(X_val_fold, y_val_fold)
        accuracies.append(accuracy)

    return accuracies


def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/GRU/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/GRU_w2v.keras")
# Out:
# 2024-03-11 00:22:02.098553: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 00:22:02.322348: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-11 00:22:03.288487: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-11 00:22:03.288591: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-11 00:22:03.288603: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-03-11 00:22:12.473251: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 00:22:17.023679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2050 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:3b:00.0, compute capability: 6.0
# 2024-03-11 00:22:17.024836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 4250 MB memory:  -> device: 1, name: Tesla P100-PCIE-12GB, pci bus id: 0000:af:00.0, compute capability: 6.0
# 2024-03-11 00:22:17.025751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 123 MB memory:  -> device: 2, name: Tesla P100-PCIE-12GB, pci bus id: 0000:d8:00.0, compute capability: 6.0
# DEBUG:tensorflow:Layer GRU_W2V will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/100
# 2024-03-11 00:22:18.856146: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 32/32 [==============================] - 6s 155ms/step - loss: 0.4711 - accuracy: 0.7621 - val_loss: 0.4209 - val_accuracy: 0.8133
# Epoch 2/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.2759 - accuracy: 0.8922 - val_loss: 0.2826 - val_accuracy: 0.9067
# Epoch 3/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.1754 - accuracy: 0.9362 - val_loss: 0.2169 - val_accuracy: 0.9333
# Epoch 4/100
# 32/32 [==============================] - 5s 152ms/step - loss: 0.1520 - accuracy: 0.9496 - val_loss: 0.2023 - val_accuracy: 0.9378
# Epoch 5/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0911 - accuracy: 0.9723 - val_loss: 0.1876 - val_accuracy: 0.9467
# Epoch 6/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0669 - accuracy: 0.9807 - val_loss: 0.1547 - val_accuracy: 0.9556
# Epoch 7/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0529 - accuracy: 0.9862 - val_loss: 0.1745 - val_accuracy: 0.9511
# Epoch 8/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.
- val_accuracy: 1.0000
# Epoch 8/100
# 32/32 [==============================] - 5s 153ms/step - loss: 1.3546e-05 - accuracy: 1.0000 - val_loss: 8.3921e-06 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 [==============================] - 5s 151ms/step - loss: 1.3242e-05 - accuracy: 1.0000 - val_loss: 8.3231e-06 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 [==============================] - 5s 154ms/step - loss: 1.2930e-05 - accuracy: 1.0000 - val_loss: 8.3217e-06 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 [==============================] - 5s 153ms/step - loss: 1.2711e-05 - accuracy: 1.0000 - val_loss: 8.2198e-06 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 [==============================] - 5s 153ms/step - loss: 1.2310e-05 - accuracy: 1.0000 - val_loss: 8.2124e-06 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.2742 - accuracy: 0.9441 - val_loss: 0.0532 - val_accuracy: 0.9821
# Epoch 14/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0494 - accuracy: 0.9827 - val_loss: 0.0182 - val_accuracy: 0.9955
# Epoch 15/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.0165 - val_accuracy: 0.9955
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0165 - accuracy: 0.9955
# Accuracy for Fold 1: 0.9599999785423279
# Accuracy for Fold 2: 0.9777777791023254
# Accuracy for Fold 3: 0.995555579662323
# Accuracy for Fold 4: 1.0
# Accuracy for Fold 5: 1.0
# Accuracy for Fold 6: 1.0
# Accuracy for Fold 7: 1.0
# Accuracy for Fold 8: 1.0
# Accuracy for Fold 9: 1.0
# Accuracy for Fold 10: 0.9955357313156128
# Average Accuracy: 0.9928869068622589
# 31/31 [==============================] - 2s 49ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97       462
#          1.0       0.99      0.96      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[456   6]
#  [ 21 480]]
# 44/44 [==============================] - 2s 51ms/step

# %% [markdown]
# # GRU FASTTEXT

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='GRU_FT_EL'))
    model.add(GRU(units=100, name='GRU_FT'))
    model.add(Dense(units=1, activation='sigmoid', name='GRU_FT_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
    fold = 1
    accuracies = []

    for train_index, val_index in skf.split(X_train_padded, y_train):
        print(f"Fold: {fold}")
        fold += 1

        X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5"
        checkpoint = ModelCheckpoint(
            checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
        )

        history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()

        _, accuracy = model.evaluate(X_val_fold, y_val_fold)
        accuracies.append(accuracy)

    return accuracies


def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/GRU_ft.keras")
# Out:
# DEBUG:tensorflow:Layer GRU_FT will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.4250 - accuracy: 0.8304 - val_loss: 0.2141 - val_accuracy: 0.9289
# Epoch 2/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1777 - accuracy: 0.9471 - val_loss: 0.1764 - val_accuracy: 0.9244
# Epoch 3/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1557 - accuracy: 0.9486 - val_loss: 0.1728 - val_accuracy: 0.9289
# Epoch 4/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1464 - accuracy: 0.9530 - val_loss: 0.1655 - val_accuracy: 0.9333
# Epoch 5/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1431 - accuracy: 0.9525 - val_loss: 0.1625 - val_accuracy: 0.9289
# Epoch 6/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1346 - accuracy: 0.9545 - val_loss: 0.1749 - val_accuracy: 0.9378
# Epoch 7/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1351 - accuracy: 0.9580 - val_loss: 0.1565 - val_accuracy: 0.9289
# Epoch 8/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1342 - accuracy: 0.9570 - val_loss: 0.1534 - val_accuracy: 0.9333
# Epoch 9/100
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1303 - accuracy: 0.9585 - val_loss: 0.1530 - val_accuracy: 0.9378
# Epoch 10/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1340 - accuracy: 0.9550 - val_loss: 0.1588 - val_accuracy: 0.9422
# Epoch 11/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1288 - accuracy: 0.9570 - val_loss: 0.1514 - val_accuracy: 0.9333
# Epoch 12/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1292 - accuracy: 0.9575 - val_loss: 0.1514 - val_accuracy: 0.9333
# Epoch 13/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1294 - accuracy: 0.9585 - val_loss: 0.1511 - val_accuracy: 0.9333
# Epoch 14/100
# 32/32 [==============================] - 1s 40ms/step - loss: 0.1274 - accuracy: 0.9570 - val_loss: 0.1505 - val_accuracy: 0.9378
# Epoch 15/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1271 - accuracy: 0.9599 - val_loss: 0.1519 - val_accuracy: 0.9378
# Epoch 16/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1283 - accuracy: 0.9585 - val_loss: 0.1499 - val_accuracy: 0.9378
# Epoch 17/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1271 - accuracy: 0.9590 - val_loss: 0.1534 - val_accuracy: 0.9333
# Epoch 18/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1258 - accuracy: 0.9585 - val_loss: 0.1503 - val_accuracy: 0.9378
# Epoch 19/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1246 - accuracy: 0.9590 - val_loss: 0.1469 - val_accuracy: 0.9333
# Epoch 20/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1253 - accuracy: 0.9585 - val_loss: 0.1515 - val_accuracy: 0.9422
# Epoch 21/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1256 - accuracy: 0.9590 - val_loss: 0.1490 - val_accuracy: 0.9378
# Epoch 22/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1251 - accuracy: 0.9580 - val_loss: 0.1478 - val_accuracy: 0.9378
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1478 - accuracy: 0.9378
# Fold: 2
# Epoch 1/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1311 - accuracy: 0.9555 - val_loss: 0.1031 - val_accuracy: 0.9644
# Epoch 2/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1283 - accuracy: 0.9555 - val_loss: 0.1091 - val_accuracy: 0.9644
# Epoch 3/100
# 32/32 [==============================] - 1s 38ms/step - loss: 0.1282 - accuracy: 0.9565 - val_loss: 0.1069 - val_accuracy: 0.9644
# Epoch 4/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1271 - accuracy: 0.9565 - val_loss: 0.1000 - val_accuracy: 0.9733
# Epoch 5/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1278 - accuracy: 0.9540 - val_loss: 0.1032 - val_accuracy: 0.9644
# Epoch 6/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1266 - accuracy: 0.9565 - val_loss: 0.1013 - val_accuracy: 0.9689
# Epoch 7/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1268 - accuracy: 0.9560 - val_loss: 0.1005 - val_accuracy: 0.9689
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1005 - accuracy: 0.9689
# Fold: 3
# Epoch 1/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1221 - accuracy: 0.9594 - val_loss: 0.1425 - val_accuracy: 0.9467
# Epoch 2/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1206 - accuracy: 0.9599 - val_loss: 0.1558 - val_accuracy: 0.9422
# Epoch 3/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1207 - accuracy: 0.9594 - val_loss: 0.1934 - val_accuracy: 0.9289
# Epoch 4/100
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1200 - accuracy: 0.9560 - val_loss: 0.1573 - val_accuracy: 0.9289
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1573 - accuracy: 0.9289
# Fold: 4
# Epoch 1/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1211 - accuracy: 0.9570 - val_loss: 0.1343 - val_accuracy: 0.9600
# Epoch 2/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.1220 - accuracy: 0.9570 - val_loss: 0.1296 - val_accuracy: 0.9600
# Epoch 3/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.1216 - accuracy: 0.9580 - val_loss: 0.1270 - val_accuracy: 0.9644
# Epoch 4/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1255 - accuracy: 0.9575 - val_loss: 0.1311 - val_accuracy: 0.9600
# Epoch 5/100
# 32/32 [==============================] - 1s 43ms/step - loss: 0.1203 - accuracy: 0.9580 - val_loss: 0.1289 - val_accuracy: 0.9644
# Epoch 6/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.1168 - accuracy: 0.9585 - val_loss: 0.1423 - val_accuracy: 0.9600
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1423 - accuracy: 0.9600
# Fold: 5
# Epoch 1/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1167 - accuracy: 0.9609 - val_loss: 0.1672 - val_accuracy: 0.9333
# Epoch 2/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1142 - accuracy: 0.9590 - val_loss: 0.1616 - val_accuracy: 0.9422
# Epoch 3/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.1139 - accuracy: 0.9585 - val_loss: 0.1684 - val_accuracy: 0.9378
# Epoch 4/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1151 - accuracy: 0.9590 - val_loss: 0.1641 - val_accuracy: 0.9422
# Epoch 5/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1109 - accuracy: 0.9614 - val_loss: 0.1670 - val_accuracy: 0.9422
# 8/8 [==============================] - 1s 16ms/step - loss: 0.1670 - accuracy: 0.9422
# Fold: 6
# Epoch 1/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1146 - accuracy: 0.9590 - val_loss: 0.1176 - val_accuracy: 0.9644
# Epoch 2/100
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1129 - accuracy: 0.9580 - val_loss: 0.1211 - val_accuracy: 0.9644
# Epoch 3/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1132 - accuracy: 0.9590 - val_loss: 0.1258 - val_accuracy: 0.9600
# Epoch 4/100
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1125 - accuracy: 0.9585 - val_loss: 0.1225 - val_accuracy: 0.9600
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1225 - accuracy: 0.9600
# Fold: 7
# Epoch 1/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1095 - accuracy: 0.9590 - val_loss: 0.1521 - val_accuracy: 0.9511
# Epoch 2/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1150 - accuracy: 0.9594 - val_loss: 0.1367 - val_accuracy: 0.9556
# Epoch 3/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1103 - accuracy: 0.9604 - val_loss: 0.1277 - val_accuracy: 0.9600
# Epoch 4/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1114 - accuracy: 0.9604 - val_loss: 0.1378 - val_accuracy: 0.9600
# Epoch 5/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1123 - accuracy: 0.9609 - val_loss: 0.1339 - val_accuracy: 0.9600
# Epoch 6/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1070 - accuracy: 0.9639 - val_loss: 0.1380 - val_accuracy: 0.9511
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1380 - accuracy: 0.9511
# Fold: 8
# Epoch 1/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1138 - accuracy: 0.9609 - val_loss: 0.0898 - val_accuracy: 0.9643
# Epoch 2/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1112 - accuracy: 0.9624 - val_loss: 0.0963 - val_accuracy: 0.9643
# Epoch 3/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1112 - accuracy: 0.9639 - val_loss: 0.0923 - val_accuracy: 0.9643
# Epoch 4/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1102 - accuracy: 0.9614 - val_loss: 0.0889 - val_accuracy: 0.9688
# Epoch 5/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1071 - accuracy: 0.9624 - val_loss: 0.0922 - val_accuracy: 0.9598
# Epoch 6/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.1058 - accuracy: 0.9634 - val_loss: 0.0889 - val_accuracy: 0.9688
# Epoch 7/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1068 - accuracy: 0.9629 - val_loss: 0.0888 - val_accuracy: 0.9643
# Epoch 8/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1043 - accuracy: 0.9634 - val_loss: 0.0912 - val_accuracy: 0.9643
# Epoch 9/100
# 32/32 [==============================] - 1s 40ms/step - loss: 0.1024 - accuracy: 0.9659 - val_loss: 0.0900 - val_accuracy: 0.9688
# Epoch 10/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.1140 - accuracy: 0.9619 - val_loss: 0.0891 - val_accuracy: 0.9643
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0891 - accuracy: 0.9643
# Fold: 9
# Epoch 1/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1100 - accuracy: 0.9614 - val_loss: 0.0895 - val_accuracy: 0.9688
# Epoch 2/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1047 - accuracy: 0.9669 - val_loss: 0.0863 - val_accuracy: 0.9643
# Epoch 3/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1030 - accuracy: 0.9669 - val_loss: 0.0862 - val_accuracy: 0.9643
# Epoch 4/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0999 - accuracy: 0.9684 - val_loss: 0.0855 - val_accuracy: 0.9643
# Epoch 5/100
# 32/32 [==============================] - 1s 40ms/step - loss: 0.1006 - accuracy: 0.9644 - val_loss: 0.0854 - val_accuracy: 0.9688
# Epoch 6/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.1020 - accuracy: 0.9654 - val_loss: 0.0931 - val_accuracy: 0.9643
# Epoch 7/100
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0993 - accuracy: 0.9679 - val_loss: 0.0856 - val_accuracy: 0.9688
# Epoch 8/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0986 - accuracy: 0.9703 - val_loss: 0.0868 - val_accuracy: 0.9643
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0868 - accuracy: 0.9643
# Fold: 10
# Epoch 1/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0977 - accuracy: 0.9689 - val_loss: 0.0571 - val_accuracy: 0.9777
# Epoch 2/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0990 - accuracy: 0.9679 - val_loss: 0.0571 - val_accuracy: 0.9777
# Epoch 3/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1012 - accuracy: 0.9679 - val_loss: 0.0713 - val_accuracy: 0.9732
# Epoch 4/100
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0976 - accuracy: 0.9698 - val_loss: 0.0586 - val_accuracy: 0.9777
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0586 - accuracy: 0.9777
# Accuracy for Fold 1: 0.9377777576446533
# Accuracy for Fold 2: 0.9688888788223267
# Accuracy for Fold 3: 0.9288889169692993
# Accuracy for Fold 4: 0.9599999785423279
# Accuracy for Fold 5: 0.9422222375869751
# Accuracy for Fold 6: 0.9599999785423279
# Accuracy for Fold 7: 0.9511111378669739
# Accuracy for Fold 8: 0.9642857313156128
# Accuracy for Fold 9: 0.9642857313156128
# Accuracy for Fold 10: 0.9776785969734192
# Average Accuracy: 0.9555138945579529
# 31/31 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96       462
#          1.0       0.99      0.94      0.96       501
#
#     accuracy                           0.96       963
#    macro avg       0.96      0.96      0.96       963
# weighted avg       0.96      0.96      0.96       963
#
# Confusion Matrix:
# [[456   6]
#  [ 32 469]]
# 44/44 [==============================] - 1s 8ms/step

# %% [markdown]
# # GRID SEARCH

# %%
import os
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle
from gensim.models import Word2Vec

import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from scikeras.wrappers import KerasClassifier


######################################################################################
import os

def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list

def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):

    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index

X_train, X_test, y_train, y_test, test_codes = load_data()



# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

########################################################################################

def load_embedding_model(embedding_dim):
    file_path = f'/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_{embedding_dim}_model.pkl'

    with open(file_path, 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(embedding_dim, vocab_size=359414, max_sequence_length= X_train_padded.shape[1]):
    embedding_model = load_embedding_model(embedding_dim)

    # Create the embedding matrix
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]

    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
    model.add(GRU(units=100))
    model.add(Dense(units=1, activation='sigmoid'))
    return model



seed = 7
tf.random.set_seed(seed)


model = KerasClassifier(model=create_model, loss='binary_crossentropy', metrics=['accuracy'], epochs=50, verbose=0)
optimizer = ['SGD', 'RMSprop', 'Adam']

# Define a list of embedding dimensions to search through
embedding_dimensions = [50, 100, 150,200]
# embedding_matrices = [embedding_matrix]
param_grid = {'model__embedding_dim': embedding_dimensions, 'optimizer':optimizer}

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_train_padded,y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" %(mean, stdev, param))
# Out:
# 2023-10-09 15:14:47.930137: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-09 15:14:48.041221: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-09 15:14:48.716317: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shaurya/miniconda3/envs/tf/lib/
# 2023-10-09 15:14:48.716402: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shaurya/miniconda3/envs/tf/lib/
# 2023-10-09 15:14:48.716410: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# DEBUG:tensorflow:Layer gru will use cuDNN kernels when running on GPU.
# 2023-10-09 15:14:54.106229: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-09 15:14:57.830123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3757 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1b:00.0, compute capability: 6.1
# 2023-10-09 15:14:57.830974: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 24 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1d:00.0, compute capability: 6.1
# 2023-10-09 15:14:57.831860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 10405 MB memory:  -> device: 2, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1e:00.0, compute capability: 6.1
# 2023-10-09 15:14:57.832695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 7090 MB memory:  -> device: 3, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3d:00.0, compute capability: 6.1
# 2023-10-09 15:14:57.833530: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 8022 MB memory:  -> device: 4, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3f:00.0, compute capability: 6.1
# 2023-10-09 15:14:57.834407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 10405 MB memory:  -> device: 5, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:41:00.0, compute capability: 6.1
# 2023-10-09 15:14:58.685828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# DEBUG:tensorflow:Layer gru_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_2 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_6 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_7 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_8 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_9 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_10 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_11 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_12 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_13 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_14 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_15 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_16 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_17 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_18 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_19 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_20 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_21 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_22 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_23 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_24 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_25 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_26 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_27 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_28 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_29 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_30 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_31 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_32 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_33 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_34 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_35 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer gru_36 will use cuDNN kernels when running on GPU.
# Best: 0.959527 using {'model__embedding_dim': 200, 'optimizer': 'SGD'}
# 0.958618 (0.008361) with: {'model__embedding_dim': 50, 'optimizer': 'SGD'}
# 0.956344 (0.004855) with: {'model__embedding_dim': 50, 'optimizer': 'RMSprop'}
# 0.959072 (0.002947) with: {'model__embedding_dim': 50, 'optimizer': 'Adam'}
# 0.958163 (0.007824) with: {'model__embedding_dim': 100, 'optimizer': 'SGD'}
# 0.956799 (0.003912) with: {'model__embedding_dim': 100, 'optimizer': 'RMSprop'}
# 0.954525 (0.006135) with: {'model__embedding_dim': 100, 'optimizer': 'Adam'}
# 0.959072 (0.005570) with: {'model__embedding_dim': 150, 'optimizer': 'SGD'}
# 0.957253 (0.005607) with: {'model__embedding_dim': 150, 'optimizer': 'RMSprop'}
# 0.957253 (0.004502) with: {'model__embedding_dim': 150, 'optimizer': 'Adam'}
# 0.959527 (0.007248) with: {'model__embedding_dim': 200, 'optimizer': 'SGD'}
# 0.954525 (0.005264) with: {'model__embedding_dim': 200, 'optimizer': 'RMSprop'}
# 0.955434 (0.003912) with: {'model__embedding_dim': 200, 'optimizer': 'Adam'}
