# %% [markdown]
# # LSTM (Sentence) word2vec

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='LSTM_W2V_EL'))
    model.add(LSTM(units=128, return_sequences=True, name='LSTM_W2V_1'))
    model.add(LSTM(units=128, name='LSTM_W2V_2'))
    model.add(Dense(units=1, activation='sigmoid', name='LSTM_W2V_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
  fold = 1
  accuracies = []

  for train_index, val_index in skf.split(X_train_padded, y_train):
    print(f"Fold: {fold}")
    fold += 1

    X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5"
    checkpoint = ModelCheckpoint(
        checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
    )

    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])

    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    _, accuracy = model.evaluate(X_val_fold, y_val_fold)
    accuracies.append(accuracy)

  return accuracies
def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/LSTM_w2v.keras")
# Out:
# 2024-03-10 22:48:14.640504: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 22:48:14.839027: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-10 22:48:15.645643: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-10 22:48:15.645754: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-10 22:48:15.645766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-03-10 22:48:23.633717: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 22:48:25.677456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2050 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:3b:00.0, compute capability: 6.0
# 2024-03-10 22:48:25.678721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10922 MB memory:  -> device: 1, name: Tesla P100-PCIE-12GB, pci bus id: 0000:af:00.0, compute capability: 6.0
# 2024-03-10 22:48:25.679732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 7185 MB memory:  -> device: 2, name: Tesla P100-PCIE-12GB, pci bus id: 0000:d8:00.0, compute capability: 6.0
# DEBUG:tensorflow:Layer LSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer LSTM_W2V_2 will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/100
# 2024-03-10 22:48:27.584528: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 32/32 [==============================] - 9s 241ms/step - loss: 0.3658 - accuracy: 0.8417 - val_loss: 0.3189 - val_accuracy: 0.8533
# Epoch 2/100
# 32/32 [==============================] - 8s 245ms/step - loss: 0.1998 - accuracy: 0.9169 - val_loss: 0.1927 - val_accuracy: 0.9378
# Epoch 3/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.1534 - accuracy: 0.9520 - val_loss: 0.2076 - val_accuracy: 0.9333
# Epoch 4/100
# 32/32 [==============================] - 8s 239ms/step - loss: 0.1660 - accuracy: 0.9352 - val_loss: 0.1486 - val_accuracy: 0.9422
# Epoch 5/100
# 32/32 [==============================] - 8s 245ms/step - loss: 0.0786 - accuracy: 0.9777 - val_loss: 0.1299 - val_accuracy: 0.9556
# Epoch 6/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0537 - accuracy: 0.9837 - val_loss: 0.1303 - val_accuracy: 0.9644
# Epoch 7/100
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0462 - accuracy: 0.9871 - val_loss: 0.0846 - val_accuracy: 0.9689
100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.0657e-09 - accuracy: 1.0000 - val_loss: 2.1938e-09 - val_accuracy: 1.0000
# Epoch 55/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.0250e-09 - accuracy: 1.0000 - val_loss: 2.1667e-09 - val_accuracy: 1.0000
# Epoch 56/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.9849e-09 - accuracy: 1.0000 - val_loss: 2.1390e-09 - val_accuracy: 1.0000
# Epoch 57/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.9454e-09 - accuracy: 1.0000 - val_loss: 2.1113e-09 - val_accuracy: 1.0000
# Epoch 58/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.9080e-09 - accuracy: 1.0000 - val_loss: 2.0837e-09 - val_accuracy: 1.0000
# Epoch 59/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.8708e-09 - accuracy: 1.0000 - val_loss: 2.0581e-09 - val_accuracy: 1.0000
# Epoch 60/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.8324e-09 - accuracy: 1.0000 - val_loss: 2.0314e-09 - val_accuracy: 1.0000
# Epoch 61/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.7948e-09 - accuracy: 1.0000 - val_loss: 2.0058e-09 - val_accuracy: 1.0000
# Epoch 62/100
# 32/32 [==============================] - 8s 253ms/step - loss: 2.7584e-09 - accuracy: 1.0000 - val_loss: 1.9797e-09 - val_accuracy: 1.0000
# Epoch 63/100
# 32/32 [==============================] - 8s 254ms/step - loss: 2.7223e-09 - accuracy: 1.0000 - val_loss: 1.9545e-09 - val_accuracy: 1.0000
# Epoch 64/100
# 32/32 [==============================] - 8s 253ms/step - loss: 2.6865e-09 - accuracy: 1.0000 - val_loss: 1.9298e-09 - val_accuracy: 1.0000
# Epoch 65/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.6519e-09 - accuracy: 1.0000 - val_loss: 1.9052e-09 - val_accuracy: 1.0000
# Epoch 66/100
# 32/32 [==============================] - 8s 253ms/step - loss: 2.6183e-09 - accuracy: 1.0000 - val_loss: 1.8809e-09 - val_accuracy: 1.0000
# Epoch 67/100
# 32/32 [==============================] - 8s 252ms/step - loss: 2.5839e-09 - accuracy: 1.0000 - val_loss: 1.8568e-09 - val_accuracy: 1.0000
# Epoch 68/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.5507e-09 - accuracy: 1.0000 - val_loss: 1.8336e-09 - val_accuracy: 1.0000
# Epoch 69/100
# 32/32 [==============================] - 8s 252ms/step - loss: 2.5181e-09 - accuracy: 1.0000 - val_loss: 1.8103e-09 - val_accuracy: 1.0000
# Epoch 70/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.4854e-09 - accuracy: 1.0000 - val_loss: 1.7878e-09 - val_accuracy: 1.0000
# Epoch 71/100
# 32/32 [==============================] - 8s 252ms/step - loss: 2.4545e-09 - accuracy: 1.0000 - val_loss: 1.7652e-09 - val_accuracy: 1.0000
# Epoch 72/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.4234e-09 - accuracy: 1.0000 - val_loss: 1.7437e-09 - val_accuracy: 1.0000
# Epoch 73/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.3915e-09 - accuracy: 1.0000 - val_loss: 1.7211e-09 - val_accuracy: 1.0000
# Epoch 74/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.3615e-09 - accuracy: 1.0000 - val_loss: 1.6998e-09 - val_accuracy: 1.0000
# Epoch 75/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.3310e-09 - accuracy: 1.0000 - val_loss: 1.6783e-09 - val_accuracy: 1.0000
# Epoch 76/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.3023e-09 - accuracy: 1.0000 - val_loss: 1.6574e-09 - val_accuracy: 1.0000
# Epoch 77/100
# 32/32 [==============================] - 8s 252ms/step - loss: 2.2727e-09 - accuracy: 1.0000 - val_loss: 1.6373e-09 - val_accuracy: 1.0000
# Epoch 78/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.2446e-09 - accuracy: 1.0000 - val_loss: 1.6166e-09 - val_accuracy: 1.0000
# Epoch 79/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.2154e-09 - accuracy: 1.0000 - val_loss: 1.5964e-09 - val_accuracy: 1.0000
# Epoch 80/100
# 32/32 [==============================] - 8s 253ms/step - loss: 2.1894e-09 - accuracy: 1.0000 - val_loss: 1.5766e-09 - val_accuracy: 1.0000
# Epoch 81/100
# 32/32 [==============================] - 8s 252ms/step - loss: 2.1608e-09 - accuracy: 1.0000 - val_loss: 1.5578e-09 - val_accuracy: 1.0000
# Epoch 82/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.1337e-09 - accuracy: 1.0000 - val_loss: 1.5382e-09 - val_accuracy: 1.0000
# Epoch 83/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.1075e-09 - accuracy: 1.0000 - val_loss: 1.5198e-09 - val_accuracy: 1.0000
# Epoch 84/100
# 32/32 [==============================] - 8s 252ms/step - loss: 2.0804e-09 - accuracy: 1.0000 - val_loss: 1.5009e-09 - val_accuracy: 1.0000
# Epoch 85/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.0556e-09 - accuracy: 1.0000 - val_loss: 1.4831e-09 - val_accuracy: 1.0000
# Epoch 86/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.0298e-09 - accuracy: 1.0000 - val_loss: 1.4650e-09 - val_accuracy: 1.0000
# Epoch 87/100
# 32/32 [==============================] - 8s 254ms/step - loss: 2.0046e-09 - accuracy: 1.0000 - val_loss: 1.4478e-09 - val_accuracy: 1.0000
# Epoch 88/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.9798e-09 - accuracy: 1.0000 - val_loss: 1.4297e-09 - val_accuracy: 1.0000
# Epoch 89/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.9558e-09 - accuracy: 1.0000 - val_loss: 1.4118e-09 - val_accuracy: 1.0000
# Epoch 90/100
# 32/32 [==============================] - 8s 253ms/step - loss: 1.9317e-09 - accuracy: 1.0000 - val_loss: 1.3952e-09 - val_accuracy: 1.0000
# Epoch 91/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.9085e-09 - accuracy: 1.0000 - val_loss: 1.3781e-09 - val_accuracy: 1.0000
# Epoch 92/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.8843e-09 - accuracy: 1.0000 - val_loss: 1.3615e-09 - val_accuracy: 1.0000
# Epoch 93/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.8619e-09 - accuracy: 1.0000 - val_loss: 1.3454e-09 - val_accuracy: 1.0000
# Epoch 94/100
# 32/32 [==============================] - 8s 248ms/step - loss: 1.8394e-09 - accuracy: 1.0000 - val_loss: 1.3293e-09 - val_accuracy: 1.0000
# Epoch 95/100
# 32/32 [==============================] - 8s 253ms/step - loss: 1.8188e-09 - accuracy: 1.0000 - val_loss: 1.3140e-09 - val_accuracy: 1.0000
# Epoch 96/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.7968e-09 - accuracy: 1.0000 - val_loss: 1.2979e-09 - val_accuracy: 1.0000
# Epoch 97/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.7730e-09 - accuracy: 1.0000 - val_loss: 1.2821e-09 - val_accuracy: 1.0000
# Epoch 98/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.7513e-09 - accuracy: 1.0000 - val_loss: 1.2669e-09 - val_accuracy: 1.0000
# Epoch 99/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.7309e-09 - accuracy: 1.0000 - val_loss: 1.2518e-09 - val_accuracy: 1.0000
# Epoch 100/100
# 32/32 [==============================] - 8s 252ms/step - loss: 1.7102e-09 - accuracy: 1.0000 - val_loss: 1.2377e-09 - val_accuracy: 1.0000
# 7/7 [==============================] - 1s 106ms/step - loss: 1.2377e-09 - accuracy: 1.0000
# Accuracy for Fold 1: 0.9644444584846497
# Accuracy for Fold 2: 0.9866666793823242
# Accuracy for Fold 3: 0.995555579662323
# Accuracy for Fold 4: 1.0
# Accuracy for Fold 5: 1.0
# Accuracy for Fold 6: 1.0
# Accuracy for Fold 7: 1.0
# Accuracy for Fold 8: 1.0
# Accuracy for Fold 9: 1.0
# Accuracy for Fold 10: 1.0
# Average Accuracy: 0.9946666717529297
# 31/31 [==============================] - 3s 95ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       462
#          1.0       0.97      0.97      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[449  13]
#  [ 14 487]]
# 44/44 [==============================] - 4s 96ms/step

# %% [markdown]
# # LSTM FastText

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='LSTM_FT_EL'))
    model.add(LSTM(units=128, return_sequences=True, name='LSTM_FT_1'))
    model.add(LSTM(units=128, name='LSTM_FT_2'))
    model.add(Dense(units=1, activation='sigmoid', name='LSTM_FT_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
  fold = 1
  accuracies = []

  for train_index, val_index in skf.split(X_train_padded, y_train):
    print(f"Fold: {fold}")
    fold += 1

    X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    checkpoint_path = f"/home/shaurya/BTP/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5"
    checkpoint = ModelCheckpoint(
        checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
    )

    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])

    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    _, accuracy = model.evaluate(X_val_fold, y_val_fold)
    accuracies.append(accuracy)

  return accuracies

def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/LSTM_ft.keras")
# Out:
# DEBUG:tensorflow:Layer LSTM_FT_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer LSTM_FT_2 will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.3259 - accuracy: 0.8709 - val_loss: 0.2338 - val_accuracy: 0.9200
# Epoch 2/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1781 - accuracy: 0.9446 - val_loss: 0.2448 - val_accuracy: 0.9289
# Epoch 3/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.1701 - accuracy: 0.9461 - val_loss: 0.2136 - val_accuracy: 0.9200
# Epoch 4/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.1680 - accuracy: 0.9466 - val_loss: 0.2416 - val_accuracy: 0.9156
# Epoch 5/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1588 - accuracy: 0.9481 - val_loss: 0.1844 - val_accuracy: 0.9244
# Epoch 6/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.
100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1256 - accuracy: 0.9575 - val_loss: 0.1499 - val_accuracy: 0.9644
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1499 - accuracy: 0.9644
# Fold: 5
# Epoch 1/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1239 - accuracy: 0.9590 - val_loss: 0.1635 - val_accuracy: 0.9422
# Epoch 2/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1261 - accuracy: 0.9575 - val_loss: 0.1656 - val_accuracy: 0.9422
# Epoch 3/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1230 - accuracy: 0.9565 - val_loss: 0.1627 - val_accuracy: 0.9378
# Epoch 4/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.1233 - accuracy: 0.9599 - val_loss: 0.1634 - val_accuracy: 0.9378
# Epoch 5/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1232 - accuracy: 0.9604 - val_loss: 0.1692 - val_accuracy: 0.9422
# Epoch 6/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1212 - accuracy: 0.9575 - val_loss: 0.1638 - val_accuracy: 0.9422
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1638 - accuracy: 0.9422
# Fold: 6
# Epoch 1/100
# 32/32 [==============================] - 2s 55ms/step - loss: 0.1267 - accuracy: 0.9585 - val_loss: 0.1268 - val_accuracy: 0.9600
# Epoch 2/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1220 - accuracy: 0.9585 - val_loss: 0.1283 - val_accuracy: 0.9644
# Epoch 3/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1248 - accuracy: 0.9585 - val_loss: 0.1283 - val_accuracy: 0.9644
# Epoch 4/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1222 - accuracy: 0.9580 - val_loss: 0.1299 - val_accuracy: 0.9556
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1299 - accuracy: 0.9556
# Fold: 7
# Epoch 1/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1192 - accuracy: 0.9604 - val_loss: 0.1420 - val_accuracy: 0.9600
# Epoch 2/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.1187 - accuracy: 0.9590 - val_loss: 0.1512 - val_accuracy: 0.9511
# Epoch 3/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1170 - accuracy: 0.9594 - val_loss: 0.1447 - val_accuracy: 0.9556
# Epoch 4/100
# 32/32 [==============================] - 2s 52ms/step - loss: 0.1165 - accuracy: 0.9604 - val_loss: 0.1592 - val_accuracy: 0.9511
# 8/8 [==============================] - 1s 29ms/step - loss: 0.1592 - accuracy: 0.9511
# Fold: 8
# Epoch 1/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1225 - accuracy: 0.9585 - val_loss: 0.1055 - val_accuracy: 0.9643
# Epoch 2/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1269 - accuracy: 0.9565 - val_loss: 0.1066 - val_accuracy: 0.9688
# Epoch 3/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1258 - accuracy: 0.9560 - val_loss: 0.1048 - val_accuracy: 0.9688
# Epoch 4/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1215 - accuracy: 0.9565 - val_loss: 0.1033 - val_accuracy: 0.9688
# Epoch 5/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1190 - accuracy: 0.9595 - val_loss: 0.1046 - val_accuracy: 0.9643
# Epoch 6/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.1181 - accuracy: 0.9600 - val_loss: 0.1025 - val_accuracy: 0.9688
# Epoch 7/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1167 - accuracy: 0.9595 - val_loss: 0.1003 - val_accuracy: 0.9732
# Epoch 8/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1188 - accuracy: 0.9580 - val_loss: 0.1035 - val_accuracy: 0.9643
# Epoch 9/100
# 32/32 [==============================] - 2s 55ms/step - loss: 0.1170 - accuracy: 0.9600 - val_loss: 0.1088 - val_accuracy: 0.9643
# Epoch 10/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1142 - accuracy: 0.9600 - val_loss: 0.1105 - val_accuracy: 0.9643
# 7/7 [==============================] - 0s 36ms/step - loss: 0.1105 - accuracy: 0.9643
# Fold: 9
# Epoch 1/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1121 - accuracy: 0.9609 - val_loss: 0.1127 - val_accuracy: 0.9598
# Epoch 2/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1179 - accuracy: 0.9605 - val_loss: 0.1180 - val_accuracy: 0.9598
# Epoch 3/100
# 32/32 [==============================] - 2s 52ms/step - loss: 0.1140 - accuracy: 0.9585 - val_loss: 0.1131 - val_accuracy: 0.9598
# Epoch 4/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1092 - accuracy: 0.9629 - val_loss: 0.1218 - val_accuracy: 0.9598
# 7/7 [==============================] - 1s 26ms/step - loss: 0.1218 - accuracy: 0.9598
# Fold: 10
# Epoch 1/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1160 - accuracy: 0.9590 - val_loss: 0.0728 - val_accuracy: 0.9777
# Epoch 2/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1147 - accuracy: 0.9614 - val_loss: 0.0780 - val_accuracy: 0.9777
# Epoch 3/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1172 - accuracy: 0.9595 - val_loss: 0.0725 - val_accuracy: 0.9777
# Epoch 4/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1118 - accuracy: 0.9609 - val_loss: 0.0665 - val_accuracy: 0.9777
# Epoch 5/100
# 32/32 [==============================] - 2s 52ms/step - loss: 0.1087 - accuracy: 0.9629 - val_loss: 0.0717 - val_accuracy: 0.9732
# Epoch 6/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1093 - accuracy: 0.9609 - val_loss: 0.0730 - val_accuracy: 0.9777
# Epoch 7/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1054 - accuracy: 0.9644 - val_loss: 0.0604 - val_accuracy: 0.9777
# Epoch 8/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1073 - accuracy: 0.9624 - val_loss: 0.0759 - val_accuracy: 0.9777
# Epoch 9/100
# 32/32 [==============================] - 2s 52ms/step - loss: 0.1040 - accuracy: 0.9649 - val_loss: 0.0674 - val_accuracy: 0.9777
# Epoch 10/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1405 - accuracy: 0.9466 - val_loss: 0.0792 - val_accuracy: 0.9643
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0792 - accuracy: 0.9643
# Accuracy for Fold 1: 0.9377777576446533
# Accuracy for Fold 2: 0.9688888788223267
# Accuracy for Fold 3: 0.9333333373069763
# Accuracy for Fold 4: 0.9644444584846497
# Accuracy for Fold 5: 0.9422222375869751
# Accuracy for Fold 6: 0.9555555582046509
# Accuracy for Fold 7: 0.9511111378669739
# Accuracy for Fold 8: 0.9642857313156128
# Accuracy for Fold 9: 0.9598214030265808
# Accuracy for Fold 10: 0.9642857313156128
# Average Accuracy: 0.9541726231575012
# 31/31 [==============================] - 1s 17ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96       462
#          1.0       0.99      0.93      0.96       501
#
#     accuracy                           0.96       963
#    macro avg       0.96      0.96      0.96       963
# weighted avg       0.96      0.96      0.96       963
#
# Confusion Matrix:
# [[458   4]
#  [ 36 465]]
# 44/44 [==============================] - 1s 17ms/step

# %%
expected_first_692 = [1] * 692
expected_last_685 = [0] * 685

matches_first_692 = sum(1 for a, e in zip(test_pred[:692], expected_first_692) if a == e)
matches_last_685 = sum(1 for a, e in zip(test_pred[692:], expected_last_685) if a == e)

accuracy_first_692 = (matches_first_692 / len(expected_first_692)) * 100
accuracy_last_685 = (matches_last_685 / len(expected_last_685)) * 100

total_matches = matches_first_692 + matches_last_685
total_accuracy = (total_matches / len(test_pred)) * 100

print(f"Accuracy for the first 692 elements: {accuracy_first_692:.2f}%")
print(f"Accuracy for the last 685 elements: {accuracy_last_685:.2f}%")
print(f"Total Accuracy: {total_accuracy:.2f}%")
# Out:
# Accuracy for the first 692 elements: 92.49%
# Accuracy for the last 685 elements: 96.79%
# Total Accuracy: 94.63%

# %% [markdown]
# # HyperParameter Optimization Word2Vec

# %%
import os
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle
from gensim.models import Word2Vec

import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from scikeras.wrappers import KerasClassifier


######################################################################################
import os

def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list

def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):

    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index

X_train, X_test, y_train, y_test, test_codes = load_data()



# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

########################################################################################

def load_embedding_model(embedding_dim):
    file_path = f'/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_{embedding_dim}_model.pkl'

    with open(file_path, 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(embedding_dim, vocab_size=359414, max_sequence_length= X_train_padded.shape[1]):
    embedding_model = load_embedding_model(embedding_dim)

    # Create the embedding matrix
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]

    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(LSTM(units=128))
    model.add(Dense(units=1, activation='sigmoid'))
    return model



seed = 7
tf.random.set_seed(seed)


model = KerasClassifier(model=create_model, loss='binary_crossentropy', metrics=['accuracy'], epochs=50, verbose=0)
optimizers = ['Adam']

# Define a list of embedding dimensions to search through
embedding_dimensions = [150]
learn_rate = [0.001]
momentum = [0.0, 0.3, 0.6, 0.8]
param_grid = dict(model__embedding_dim=embedding_dimensions, optimizer=optimizers, optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_train_padded,y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" %(mean, stdev, param))
# Out:
# 2024-02-08 04:23:47.508961: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 04:23:47.667982: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-08 04:23:48.398821: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shaurya/miniconda3/envs/tf/lib/
# 2024-02-08 04:23:48.398928: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shaurya/miniconda3/envs/tf/lib/
# 2024-02-08 04:23:48.398936: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # Hyperparameter Optimisation Fasttext

# %%
import os
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle
from gensim.models import Word2Vec

import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from scikeras.wrappers import KerasClassifier


######################################################################################
import os

def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list

def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):

    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index

X_train, X_test, y_train, y_test, test_codes = load_data()



# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

########################################################################################

def load_embedding_model(embedding_dim):
    file_path = f'/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_{embedding_dim}_model.pkl'

    with open(file_path, 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(embedding_dim, vocab_size=359414, max_sequence_length= X_train_padded.shape[1]):
    embedding_model = load_embedding_model(embedding_dim)

    # Create the embedding matrix
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]

    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(LSTM(units=128))
    model.add(Dense(units=1, activation='sigmoid'))
    return model



seed = 7
tf.random.set_seed(seed)


model = KerasClassifier(model=create_model, loss='binary_crossentropy', metrics=['accuracy'], epochs=50, verbose=0)
optimizer = ['SGD', 'RMSprop', 'Adam']

# Define a list of embedding dimensions to search through
embedding_dimensions = [50, 100, 150,200]
# embedding_matrices = [embedding_matrix]
param_grid = {'model__embedding_dim': embedding_dimensions, 'optimizer':optimizer}

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_train_padded,y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" %(mean, stdev, param))
# Out:
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# 2023-10-09 08:31:07.513290: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-09 08:31:11.313934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3757 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1b:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.314811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 24 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1d:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.315721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 10405 MB memory:  -> device: 2, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1e:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.316696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 7090 MB memory:  -> device: 3, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3d:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.317552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 8022 MB memory:  -> device: 4, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3f:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.318429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 10405 MB memory:  -> device: 5, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:41:00.0, compute capability: 6.1
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# 2023-10-09 08:31:12.589718: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# DEBUG:tensorflow:Layer lstm_2 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_6 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_7 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_8 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_9 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_10 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_11 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_12 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_13 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_14 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_15 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_16 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_17 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_18 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_19 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_20 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_21 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_22 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_23 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_24 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_25 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_26 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_27 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_28 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_29 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_30 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_31 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_32 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_33 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_34 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_35 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_36 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_37 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_38 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_39 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_40 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_41 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_42 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_43 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_44 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_45 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_46 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_47 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_48 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_49 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_50 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_51 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_52 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_53 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_54 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_55 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_56 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_57 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_58 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_59 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_60 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_61 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_62 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_63 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_64 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_65 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_66 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_67 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_68 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_69 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_70 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_71 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_72 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_73 will use cuDNN kernels when running on GPU.
# Best: 0.960437 using {'model__embedding_dim': 50, 'optimizer': 'Adam'}
# 0.953161 (0.006135) with: {'model__embedding_dim': 50, 'optimizer': 'SGD'}
# 0.959527 (0.002319) with: {'model__embedding_dim': 50, 'optimizer': 'RMSprop'}
# 0.960437 (0.003859) with: {'model__embedding_dim': 50, 'optimizer': 'Adam'}
# 0.950887 (0.005894) with: {'model__embedding_dim': 100, 'optimizer': 'SGD'}
# 0.959982 (0.006334) with: {'model__embedding_dim': 100, 'optimizer': 'RMSprop'}
# 0.957253 (0.005607) with: {'model__embedding_dim': 100, 'optimizer': 'Adam'}
# 0.952251 (0.004456) with: {'model__embedding_dim': 150, 'optimizer': 'SGD'}
# 0.956344 (0.007797) with: {'model__embedding_dim': 150, 'optimizer': 'RMSprop'}
# 0.959072 (0.008410) with: {'model__embedding_dim': 150, 'optimizer': 'Adam'}
# 0.950887 (0.004855) with: {'model__embedding_dim': 200, 'optimizer': 'SGD'}
# 0.960437 (0.005570) with: {'model__embedding_dim': 200, 'optimizer': 'RMSprop'}
# 0.956799 (0.005495) with: {'model__embedding_dim': 200, 'optimizer': 'Adam'}
