# %%
import os
# os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam


import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='BLSTM_W2V_EL'))
    model.add(Bidirectional(LSTM(units=128, return_sequences=True), name='BLSTM_W2V_1'))
    model.add(Bidirectional(LSTM(units=128), name='BLSTM_W2V_2'))
    model.add(Dense(units=1, activation='sigmoid', name='BLSTM_W2V_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model




def perform_cross_validation(X_train_padded, y_train, model, skf):
    fold = 1
    accuracies = []

    for train_index, val_index in skf.split(X_train_padded, y_train):
        print(f"Fold: {fold}")
        fold += 1

        X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/BILSTM/Word2vec/model10k_fold_{fold}.h5"
        checkpoint = ModelCheckpoint(
            checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
        )

        history = model.fit(X_train_fold, y_train_fold, epochs=10, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])
        
        plt.figure(figsize=(10, 5))  # Adjust figure size as desired
        plt.subplot(1, 2, 1)  # Create subplot for loss
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
    
        plt.subplot(1, 2, 2)  # Create subplot for accuracy
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
    
        plt.tight_layout()  # Adjust spacing between subplots
        plt.show()

        _, accuracy = model.evaluate(X_val_fold, y_val_fold)
        accuracies.append(accuracy)

    return accuracies

    
def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/BILSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/BLSTM_w2v.keras")
# Out:
# 2024-03-11 01:17:41.781543: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 01:17:41.990204: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-11 01:17:42.904594: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-11 01:17:42.904688: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-11 01:17:42.904699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-03-11 01:17:52.407500: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 01:17:56.730230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2050 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:3b:00.0, compute capability: 6.0
# 2024-03-11 01:17:56.731501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 4250 MB memory:  -> device: 1, name: Tesla P100-PCIE-12GB, pci bus id: 0000:af:00.0, compute capability: 6.0
# 2024-03-11 01:17:56.732382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 123 MB memory:  -> device: 2, name: Tesla P100-PCIE-12GB, pci bus id: 0000:d8:00.0, compute capability: 6.0
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/10
# 2024-03-11 01:17:59.429190: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 64/64 [==============================] - 27s 414ms/step - loss: 0.2916 - accuracy: 0.8843 - val_loss: 0.1920 - val_accuracy: 0.9422
# Epoch 2/10
# 64/64 [==============================] - 27s 416ms/step - loss: 0.1383 - accuracy: 0.9560 - val_loss: 0.1364 - val_accuracy: 0.9644
# Epoch 3/10
# 64/64 [==============================] - 26s 406ms/step - loss: 0.1133 - accuracy: 0.9639 - val_loss: 0.1425 - val_accuracy: 0.9422
# Epoch 4/10
# 64/64 [==============================] - 26s 413ms/step - loss: 0.0883 - accuracy: 0.9693 - val_loss: 0.1208 - val_accuracy: 0.9511
# Epoch 5/10
# 64/64 [==============================] - 26s 414ms/step - loss: 0.0479 - accuracy: 0.9871 - val_loss: 0.1035 - val_accuracy: 0.9778
# Epoch 6/10
# 64/64 [==============================] - 26s 411ms/step - loss: 0.0435 - accuracy: 0.9862 - val_loss: 0.0893 - val_accuracy: 0.9822
# Epoch 7/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0331 - accuracy: 0.9911 - val_loss: 0.1128 - val_accuracy: 0.9689
# Epoch 8/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0980 - accuracy: 0.9664 - val_loss: 0.1344 - val_accuracy: 0.9600
# Epoch 9/10
# 64/64 [==============================] - 26s 405ms/step - loss: 0.0556 - accuracy: 0.9832 - val_loss: 0.0981 - val_accuracy: 0.9778
# 8/8 [==============================] - 2s 187ms/step - loss: 0.0981 - accuracy: 0.9778
# Fold: 2
# Epoch 1/10
# 64/64 [==============================] - 27s 415ms/step - loss: 0.0370 - accuracy: 0.9876 - val_loss: 0.0422 - val_accuracy: 0.9867
# Epoch 2/10
# 64/64 [==============================] - 26s 405ms/step - loss: 0.0425 - accuracy: 0.9857 - val_loss: 0.0687 - val_accuracy: 0.9911
# Epoch 3/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0381 - accuracy: 0.9886 - val_loss: 0.0497 - val_accuracy: 0.9867
# Epoch 4/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.0500 - val_accuracy: 0.9911
# 8/8 [==============================] - 2s 185ms/step - loss: 0.0500 - accuracy: 0.9911
# Fold: 3
# Epoch 1/10
# 64/64 [==============================] - 26s 414ms/step - loss: 0.0136 - accuracy: 0.9970 - val_loss: 0.0180 - val_accuracy: 0.9956
# Epoch 2/10
# 64/64 [==============================] - 26s 413ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0102 - val_accuracy: 0.9956
# Epoch 3/10
# 64/64 [==============================] - 26s 405ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0169 - val_accuracy: 0.9956
# Epoch 4/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0279 - val_accuracy: 0.9956
# Epoch 5/10
# 64/64 [==============================] - 26s 404ms/step - loss: 8.6193e-04 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9956
# 8/8 [==============================] - 2s 185ms/step - loss: 0.0281 - accuracy: 0.9956
# Fold: 4
# Epoch 1/10
# 64/64 [==============================] - 27s 416ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 2/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0100 - val_accuracy: 0.9956
# Epoch 3/10
# 64/64 [==============================] - 26s 405ms/step - loss: 0.0328 - accuracy: 0.9911 - val_loss: 0.0096 - val_accuracy: 0.9956
# Epoch 4/10
# 64/64 [==============================] - 26s 406ms/step - loss: 0.0110 - accuracy: 0.9975 - val_loss: 0.0184 - val_accuracy: 0.9956
# 8/8 [==============================] - 2s 192ms/step - loss: 0.0184 - accuracy: 0.9956
# Fold: 5
# Epoch 1/10
# 64/64 [==============================] - 27s 415ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.0072 - val_accuracy: 0.9956
# Epoch 2/10
# 64/64 [==============================] - 26s 404ms/step - loss: 0.0290 - accuracy: 0.9926 - val_loss: 0.0115 - val_accuracy: 0.9956
# Epoch 3/10
# 64/64 [==============================] - 26s 406ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0080 - val_accuracy: 0.9956
# Epoch 4/10
# 64/64 [==============================] - 26s 413ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy:
# Epoch 7/10
# 64/64 [==============================] - 26s 413ms/step - loss: 1.1276e-05 - accuracy: 1.0000 - val_loss: 5.7050e-06 - val_accuracy: 1.0000
# Epoch 8/10
# 64/64 [==============================] - 26s 414ms/step - loss: 1.0787e-05 - accuracy: 1.0000 - val_loss: 5.4852e-06 - val_accuracy: 1.0000
# Epoch 9/10
# 64/64 [==============================] - 27s 414ms/step - loss: 1.0309e-05 - accuracy: 1.0000 - val_loss: 5.2778e-06 - val_accuracy: 1.0000
# Epoch 10/10
# 64/64 [==============================] - 26s 413ms/step - loss: 9.8942e-06 - accuracy: 1.0000 - val_loss: 5.0771e-06 - val_accuracy: 1.0000
# 7/7 [==============================] - 1s 205ms/step - loss: 5.0771e-06 - accuracy: 1.0000
# Accuracy for Fold 1: 0.9777777791023254
# Accuracy for Fold 2: 0.9911110997200012
# Accuracy for Fold 3: 0.995555579662323
# Accuracy for Fold 4: 0.995555579662323
# Accuracy for Fold 5: 0.995555579662323
# Accuracy for Fold 6: 1.0
# Accuracy for Fold 7: 1.0
# Accuracy for Fold 8: 1.0
# Accuracy for Fold 9: 1.0
# Accuracy for Fold 10: 1.0
# Average Accuracy: 0.9955555617809295
# 31/31 [==============================] - 6s 188ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96       462
#          1.0       0.97      0.96      0.96       501
#
#     accuracy                           0.96       963
#    macro avg       0.96      0.96      0.96       963
# weighted avg       0.96      0.96      0.96       963
#
# Confusion Matrix:
# [[447  15]
#  [ 20 481]]
# 44/44 [==============================] - 8s 185ms/step

# %% [markdown]
# # FastText

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='BLSTM_FT_EL'))
    model.add(Bidirectional(LSTM(units=128, return_sequences=True), name='BLSTM_FT_1'))
    model.add(Bidirectional(LSTM(units=128), name='BLSTM_FT_2'))
    model.add(Dense(units=1, activation='sigmoid', name='BLSTM_FT_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model

def perform_cross_validation(X_train_padded, y_train, model, skf):
    fold = 1
    accuracies = []

    for train_index, val_index in skf.split(X_train_padded, y_train):
        print(f"Fold: {fold}")
        fold += 1

        X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/BILSTM/FastText/model10k_fold_{fold}.h5"
        checkpoint = ModelCheckpoint(
            checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
        )

        history = model.fit(X_train_fold, y_train_fold, epochs=10, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])
        
        plt.figure(figsize=(10, 5))  # Adjust figure size as desired
        plt.subplot(1, 2, 1)  # Create subplot for loss
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
    
        plt.subplot(1, 2, 2)  # Create subplot for accuracy
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
    
        plt.tight_layout()  # Adjust spacing between subplots
        plt.show()

        _, accuracy = model.evaluate(X_val_fold, y_val_fold)
        accuracies.append(accuracy)

    return accuracies

def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/BILSTM/FastText/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/BLSTM_ft.keras")
# Out:
# DEBUG:tensorflow:Layer lstm_2 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_2 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_2 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.2727 - accuracy: 0.8877 - val_loss: 0.2477 - val_accuracy: 0.9200
# Epoch 2/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.1744 - accuracy: 0.9431 - val_loss: 0.2319 - val_accuracy: 0.9244
# Epoch 3/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1704 - accuracy: 0.9441 - val_loss: 0.2233 - val_accuracy: 0.9200
# Epoch 4/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1644 - accuracy: 0.9461 - val_loss: 0.1871 - val_accuracy: 0.9200
# Epoch 5/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1587 - accuracy: 0.9491 - val_loss: 0.2015 - val_accuracy: 0.9244
# Epoch 6/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1496 - accuracy: 0.9491 - val_loss: 0.1871 - val_accuracy: 0.9289
# Epoch 7/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1480 - accuracy: 0.9525 - val_loss: 0.1700 - val_accuracy: 0.9333
# Epoch 8/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1410 - accuracy: 0.9525 - val_loss: 0.1664 - val_accuracy: 0.9333
# Epoch 9/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1346 - accuracy: 0.9555 - val_loss: 0.1689 - val_accuracy: 0.9378
# Epoch 10/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1381 - accuracy: 0.9550 - val_loss: 0.1637 - val_accuracy: 0.9333
# Epoch 11/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1312 - accuracy: 0.9594 - val_loss: 0.1648 - val_accuracy: 0.9422
# Epoch 12/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1317 - accuracy: 0.9570 - val_loss: 0.1735 - val_accuracy: 0.9378
# Epoch 13/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1304 - accuracy: 0.9565 - val_loss: 0.1543 - val_accuracy: 0.9333
# Epoch 14/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1271 - accuracy: 0.9585 - val_loss: 0.1757 - val_accuracy: 0.9244
# Epoch 15/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1367 - accuracy: 0.9525 - val_loss: 0.1629 - val_accuracy: 0.9378
# Epoch 16/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1288 - accuracy: 0.9580 - val_loss: 0.1610 - val_accuracy: 0.9378
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1610 - accuracy: 0.9378
# Fold: 2
# Epoch 1/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.1343 - accuracy: 0.9535 - val_loss: 0.1024 - val_accuracy: 0.9689
# Epoch 2/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1341 - accuracy: 0.9550 - val_loss: 0.1007 - val_accuracy: 0.9689
# Epoch 3/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1321 - accuracy: 0.9550 - val_loss: 0.1029 - val_accuracy: 0.9689
# Epoch 4/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1310 - accuracy: 0.9560 - val_loss: 0.0987 - val_accuracy: 0.9733
# Epoch 5/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1301 - accuracy: 0.9540 - val_loss: 0.0966 - val_accuracy: 0.9733
# Epoch 6/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1301 - accuracy: 0.9565 - val_loss: 0.1031 - val_accuracy: 0.9689
# Epoch 7/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.1289 - accuracy: 0.9570 - val_loss: 0.0993 - val_accuracy: 0.9644
# Epoch 8/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1316 - accuracy: 0.9555 - val_loss: 0.1047 - val_accuracy: 0.9644
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1047 - accuracy: 0.9644
# Fold: 3
# Epoch 1/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.1261 - accuracy: 0.9585 - val_loss: 0.1328 - val_accuracy: 0.9467
# Epoch 2/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1225 - accuracy: 0.9599 - val_loss: 0.1413 - val_accuracy: 0.9422
# Epoch 3/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1235 - accuracy: 0.9585 - val_loss: 0.1392 - val_accuracy: 0.9422
# Epoch 4/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1222 - accuracy: 0.9594 - val_loss: 0.1456 - val_accuracy: 0.9378
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1456 - accuracy: 0.9378
# Fold: 4
# Epoch 1/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1252 - accuracy: 0.9570 - val_loss: 0.1209 - val_accuracy: 0.9689
# Epoch 2/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1245 - accuracy: 0.9575 - val_loss: 0.1252 - val_accuracy: 0.9689
# Epoch 3/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.1216 - accuracy: 0.9580 - val_loss: 0.1234 - val_accuracy: 0.9689
# Epoch 4/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1221 - accuracy: 0.9580 - val_loss: 0.1314 - val_accuracy: 0.9689
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1314 - accuracy: 0.9689
# Fold: 5
# Epoch 1/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1188 - accuracy: 0.9599 - val_loss: 0.1545 - val_accuracy: 0.9422
# Epoch 2/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1172 - accuracy: 0.9594 - val_loss: 0.1587 - val_accuracy: 0.9422
# Epoch 3/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1168 - accuracy: 0.9614 - val_loss: 0.1539 - val_accuracy: 0.9467
# Epoch 4/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1165 - accuracy: 0.9619 - val_loss: 0.1562 - val_accuracy: 0.9467
# Epoch 5/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1139 - accuracy: 0.9604 - val_loss: 0.1585 - val_accuracy: 0.9422
# Epoch 6/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1129 - accuracy: 0.9604 - val_loss: 0.1540 - val_accuracy: 0.9467
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1540 - accuracy: 0.9467
# Fold: 6
# Epoch 1/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1160 - accuracy: 0.9604 - val_loss: 0.1184 - val_accuracy: 0.9600
# Epoch 2/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1158 - accuracy: 0.9594 - val_loss: 0.1238 - val_accuracy: 0.9600
# Epoch 3/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1179 - accuracy: 0.9614 - val_loss: 0.1207 - val_accuracy: 0.9600
# Epoch 4/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1145 - accuracy: 0.9604 - val_loss: 0.1193 - val_accuracy: 0.9600
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1193 - accuracy: 0.9600
# Fold: 7
# Epoch 1/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1187 - accuracy: 0.9609 - val_loss: 0.1568 - val_accuracy: 0.9467
# Epoch 2/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1145 - accuracy: 0.9594 - val_loss: 0.1336 - val_accuracy: 0.9600
# Epoch 3/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1129 - accuracy: 0.9585 - val_loss: 0.1354 - val_accuracy: 0.9600
# Epoch 4/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1110 - accuracy: 0.9609 - val_loss: 0.1351 - val_accuracy: 0.9600
# Epoch 5/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.1105 - accuracy: 0.9609 - val_loss: 0.1380 - val_accuracy: 0.9600
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1380 - accuracy: 0.9600
# Fold: 8
# Epoch 1/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.1130 - accuracy: 0.9605 - val_loss: 0.0898 - val_accuracy: 0.9688
# Epoch 2/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1156 - accuracy: 0.9614 - val_loss: 0.0900 - val_accuracy: 0.9732
# Epoch 3/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.1144 - accuracy: 0.9609 - val_loss: 0.0917 - val_accuracy: 0.9732
# Epoch 4/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1158 - accuracy: 0.9595 - val_loss: 0.0977 - val_accuracy: 0.9688
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0977 - accuracy: 0.9688
# Fold: 9
# Epoch 1/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.3959 - accuracy: 0.9100 - val_loss: 0.1407 - val_accuracy: 0.9643
# Epoch 2/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1395 - accuracy: 0.9565 - val_loss: 0.1288 - val_accuracy: 0.9554
# Epoch 3/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.1218 - accuracy: 0.9585 - val_loss: 0.1175 - val_accuracy: 0.9554
# Epoch 4/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1182 - accuracy: 0.9605 - val_loss: 0.1204 - val_accuracy: 0.9554
# Epoch 5/100
# 32/32 [==============================] - 2s 78ms/step - loss: 0.1179 - accuracy: 0.9605 - val_loss: 0.1184 - val_accuracy: 0.9598
# Epoch 6/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.1127 - accuracy: 0.9629 - val_loss: 0.1205 - val_accuracy: 0.9598
# 7/7 [==============================] - 0s 57ms/step - loss: 0.1205 - accuracy: 0.9598
# Fold: 10
# Epoch 1/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1205 - accuracy: 0.9585 - val_loss: 0.0598 - val_accuracy: 0.9777
# Epoch 2/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1186 - accuracy: 0.9614 - val_loss: 0.0691 - val_accuracy: 0.9732
# Epoch 3/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1142 - accuracy: 0.9600 - val_loss: 0.0766 - val_accuracy: 0.9732
# Epoch 4/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1135 - accuracy: 0.9624 - val_loss: 0.0725 - val_accuracy: 0.9777
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0725 - accuracy: 0.9777
# Accuracy for Fold 1: 0.9377777576446533
# Accuracy for Fold 2: 0.9644444584846497
# Accuracy for Fold 3: 0.9377777576446533
# Accuracy for Fold 4: 0.9688888788223267
# Accuracy for Fold 5: 0.9466666579246521
# Accuracy for Fold 6: 0.9599999785423279
# Accuracy for Fold 7: 0.9599999785423279
# Accuracy for Fold 8: 0.96875
# Accuracy for Fold 9: 0.9598214030265808
# Accuracy for Fold 10: 0.9776785969734192
# Average Accuracy: 0.9581805467605591
# 31/31 [==============================] - 1s 31ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96       462
#          1.0       0.99      0.93      0.96       501
#
#     accuracy                           0.96       963
#    macro avg       0.96      0.96      0.96       963
# weighted avg       0.96      0.96      0.96       963
#
# Confusion Matrix:
# [[458   4]
#  [ 35 466]]
# 44/44 [==============================] - 1s 29ms/step
