# %%
import os
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score

os.environ['TF_FORCE_UNIFIED_MEMORY']='1'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='2.0'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH ']='true' # as I understood, this is redundant with the set_memory_growth part :)

import tensorflow as tf    
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      print(gpu)
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = 'F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//Raw//dataset 1//Dataset_raw'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=539249, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model(x):
  filename = f'F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Embedding Models 2//Word2vec//word2vec_{x}_model.pkl'

  with open(filename, 'rb') as f:
    embedding_model = pickle.load(f)

  return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='BLSTM_W2V_EL'))
    model.add(Bidirectional(LSTM(units=128, return_sequences=True), name='BLSTM_W2V_1'))
    model.add(Bidirectional(LSTM(units=128), name='BLSTM_W2V_2'))
    model.add(Dense(units=2, activation='softmax', name='BLSTM_W2V_OL'))    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model


def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)  

    y_pred = np.argmax(y_pred_prob, axis=1)

    if y_test.shape[1] > 1:
        y_test = np.argmax(y_test, axis=1)

    report = classification_report(y_test, y_pred)
    print(report)

    confusion = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Checkpoints//Sentence//LSTM//Word2vec//model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()
y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)
print("1")
# Load the Word2Vec embedding model

embedding_dims = [50,100,150]

for embedding_dim in embedding_dims:
    embedding_model = load_embedding_model(embedding_dim)
    
    # Create the embedding matrix
    embedding_dim = embedding_dim
    vocab_size = 539249
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]
    
    # Create a sequential model
    model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])
    
    X_train_fold, X_val_fold, y_train_fold, y_val_fold = train_test_split(X_train_padded, y_train, test_size=0.1, random_state=42)
      
    
    history = model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=64, validation_data=(X_val_fold, y_val_fold))
    
    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
        
    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()
    # Evaluate the model using the test set
    evaluate_model(X_test_padded, y_test, model)
    
    # Predict on the additional test set
    test_pred = predict_additional_data(test_padded, model)        
        
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//LSTM//word2vec/BLSTM_w2v_{embedding_dim}.keras")
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# 1
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# Epoch 1/50
#  7/32 [=====>........................] - ETA: 1:07 - loss: 0.5772 - accuracy: 0.7009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 181
#     176 model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])
#     178 X_train_fold, X_val_fold, y_train_fold, y_val_fold = train_test_split(X_train_padded, y_train, test_size=0.1, random_state=42)
# --> 181 history = model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=64, validation_data=(X_val_fold, y_val_fold))
#     183 # Plot both loss and accuracy
#     184 plt.figure(figsize=(10, 5))  # Adjust figure size as desired
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1160, in Model.make_train_function.<locals>.train_function(iterator)
#    1158 def train_function(iterator):
#    1159     """Runs a training execution with a single step."""
# -> 1160     return step_function(self, iterator)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1146, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1142     run_step = tf.function(
#    1143         run_step, jit_compile=True, reduce_retracing=True
#    1144     )
#    1145 data = next(iterator)
# -> 1146 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1147 outputs = reduce_per_replica(
#    1148     outputs, self.distribute_strategy, reduction="first"
#    1149 )
#    1150 return outputs
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1315, in StrategyBase.run(***failed resolving arguments***)
#    1310 with self.scope():
#    1311   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1312   # applied when the caller is also in Eager mode.
#    1313   fn = autograph.tf_convert(
#    1314       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1315   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2891, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2889   kwargs = {}
#    2890 with self._container_strategy().scope():
# -> 2891   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3692, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3690 def _call_for_each_replica(self, fn, args, kwargs):
#    3691   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3692     return fn(*args, **kwargs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1135, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1134 def run_step(data):
# -> 1135     outputs = model.train_step(data)
#    1136     # Ensure counter is updated only if `train_step` succeeds.
#    1137     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:997, in Model.train_step(self, data)
#     995 self._validate_target_and_loss(y, loss)
#     996 # Run backwards pass.
# --> 997 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     998 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:576, in OptimizerV2.minimize(self, loss, var_list, grad_loss, name, tape)
#     545 def minimize(self, loss, var_list, grad_loss=None, name=None, tape=None):
#     546     """Minimize `loss` by updating `var_list`.
#     547
#     548     This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     574
#     575     """
# --> 576     grads_and_vars = self._compute_gradients(
#     577         loss, var_list=var_list, grad_loss=grad_loss, tape=tape
#     578     )
#     579     return self.apply_gradients(grads_and_vars, name=name)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:634, in OptimizerV2._compute_gradients(self, loss, var_list, grad_loss, tape)
#     632 var_list = tf.nest.flatten(var_list)
#     633 with tf.name_scope(self._name + "/gradients"):
# --> 634     grads_and_vars = self._get_gradients(
#     635         tape, loss, var_list, grad_loss
#     636     )
#     638 self._assert_valid_dtypes(
#     639     [
#     640         v
#    (...)
#     643     ]
#     644 )
#     646 return grads_and_vars
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:510, in OptimizerV2._get_gradients(self, tape, loss, var_list, grad_loss)
#     508 def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     509     """Called in `minimize` to compute gradients from loss."""
# --> 510     grads = tape.gradient(loss, var_list, grad_loss)
#     511     return list(zip(grads, var_list))
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\eager\backprop.py:1113, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1107   output_gradients = (
#    1108       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1109           output_gradients))
#    1110   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1111                       for x in output_gradients]
# -> 1113 flat_grad = imperative_grad.imperative_grad(
#    1114     self._tape,
#    1115     flat_targets,
#    1116     flat_sources,
#    1117     output_gradients=output_gradients,
#    1118     sources_raw=flat_sources_raw,
#    1119     unconnected_gradients=unconnected_gradients)
#    1121 if not self._persistent:
#    1122   # Keep track of watched variables before setting tape to None
#    1123   self._watched_variables = self._tape.watched_variables()
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\eager\backprop.py:160, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     158     gradient_name_scope += forward_pass_name_scope + "/"
#     159   with ops.name_scope(gradient_name_scope):
# --> 160     return grad_fn(mock_op, *out_grads)
#     161 else:
#     162   return grad_fn(mock_op, *out_grads)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\cudnn_rnn_grad.py:26, in _cudnn_rnn_backward(op, *grads)
#      23 if not op.get_attr("is_training"):
#      24   raise ValueError(
#      25       "To use CudnnRNN in gradients, is_training must be set to True.")
# ---> 26 return gen_cudnn_rnn_ops.cudnn_rnn_backprop(
#      27     input=op.inputs[0],
#      28     input_h=op.inputs[1],
#      29     input_c=op.inputs[2],
#      30     params=op.inputs[3],
#      31     output=op.outputs[0],
#      32     output_h=op.outputs[1],
#      33     output_c=op.outputs[2],
#      34     output_backprop=grads[0],
#      35     output_h_backprop=grads[1],
#      36     output_c_backprop=grads[2],
#      37     reserve_space=op.outputs[3],
#      38     dropout=op.get_attr("dropout"),
#      39     seed=op.get_attr("seed"),
#      40     seed2=op.get_attr("seed2"),
#      41     rnn_mode=op.get_attr("rnn_mode"),
#      42     input_mode=op.get_attr("input_mode"),
#      43     direction=op.get_attr("direction"))
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gen_cudnn_rnn_ops.py:266, in cudnn_rnn_backprop(input, input_h, input_c, params, output, output_h, output_c, output_backprop, output_h_backprop, output_c_backprop, reserve_space, rnn_mode, input_mode, direction, dropout, seed, seed2, name)
#     264 if tld.is_eager:
#     265   try:
# --> 266     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     267       _ctx, "CudnnRNNBackprop", name, input, input_h, input_c, params,
#     268       output, output_h, output_c, output_backprop, output_h_backprop,
#     269       output_c_backprop, reserve_space, "rnn_mode", rnn_mode, "input_mode",
#     270       input_mode, "direction", direction, "dropout", dropout, "seed", seed,
#     271       "seed2", seed2)
#     272     _result = _CudnnRNNBackpropOutput._make(_result)
#     273     return _result
#
# KeyboardInterrupt:

# %%
import os
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score

os.environ['TF_FORCE_UNIFIED_MEMORY']='1'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='2.0'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH ']='true' # as I understood, this is redundant with the set_memory_growth part :)

import tensorflow as tf    
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      print(gpu)
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = 'F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//Raw//dataset 1//Dataset_raw'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=539249, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model(x):
  filename = f'F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Embedding Models 2//FastText//fasttext_{x}_model.pkl'

  with open(filename, 'rb') as f:
    embedding_model = pickle.load(f)

  return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='BLSTM_W2V_EL'))
    model.add(Bidirectional(LSTM(units=128, return_sequences=True), name='BLSTM_W2V_1'))
    model.add(Bidirectional(LSTM(units=128), name='BLSTM_W2V_2'))
    model.add(Dense(units=2, activation='softmax', name='BLSTM_W2V_OL'))    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model


def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)  

    y_pred = np.argmax(y_pred_prob, axis=1)

    if y_test.shape[1] > 1:
        y_test = np.argmax(y_test, axis=1)

    report = classification_report(y_test, y_pred)
    print(report)

    confusion = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Checkpoints//Sentence//LSTM//Word2vec//model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()
y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)
print("1")
# Load the Word2Vec embedding model

embedding_dims = [50,100,150]

for embedding_dim in embedding_dims:
    embedding_model = load_embedding_model(embedding_dim)
    
    # Create the embedding matrix
    embedding_dim = embedding_dim
    vocab_size = 539249
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]
    
    # Create a sequential model
    model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])
    
    X_train_fold, X_val_fold, y_train_fold, y_val_fold = train_test_split(X_train_padded, y_train, test_size=0.1, random_state=42)
      
    
    history = model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=64, validation_data=(X_val_fold, y_val_fold))
    
    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
        
    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()
    # Evaluate the model using the test set
    evaluate_model(X_test_padded, y_test, model)
    
    # Predict on the additional test set
    test_pred = predict_additional_data(test_padded, model)        
        
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//LSTM//word2vec/BLSTM_ft_{embedding_dim}.keras")
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# 1
# DEBUG:tensorflow:Layer lstm_6 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_6 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_6 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_7 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_7 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_7 will use cuDNN kernels when running on GPU.
# Epoch 1/50
# 32/32 [==============================] - 15s 476ms/step - loss: 0.4586 - accuracy: 0.7938 - val_loss: 0.3924 - val_accuracy: 0.8667
# Epoch 2/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.2890 - accuracy: 0.8872 - val_loss: 0.1987 - val_accuracy: 0.9422
# Epoch 3/50
# 32/32 [==============================] - 15s 476ms/step - loss: 0.2411 - accuracy: 0.9130 - val_loss: 0.2216 - val_accuracy: 0.9333
# Epoch 4/50
# 32/32 [==============================] - 15s 476ms/step - loss: 0.2249 - accuracy: 0.9090 - val_loss: 0.1475 - val_accuracy: 0.9600
# Epoch 5/50
# 32/32 [==============================] - 15s 476ms/step - loss: 0.1275 - accuracy: 0.9644 - val_loss: 0.1090 - val_accuracy: 0.9689
# Epoch 6/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.1496 - accuracy: 0.9515 - val_loss: 0.1567 - val_accuracy: 0.9556
# Epoch 7/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.2304 - accuracy: 0.9194 - val_loss: 0.2157 - val_accuracy: 0.9244
# Epoch 8/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.1502 - accuracy: 0.9500 - val_loss: 0.1480 - val_accuracy: 0.9511
# Epoch 9/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.1208 - accuracy: 0.9619 - val_loss: 0.1243 - val_accuracy: 0.9600
# Epoch 10/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0962 - accuracy: 0.9713 - val_loss: 0.1018 - val_accuracy: 0.9733
# Epoch 11/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0857 - accuracy: 0.9748 - val_loss: 0.0925 - val_accuracy: 0.9778
# Epoch 12/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0769 - accuracy: 0.9782 - val_loss: 0.1012 - val_accuracy: 0.9778
# Epoch 13/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0728 - accuracy: 0.9758 - val_loss: 0.1062 - val_accuracy: 0.9689
# Epoch 14/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0625 - accuracy: 0.9787 - val_loss: 0.1308 - val_accuracy: 0.9556
# Epoch 15/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0569 - accuracy: 0.9837 - val_loss: 0.0964 - val_accuracy: 0.9689
# Epoch 16/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0505 - accuracy: 0.9822 - val_loss: 0.1246 - val_accuracy: 0.9556
# Epoch 17/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0451 - accuracy: 0.9832 - val_loss: 0.1075 - val_accuracy: 0.9644
# Epoch 18/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0402 - accuracy: 0.9876 - val_loss: 0.0722 - val_accuracy: 0.9733
# Epoch 19/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0337 - accuracy: 0.9871 - val_loss: 0.0798 - val_accuracy: 0.9733
# Epoch 20/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0270 - accuracy: 0.9926 - val_loss: 0.1598 - val_accuracy: 0.9511
# Epoch 21/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0213 - accuracy: 0.9936 - val_loss: 0.0832 - val_accuracy: 0.9689
# Epoch 22/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0200 - accuracy: 0.9951 - val_loss: 0.1134 - val_accuracy: 0.9556
# Epoch 23/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0235 - accuracy: 0.9931 - val_loss: 0.0884 - val_accuracy: 0.9733
# Epoch 24/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.1133 - val_accuracy: 0.9556
# Epoch 25/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0119 - accuracy: 0.9985 - val_loss: 0.1472 - val_accuracy: 0.9556
# Epoch 26/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0601 - accuracy: 0.9822 - val_loss: 0.0832 - val_accuracy: 0.9733
# Epoch 27/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0420 - accuracy: 0.9871 - val_loss: 0.1188 - val_accuracy: 0.9600
# Epoch 28/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0201 - accuracy: 0.9941 - val_loss: 0.1262 - val_accuracy: 0.9511
# Epoch 29/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.1974 - val_accuracy: 0.9200
# Epoch 30/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0465 - accuracy: 0.9832 - val_loss: 0.0998 - val_accuracy: 0.9778
# Epoch 31/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0177 - accuracy: 0.9960 - val_loss: 0.1263 - val_accuracy: 0.9644
# Epoch 32/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.1068 - val_accuracy: 0.9644
# Epoch 33/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0080 - accuracy: 0.9985 - val_loss: 0.1171 - val_accuracy: 0.9600
# Epoch 34/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.1198 - val_accuracy: 0.9689
# Epoch 35/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.1224 - val_accuracy: 0.9689
# Epoch 36/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.1118 - val_accuracy: 0.9644
# Epoch 37/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.1341 - val_accuracy: 0.9600
# Epoch 38/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.1285 - val_accuracy: 0.9600
# Epoch 39/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9644
# Epoch 40/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1508 - val_accuracy: 0.9556
# Epoch 41/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.1838 - val_accuracy: 0.9600
# Epoch 42/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0246 - accuracy: 0.9946 - val_loss: 0.4649 - val_accuracy: 0.8800
# Epoch 43/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0879 - accuracy: 0.9713 - val_loss: 0.0825 - val_accuracy: 0.9689
# Epoch 44/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0240 - accuracy: 0.9936 - val_loss: 0.0912 - val_accuracy: 0.9644
# Epoch 45/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.0839 - val_accuracy: 0.9644
# Epoch 46/50
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.1099 - val_accuracy: 0.9644
# Epoch 47/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.1141 - val_accuracy: 0.9600
# Epoch 48/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.1243 - val_accuracy: 0.9600
# Epoch 49/50
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.1190 - val_accuracy: 0.9689
# Epoch 50/50
# 32/32 [==============================] - 15s 479ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.1068 - val_accuracy: 0.9689
# 31/31 [==============================] - 4s 129ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       462
#            1       0.97      0.97      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[445  17]
#  [ 16 485]]
# 44/44 [==============================] - 6s 129ms/step
# DEBUG:tensorflow:Layer lstm_8 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_8 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_8 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_9 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_9 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_9 will use cuDNN kernels when running on GPU.
# Epoch 1/50
# 32/32 [==============================] - 16s 503ms/step - loss: 0.4076 - accuracy: 0.8185 - val_loss: 0.3146 - val_accuracy: 0.8844
# Epoch 2/50
# 32/32 [==============================] - 16s 489ms/step - loss: 0.2972 - accuracy: 0.8897 - val_loss: 0.1918 - val_accuracy: 0.9378
# Epoch 3/50
# 32/32 [==============================] - 16s 490ms/step - loss: 0.1769 - accuracy: 0.9407 - val_loss: 0.1149 - val_accuracy: 0.9689
# Epoch 4/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.1426 - accuracy: 0.9525 - val_loss: 0.1653 - val_accuracy: 0.9511
# Epoch 5/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.1193 - accuracy: 0.9594 - val_loss: 0.1147 - val_accuracy: 0.9644
# Epoch 6/50
# 32/32 [==============================] - 16s 500ms/step - loss: 0.0854 - accuracy: 0.9748 - val_loss: 0.1094 - val_accuracy: 0.9644
# Epoch 7/50
# 32/32 [==============================] - 16s 495ms/step - loss: 0.0738 - accuracy: 0.9763 - val_loss: 0.1018 - val_accuracy: 0.9733
# Epoch 8/50
# 32/32 [==============================] - 16s 503ms/step - loss: 0.0645 - accuracy: 0.9792 - val_loss: 0.1138 - val_accuracy: 0.9644
# Epoch 9/50
# 32/32 [==============================] - 16s 495ms/step - loss: 0.0710 - accuracy: 0.9773 - val_loss: 0.1017 - val_accuracy: 0.9644
# Epoch 10/50
# 32/32 [==============================] - 16s 498ms/step - loss: 0.0510 - accuracy: 0.9822 - val_loss: 0.1032 - val_accuracy: 0.9689
# Epoch 11/50
# 32/32 [==============================] - 16s 502ms/step - loss: 0.0432 - accuracy: 0.9857 - val_loss: 0.1082 - val_accuracy: 0.9689
# Epoch 12/50
# 32/32 [==============================] - 16s 496ms/step - loss: 0.0653 - accuracy: 0.9782 - val_loss: 0.1117 - val_accuracy: 0.9644
# Epoch 13/50
# 32/32 [==============================] - 16s 501ms/step - loss: 0.0411 - accuracy: 0.9876 - val_loss: 0.0874 - val_accuracy: 0.9733
# Epoch 14/50
# 32/32 [==============================] - 16s 499ms/step - loss: 0.0378 - accuracy: 0.9886 - val_loss: 0.1886 - val_accuracy: 0.9467
# Epoch 15/50
# 32/32 [==============================] - 16s 501ms/step - loss: 0.0294 - accuracy: 0.9901 - val_loss: 0.0852 - val_accuracy: 0.9778
# Epoch 16/50
# 32/32 [==============================] - 16s 502ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0809 - val_accuracy: 0.9778
# Epoch 17/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0154 - accuracy: 0.9941 - val_loss: 0.1103 - val_accuracy: 0.9733
# Epoch 18/50
# 32/32 [==============================] - 16s 499ms/step - loss: 0.0272 - accuracy: 0.9921 - val_loss: 0.1009 - val_accuracy: 0.9778
# Epoch 19/50
# 32/32 [==============================] - 16s 495ms/step - loss: 0.0495 - accuracy: 0.9827 - val_loss: 0.1078 - val_accuracy: 0.9600
# Epoch 20/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.1047 - val_accuracy: 0.9733
# Epoch 21/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0170 - accuracy: 0.9955 - val_loss: 0.1181 - val_accuracy: 0.9600
# Epoch 22/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0264 - accuracy: 0.9901 - val_loss: 0.1238 - val_accuracy: 0.9556
# Epoch 23/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.1672 - val_accuracy: 0.9644
# Epoch 24/50
# 32/32 [==============================] - 16s 495ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0973 - val_accuracy: 0.9778
# Epoch 25/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.1070 - val_accuracy: 0.9778
# Epoch 26/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1106 - val_accuracy: 0.9778
# Epoch 27/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.1575 - val_accuracy: 0.9733
# Epoch 28/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 0.1158 - val_accuracy: 0.9778
# Epoch 29/50
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0113 - accuracy: 0.9955 - val_loss: 0.1231 - val_accuracy: 0.9733
# Epoch 30/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.1375 - val_accuracy: 0.9689
# Epoch 31/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.1100 - val_accuracy: 0.9778
# Epoch 32/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1181 - val_accuracy: 0.9778
# Epoch 33/50
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0581 - accuracy: 0.9807 - val_loss: 0.1237 - val_accuracy: 0.9689
# Epoch 34/50
# 32/32 [==============================] - 16s 505ms/step - loss: 0.0577 - accuracy: 0.9782 - val_loss: 0.0865 - val_accuracy: 0.9822
# Epoch 35/50
# 32/32 [==============================] - 17s 520ms/step - loss: 0.0155 - accuracy: 0.9941 - val_loss: 0.0979 - val_accuracy: 0.9689
# Epoch 36/50
# 32/32 [==============================] - 17s 517ms/step - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.1149 - val_accuracy: 0.9733
# Epoch 37/50
# 32/32 [==============================] - 16s 496ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.1085 - val_accuracy: 0.9778
# Epoch 38/50
# 32/32 [==============================] - 16s 516ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9778
# Epoch 39/50
# 32/32 [==============================] - 17s 519ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9778
# Epoch 40/50
# 32/32 [==============================] - 16s 511ms/step - loss: 8.0216e-04 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9822
# Epoch 41/50
# 32/32 [==============================] - 16s 502ms/step - loss: 6.8920e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9822
# Epoch 42/50
# 32/32 [==============================] - 16s 496ms/step - loss: 4.7585e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9778
# Epoch 43/50
# 32/32 [==============================] - 16s 494ms/step - loss: 3.6874e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9778
# Epoch 44/50
# 32/32 [==============================] - 16s 493ms/step - loss: 3.0980e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9733
# Epoch 45/50
# 32/32 [==============================] - 16s 494ms/step - loss: 2.7132e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9778
# Epoch 46/50
# 32/32 [==============================] - 16s 494ms/step - loss: 2.3688e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9733
# Epoch 47/50
# 32/32 [==============================] - 16s 493ms/step - loss: 2.1498e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9778
# Epoch 48/50
# 32/32 [==============================] - 16s 494ms/step - loss: 1.9091e-04 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9733
# Epoch 49/50
# 32/32 [==============================] - 16s 494ms/step - loss: 1.7521e-04 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9733
# Epoch 50/50
# 32/32 [==============================] - 16s 493ms/step - loss: 1.6044e-04 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9733
# 31/31 [==============================] - 4s 130ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       462
#            1       0.97      0.96      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[448  14]
#  [ 18 483]]
# 44/44 [==============================] - 6s 130ms/step
# DEBUG:tensorflow:Layer lstm_10 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_10 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_10 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_11 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_11 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_11 will use cuDNN kernels when running on GPU.
# Epoch 1/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.3968 - accuracy: 0.8244 - val_loss: 0.2701 - val_accuracy: 0.8978
# Epoch 2/50
# 32/32 [==============================] - 16s 508ms/step - loss: 0.3346 - accuracy: 0.8689 - val_loss: 0.2494 - val_accuracy: 0.9067
# Epoch 3/50
# 32/32 [==============================] - 16s 508ms/step - loss: 0.1719 - accuracy: 0.9431 - val_loss: 0.1474 - val_accuracy: 0.9467
# Epoch 4/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.1256 - accuracy: 0.9594 - val_loss: 0.1096 - val_accuracy: 0.9600
# Epoch 5/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.1280 - accuracy: 0.9590 - val_loss: 0.1505 - val_accuracy: 0.9511
# Epoch 6/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.1318 - accuracy: 0.9575 - val_loss: 0.1164 - val_accuracy: 0.9689
# Epoch 7/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.1096 - accuracy: 0.9669 - val_loss: 0.1062 - val_accuracy: 0.9689
# Epoch 8/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0841 - accuracy: 0.9758 - val_loss: 0.1020 - val_accuracy: 0.9689
# Epoch 9/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0761 - accuracy: 0.9753 - val_loss: 0.0954 - val_accuracy: 0.9689
# Epoch 10/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0701 - accuracy: 0.9807 - val_loss: 0.1281 - val_accuracy: 0.9556
# Epoch 11/50
# 32/32 [==============================] - 16s 515ms/step - loss: 0.0656 - accuracy: 0.9787 - val_loss: 0.1014 - val_accuracy: 0.9689
# Epoch 12/50
# 32/32 [==============================] - 17s 528ms/step - loss: 0.0664 - accuracy: 0.9787 - val_loss: 0.0998 - val_accuracy: 0.9689
# Epoch 13/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0483 - accuracy: 0.9862 - val_loss: 0.1372 - val_accuracy: 0.9511
# Epoch 14/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0635 - accuracy: 0.9807 - val_loss: 0.1107 - val_accuracy: 0.9644
# Epoch 15/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0563 - accuracy: 0.9822 - val_loss: 0.1286 - val_accuracy: 0.9511
# Epoch 16/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0511 - accuracy: 0.9842 - val_loss: 0.1649 - val_accuracy: 0.9422
# Epoch 17/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0538 - accuracy: 0.9837 - val_loss: 0.1312 - val_accuracy: 0.9600
# Epoch 18/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0365 - accuracy: 0.9886 - val_loss: 0.1354 - val_accuracy: 0.9511
# Epoch 19/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0385 - accuracy: 0.9871 - val_loss: 0.1134 - val_accuracy: 0.9644
# Epoch 20/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0471 - accuracy: 0.9832 - val_loss: 0.1022 - val_accuracy: 0.9511
# Epoch 21/50
# 32/32 [==============================] - 16s 509ms/step - loss: 0.0274 - accuracy: 0.9931 - val_loss: 0.1378 - val_accuracy: 0.9556
# Epoch 22/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0313 - accuracy: 0.9891 - val_loss: 0.1276 - val_accuracy: 0.9600
# Epoch 23/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0332 - accuracy: 0.9886 - val_loss: 0.1165 - val_accuracy: 0.9644
# Epoch 24/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0425 - accuracy: 0.9842 - val_loss: 0.1533 - val_accuracy: 0.9511
# Epoch 25/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0311 - accuracy: 0.9881 - val_loss: 0.1411 - val_accuracy: 0.9556
# Epoch 26/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.1265 - val_accuracy: 0.9644
# Epoch 27/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.1192 - val_accuracy: 0.9689
# Epoch 28/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.1477 - val_accuracy: 0.9644
# Epoch 29/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 0.1317 - val_accuracy: 0.9644
# Epoch 30/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.1249 - val_accuracy: 0.9733
# Epoch 31/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.1451 - val_accuracy: 0.9644
# Epoch 32/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.1651 - val_accuracy: 0.9689
# Epoch 33/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.1354 - val_accuracy: 0.9556
# Epoch 34/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.1592 - val_accuracy: 0.9733
# Epoch 35/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.1670 - val_accuracy: 0.9689
# Epoch 36/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.1817 - val_accuracy: 0.9644
# Epoch 37/50
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1788 - val_accuracy: 0.9644
# Epoch 38/50
# 32/32 [==============================] - 16s 511ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9644
# Epoch 39/50
# 32/32 [==============================] - 16s 510ms/step - loss: 7.6885e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9644
# Epoch 40/50
# 32/32 [==============================] - 16s 510ms/step - loss: 5.3585e-04 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9689
# Epoch 41/50
# 32/32 [==============================] - 16s 511ms/step - loss: 4.1178e-04 - accuracy: 1.0000 - val_loss: 0.1819 - val_accuracy: 0.9689
# Epoch 42/50
# 32/32 [==============================] - 16s 511ms/step - loss: 3.3103e-04 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9689
# Epoch 43/50
# 32/32 [==============================] - 16s 511ms/step - loss: 2.8556e-04 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9689
# Epoch 44/50
# 32/32 [==============================] - 16s 510ms/step - loss: 2.5577e-04 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9689
# Epoch 45/50
# 32/32 [==============================] - 16s 510ms/step - loss: 2.3138e-04 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.9689
# Epoch 46/50
# 32/32 [==============================] - 16s 511ms/step - loss: 2.1140e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9689
# Epoch 47/50
# 32/32 [==============================] - 16s 512ms/step - loss: 1.9443e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9689
# Epoch 48/50
# 32/32 [==============================] - 16s 511ms/step - loss: 1.7966e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9689
# Epoch 49/50
# 32/32 [==============================] - 16s 511ms/step - loss: 1.6690e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9689
# Epoch 50/50
# 32/32 [==============================] - 16s 510ms/step - loss: 1.5575e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9689
# 31/31 [==============================] - 4s 134ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       462
#            1       0.97      0.96      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[448  14]
#  [ 18 483]]
# 44/44 [==============================] - 6s 135ms/step
