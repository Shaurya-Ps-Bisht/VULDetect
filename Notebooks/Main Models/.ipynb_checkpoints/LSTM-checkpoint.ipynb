# %% [markdown]
# # LSTM (Sentence) word2vec

# %%
import os
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
# tf.data.experimental.enable_debug_mode()
# tf.config.run_functions_eagerly(True)
# tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='LSTM_W2V_EL'))
    model.add(LSTM(units=128, return_sequences=True, name='LSTM_W2V_1'))
    model.add(LSTM(units=128, name='LSTM_W2V_2'))
    model.add(Dense(units=1, activation='sigmoid', name='LSTM_W2V_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
  fold = 1
  accuracies = []

  for train_index, val_index in skf.split(X_train_padded, y_train):
    print(f"Fold: {fold}")
    fold += 1

    X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5"
    checkpoint = ModelCheckpoint(
        checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
    )

    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])

    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    _, accuracy = model.evaluate(X_val_fold, y_val_fold)
    accuracies.append(accuracy)

  return accuracies
def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/LSTM_w2v.keras")
# Out:
# 2024-03-19 05:44:46.354447: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 05:44:46.573964: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-19 05:44:47.367804: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-19 05:44:47.367967: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-19 05:44:47.367979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # LSTM FastText

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='LSTM_FT_EL'))
    model.add(LSTM(units=128, return_sequences=True, name='LSTM_FT_1'))
    model.add(LSTM(units=128, name='LSTM_FT_2'))
    model.add(Dense(units=1, activation='sigmoid', name='LSTM_FT_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
  fold = 1
  accuracies = []

  for train_index, val_index in skf.split(X_train_padded, y_train):
    print(f"Fold: {fold}")
    fold += 1

    X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    checkpoint_path = f"/home/shaurya/BTP/Outputs/Checkpoints/Sentence/LSTM/FastText/model10k_fold_{fold}.h5"
    checkpoint = ModelCheckpoint(
        checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
    )

    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])

    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    _, accuracy = model.evaluate(X_val_fold, y_val_fold)
    accuracies.append(accuracy)

  return accuracies

def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/FastText/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

# Load the Word2Vec embedding model
embedding_model = load_embedding_model()

# Create the embedding matrix
embedding_dim = 150
vocab_size = 359414
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size and word in embedding_model.wv:
        embedding_matrix[i] = embedding_model.wv[word]

# Create a sequential model
model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Create Stratified K-fold cross-validation object
skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

# Perform cross-validation training and collect accuracies
accuracies = perform_cross_validation(X_train_padded, y_train, model, skf)

# Print accuracy for each fold
for fold, accuracy in enumerate(accuracies, start=1):
    print(f"Accuracy for Fold {fold}: {accuracy}")

# Calculate and print average accuracy
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy: {average_accuracy}")

# Evaluate the model using the test set
evaluate_model(X_test_padded, y_test, model)

# Predict on the additional test set
test_pred = predict_additional_data(test_padded, model)

# Save the trained model for each fold
for fold in range(1, skf.n_splits + 1):
    save_model(model, fold)
    
    
model.save(f"/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/LSTM_ft.keras")
# Out:
# 2024-03-11 08:42:08.382203: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 08:42:08.560753: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-11 08:42:09.374781: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-11 08:42:09.374876: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-11 08:42:09.374887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-03-11 08:42:20.121953: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 08:42:22.189778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2050 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:3b:00.0, compute capability: 6.0
# 2024-03-11 08:42:22.191053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10922 MB memory:  -> device: 1, name: Tesla P100-PCIE-12GB, pci bus id: 0000:af:00.0, compute capability: 6.0
# 2024-03-11 08:42:22.192109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 7185 MB memory:  -> device: 2, name: Tesla P100-PCIE-12GB, pci bus id: 0000:d8:00.0, compute capability: 6.0
# DEBUG:tensorflow:Layer LSTM_FT_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer LSTM_FT_2 will use cuDNN kernels when running on GPU.
# Fold: 1
# Epoch 1/100
# 2024-03-11 08:42:24.086850: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 32/32 [==============================] - 9s 251ms/step - loss: 0.3670 - accuracy: 0.8452 - val_loss: 0.2174 - val_accuracy: 0.9378
# Epoch 2/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.6762 - accuracy: 0.7611 - val_loss: 0.6582 - val_accuracy: 0.5244
# Epoch 3/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.5684 - accuracy: 0.6944 - val_loss: 0.4827 - val_accuracy: 0.7822
# Epoch 4/100
# 32/32 [==============================] - 7s 232ms/step - loss: 0.3205 - accuracy: 0.8843 - val_loss: 0.2701 - val_accuracy: 0.9156
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2701 - accuracy: 0.9156
# Fold: 2
# Epoch 1/100
# 32/32 [==============================] - 8s 254ms/step - loss: 0.2299 - accuracy: 0.9144 - val_loss: 0.1481 - val_accuracy: 0.9511
# Epoch 2/100
# 32/32 [==============================] - 7s 234ms/step - loss: 0.1600 - accuracy: 0.9471 - val_loss: 0.1785 - val_accuracy: 0.9333
# Epoch 3/100
# 32/32 [==============================] - 8s 243ms/step - loss: 0.1305 - accuracy: 0.9629 - val_loss: 0.1182 - val_accuracy: 0.9600
# Epoch 4/100
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0906 - accuracy: 0.9723 - val_loss: 0.1370 - val_accuracy: 0.9556
# Epoch 5/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0820 - accuracy: 0.9797 - val_loss: 0.1518 - val_accuracy: 0.9511
# Epoch 6/100
# 32/32 [==============================] - 8s 250ms/step - loss: 0.0694 - accuracy: 0.9827 - val_loss: 0.1079 - val_accuracy: 0.9600
# Epoch 7/100
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0695 - accuracy: 0.9807 - val_loss: 0.1233 - val_accuracy: 0.9644
# Epoch 8/100
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0535 - accuracy: 0.9862 - val_loss: 0.1293 - val_accuracy: 0.9556
# Epoch 9/100
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0499 - accuracy: 0.9881 - val_loss: 0.1129 - val_accuracy: 0.9689
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1129 - accuracy: 0.9689
# Fold: 3
# Epoch 1/100
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0549 - accuracy: 0.9857 - val_loss: 0.0421 - val_accuracy: 0.9911
# Epoch 2/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0522 - accuracy: 0.9871 - val_loss: 0.0456 - val_accuracy: 0.9911
# Epoch 3/100
# 32/32 [==============================] - 7s 225ms/step - loss: 0.0743 - accuracy: 0.9787 - val_loss: 0.0763 - val_accuracy: 0.9822
# Epoch 4/100
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0539 - accuracy: 0.9847 - val_loss: 0.0446 - val_accuracy: 0.9911
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0446 - accuracy: 0.9911
# Fold: 4
# Epoch 1/100
# 32/32 [==============================] - 8s 256ms/step - loss: 0.0430 - accuracy: 0.9891 - val_loss: 0.0281 - val_accuracy: 0.9911
# Epoch 2/100
# 32/32 [==============================] - 8s 252ms/step - loss: 0.0359 - accuracy: 0.9926 - val_loss: 0.0237 - val_accuracy: 0.9911
# Epoch 3/100
# 32/32 [==============================] - 8s 252ms/step - loss: 0.0315 - accuracy: 0.9931 - val_loss: 0.0199 - val_accuracy: 0.9911
# Epoch 4/100
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0272 - accuracy: 0.9941 - val_loss: 0.0183 - val_accuracy: 0.9911
# Epoch 5/100
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0266 - accuracy: 0.9936 - val_loss: 0.0205 - val_accuracy: 0.9956
# Epoch 6/100
# 32/32 [==============================] - 8s 253ms/step - loss: 0.0293 - accuracy: 0.9916 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0289 - accuracy: 0.9916 - val_loss: 0.0784 - val_accuracy: 0.9733
# Epoch 8/100
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0554 - accuracy: 0.9822 - val_loss: 0.0294 - val_accuracy: 0.9867
# Epoch 9/100
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0295 - accuracy: 0.9911 - val_loss: 0.0214 - val_accuracy: 0.9956
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0214 - accuracy: 0.9956
# Fold: 5
# Epoch 1/100
# 32/32 [==============================] - 8s 253ms/step - loss: 0.0187 - accuracy: 0.9951 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 [==============================] - 8s 249ms/step - loss: 0.0102 - accuracy: 0.9990 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 [==============================] - 8s 253ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 [==============================] - 8s 252ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 [==============================] - 8s 251ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 [==============================] - 8s 251ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 [==============================] - 8s 254ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.0029 - val_accuracy: 1.0000
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0029 - accuracy: 1.0000
# Fold: 6
# Epoch 1/100
# 32/32 [==============================] - 8s 249ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 7.2201e-04 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 [==============================] - 8s 247ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 6.8725e-04 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 [==============================] - 8s 249ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 6.4289e-04 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 5.8253e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 [==============================] - 8s 247ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 5.5818e-04 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 [==============================] - 8s 249ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 5.1131e-04 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 [==============================] - 8s 249ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 4.7460e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 [==============================] - 8s 249ms/step - loss: 8.6032e-04 - accuracy: 1.0000 - val_loss: 4.3517e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 [==============================] - 8s 249ms/step - loss: 7.1257e-04 - accuracy: 1.0000 - val_loss: 3.9384e-04 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 [==============================] - 8s 248ms/step - loss: 6.0881e-04 - accuracy: 1.0000 - val_loss: 3.6243e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 [==============================] - 8s 250ms/step - loss: 5.4997e-04 - accuracy: 1.0000 - val_loss: 3.3520e-04 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.7745e-04 - accuracy: 1.0000 - val_loss: 3.1323e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.4927e-04 - accuracy: 1.0000 - val_loss: 2.9988e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.0194e-04 - accuracy: 1.0000 - val_loss: 2.7835e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.6909e-04 - accuracy: 1.0000 - val_loss: 2.6253e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.4280e-04 - accuracy: 1.0000 - val_loss: 2.4913e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 32/32 [==============================] - 8s 245ms/step - loss: 3.2151e-04 - accuracy: 1.0000 - val_loss: 2.3759e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 32/32 [==============================] - 8s 249ms/step - loss: 3.0080e-04 - accuracy: 1.0000 - val_loss: 2.2705e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.8412e-04 - accuracy: 1.0000 - val_loss: 2.1710e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.7002e-04 - accuracy: 1.0000 - val_loss: 2.0811e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 [==============================] - 8s 251ms/step - loss: 2.5706e-04 - accuracy: 1.0000 - val_loss: 2.0026e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.4529e-04 - accuracy: 1.0000 - val_loss: 1.9297e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.3314e-04 - accuracy: 1.0000 - val_loss: 1.8500e-04 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 8s 247ms/step - loss: 2.2327e-04 - accuracy: 1.0000 - val_loss: 1.7789e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.1451e-04 - accuracy: 1.0000 - val_loss: 1.7192e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.0543e-04 - accuracy: 1.0000 - val_loss: 1.6608e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.9773e-04 - accuracy: 1.0000 - val_loss: 1.6076e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.9050e-04 - accuracy: 1.0000 - val_loss: 1.5564e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.8386e-04 - accuracy: 1.0000 - val_loss: 1.5090e-04 - val_accuracy: 1.0000
# Epoch 30/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.7690e-04 - accuracy: 1.0000 - val_loss: 1.4552e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 32/32 [==============================] - 8s 247ms/step - loss: 1.6843e-04 - accuracy: 1.0000 - val_loss: 1.4077e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 32/32 [==============================] - 8s 247ms/step - loss: 1.6107e-04 - accuracy: 1.0000 - val_loss: 1.3685e-04 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.5607e-04 - accuracy: 1.0000 - val_loss: 1.3276e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.5092e-04 - accuracy: 1.0000 - val_loss: 1.2887e-04 - val_accuracy: 1.0000
# Epoch 35/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.4625e-04 - accuracy: 1.0000 - val_loss: 1.2532e-04 - val_accuracy: 1.0000
# Epoch 36/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.4183e-04 - accuracy: 1.0000 - val_loss: 1.2198e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 32/32 [==============================] - 8s 248ms/step - loss: 1.3706e-04 - accuracy: 1.0000 - val_loss: 1.1867e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.3298e-04 - accuracy: 1.0000 - val_loss: 1.1543e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.2875e-04 - accuracy: 1.0000 - val_loss: 1.1247e-04 - val_accuracy: 1.0000
# Epoch 40/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.2506e-04 - accuracy: 1.0000 - val_loss: 1.0964e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 32/32 [==============================] - 7s 232ms/step - loss: 2.4904e-04 - accuracy: 1.0000 - val_loss: 1.1727e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 32/32 [==============================] - 7s 234ms/step - loss: 1.3833e-04 - accuracy: 1.0000 - val_loss: 1.1855e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 32/32 [==============================] - 7s 233ms/step - loss: 1.8065e-04 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9956
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0193 - accuracy: 0.9956
# Fold: 7
# Epoch 1/100
# 32/32 [==============================] - 8s 254ms/step - loss: 0.1249 - accuracy: 0.9634 - val_loss: 0.0865 - val_accuracy: 0.9689
# Epoch 2/100
# 32/32 [==============================] - 8s 235ms/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.0868 - val_accuracy: 0.9778
# Epoch 3/100
# 32/32 [==============================] - 8s 250ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.0853 - val_accuracy: 0.9733
# Epoch 4/100
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0123 - accuracy: 0.9975 - val_loss: 0.0907 - val_accuracy: 0.9733
# Epoch 5/100
# 32/32 [==============================] - 8s 250ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0712 - val_accuracy: 0.9822
# Epoch 6/100
# 32/32 [==============================] - 8s 235ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0772 - val_accuracy: 0.9733
# Epoch 7/100
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0781 - val_accuracy: 0.9733
# Epoch 8/100
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9689
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0976 - accuracy: 0.9689
# Fold: 8
# Epoch 1/100
# 32/32 [==============================] - 8s 251ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.0149 - val_accuracy: 0.9955
# Epoch 2/100
# 32/32 [==============================] - 8s 249ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.0066 - val_accuracy: 0.9955
# Epoch 3/100
# 32/32 [==============================] - 8s 253ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0066 - val_accuracy: 0.9955
# Epoch 4/100
# 32/32 [==============================] - 8s 235ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0148 - val_accuracy: 0.9955
# Epoch 5/100
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9955
# Epoch 6/100
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0220 - val_accuracy: 0.9955
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0220 - accuracy: 0.9955
# Fold: 9
# Epoch 1/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 7.3607e-04 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 [==============================] - 8s 250ms/step - loss: 9.7858e-04 - accuracy: 1.0000 - val_loss: 7.2435e-04 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 [==============================] - 8s 249ms/step - loss: 5.9939e-04 - accuracy: 1.0000 - val_loss: 6.8718e-04 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.8394e-04 - accuracy: 1.0000 - val_loss: 6.1971e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 [==============================] - 8s 254ms/step - loss: 4.0884e-04 - accuracy: 1.0000 - val_loss: 5.7911e-04 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 [==============================] - 8s 252ms/step - loss: 3.6225e-04 - accuracy: 1.0000 - val_loss: 5.4446e-04 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 [==============================] - 8s 245ms/step - loss: 3.2226e-04 - accuracy: 1.0000 - val_loss: 5.2434e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 [==============================] - 8s 247ms/step - loss: 2.9667e-04 - accuracy: 1.0000 - val_loss: 4.8756e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 [==============================] - 8s 247ms/step - loss: 2.6563e-04 - accuracy: 1.0000 - val_loss: 4.6478e-04 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.4482e-04 - accuracy: 1.0000 - val_loss: 4.4286e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 [==============================] - 8s 247ms/step - loss: 2.2622e-04 - accuracy: 1.0000 - val_loss: 4.3513e-04 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.1087e-04 - accuracy: 1.0000 - val_loss: 4.1674e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.9660e-04 - accuracy: 1.0000 - val_loss: 4.0443e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.8451e-04 - accuracy: 1.0000 - val_loss: 3.8366e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.7270e-04 - accuracy: 1.0000 - val_loss: 3.7876e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.6270e-04 - accuracy: 1.0000 - val_loss: 3.6547e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.5395e-04 - accuracy: 1.0000 - val_loss: 3.5358e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.4608e-04 - accuracy: 1.0000 - val_loss: 3.4827e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.3879e-04 - accuracy: 1.0000 - val_loss: 3.4026e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.3184e-04 - accuracy: 1.0000 - val_loss: 3.2747e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.2595e-04 - accuracy: 1.0000 - val_loss: 3.1784e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 32/32 [==============================] - 8s 248ms/step - loss: 1.2026e-04 - accuracy: 1.0000 - val_loss: 3.1755e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.1518e-04 - accuracy: 1.0000 - val_loss: 3.0808e-04 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 8s 246ms/step - loss: 1.1046e-04 - accuracy: 1.0000 - val_loss: 3.0397e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 32/32 [==============================] - 8s 245ms/step - loss: 1.0604e-04 - accuracy: 1.0000 - val_loss: 2.9715e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.0190e-04 - accuracy: 1.0000 - val_loss: 2.9535e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 [==============================] - 8s 249ms/step - loss: 9.8086e-05 - accuracy: 1.0000 - val_loss: 2.8837e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 32/32 [==============================] - 8s 250ms/step - loss: 9.4403e-05 - accuracy: 1.0000 - val_loss: 2.8660e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 32/32 [==============================] - 8s 249ms/step - loss: 9.1185e-05 - accuracy: 1.0000 - val_loss: 2.7993e-04 - val_accuracy: 1.0000
# Epoch 30/100
# 32/32 [==============================] - 8s 243ms/step - loss: 8.7871e-05 - accuracy: 1.0000 - val_loss: 2.7803e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 32/32 [==============================] - 8s 249ms/step - loss: 8.4837e-05 - accuracy: 1.0000 - val_loss: 2.7304e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 32/32 [==============================] - 8s 247ms/step - loss: 8.2047e-05 - accuracy: 1.0000 - val_loss: 2.6915e-04 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 [==============================] - 8s 251ms/step - loss: 7.9348e-05 - accuracy: 1.0000 - val_loss: 2.6091e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 32/32 [==============================] - 8s 249ms/step - loss: 7.6684e-05 - accuracy: 1.0000 - val_loss: 2.5617e-04 - val_accuracy: 1.0000
# Epoch 35/100
# 32/32 [==============================] - 8s 248ms/step - loss: 7.4294e-05 - accuracy: 1.0000 - val_loss: 2.5563e-04 - val_accuracy: 1.0000
# Epoch 36/100
# 32/32 [==============================] - 8s 247ms/step - loss: 7.1990e-05 - accuracy: 1.0000 - val_loss: 2.4754e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 32/32 [==============================] - 7s 228ms/step - loss: 6.9690e-05 - accuracy: 1.0000 - val_loss: 2.4836e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 32/32 [==============================] - 8s 249ms/step - loss: 6.7581e-05 - accuracy: 1.0000 - val_loss: 2.4598e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 32/32 [==============================] - 8s 249ms/step - loss: 6.5602e-05 - accuracy: 1.0000 - val_loss: 2.3853e-04 - val_accuracy: 1.0000
# Epoch 40/100
# 32/32 [==============================] - 8s 250ms/step - loss: 6.3632e-05 - accuracy: 1.0000 - val_loss: 2.3464e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 32/32 [==============================] - 8s 250ms/step - loss: 6.1773e-05 - accuracy: 1.0000 - val_loss: 2.3109e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 32/32 [==============================] - 8s 249ms/step - loss: 5.9978e-05 - accuracy: 1.0000 - val_loss: 2.2764e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 32/32 [==============================] - 8s 246ms/step - loss: 5.8271e-05 - accuracy: 1.0000 - val_loss: 2.2604e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 32/32 [==============================] - 8s 248ms/step - loss: 5.6677e-05 - accuracy: 1.0000 - val_loss: 2.2050e-04 - val_accuracy: 1.0000
# Epoch 45/100
# 32/32 [==============================] - 8s 249ms/step - loss: 5.5103e-05 - accuracy: 1.0000 - val_loss: 2.1688e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 32/32 [==============================] - 7s 234ms/step - loss: 5.3592e-05 - accuracy: 1.0000 - val_loss: 2.1701e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 32/32 [==============================] - 8s 246ms/step - loss: 5.2153e-05 - accuracy: 1.0000 - val_loss: 2.1058e-04 - val_accuracy: 1.0000
# Epoch 48/100
# 32/32 [==============================] - 7s 234ms/step - loss: 5.0764e-05 - accuracy: 1.0000 - val_loss: 2.1090e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 32/32 [==============================] - 8s 244ms/step - loss: 4.9551e-05 - accuracy: 1.0000 - val_loss: 2.0392e-04 - val_accuracy: 1.0000
# Epoch 50/100
# 32/32 [==============================] - 8s 245ms/step - loss: 4.8095e-05 - accuracy: 1.0000 - val_loss: 2.0134e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 32/32 [==============================] - 8s 248ms/step - loss: 4.6854e-05 - accuracy: 1.0000 - val_loss: 2.0012e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 32/32 [==============================] - 8s 248ms/step - loss: 4.5667e-05 - accuracy: 1.0000 - val_loss: 1.9561e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 32/32 [==============================] - 8s 248ms/step - loss: 4.4497e-05 - accuracy: 1.0000 - val_loss: 1.9420e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 32/32 [==============================] - 8s 246ms/step - loss: 4.3374e-05 - accuracy: 1.0000 - val_loss: 1.9330e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.2283e-05 - accuracy: 1.0000 - val_loss: 1.9092e-04 - val_accuracy: 1.0000
# Epoch 56/100
# 32/32 [==============================] - 8s 251ms/step - loss: 4.1256e-05 - accuracy: 1.0000 - val_loss: 1.8694e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 32/32 [==============================] - 8s 251ms/step - loss: 4.0230e-05 - accuracy: 1.0000 - val_loss: 1.8471e-04 - val_accuracy: 1.0000
# Epoch 58/100
# 32/32 [==============================] - 8s 248ms/step - loss: 3.9247e-05 - accuracy: 1.0000 - val_loss: 1.8098e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 32/32 [==============================] - 8s 248ms/step - loss: 3.8273e-05 - accuracy: 1.0000 - val_loss: 1.7968e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 32/32 [==============================] - 7s 234ms/step - loss: 3.7360e-05 - accuracy: 1.0000 - val_loss: 1.7996e-04 - val_accuracy: 1.0000
# Epoch 61/100
# 32/32 [==============================] - 8s 248ms/step - loss: 3.6489e-05 - accuracy: 1.0000 - val_loss: 1.7416e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.5580e-05 - accuracy: 1.0000 - val_loss: 1.7389e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 32/32 [==============================] - 8s 249ms/step - loss: 3.4789e-05 - accuracy: 1.0000 - val_loss: 1.7034e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 32/32 [==============================] - 8s 235ms/step - loss: 3.3911e-05 - accuracy: 1.0000 - val_loss: 1.7131e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 32/32 [==============================] - 8s 248ms/step - loss: 3.3130e-05 - accuracy: 1.0000 - val_loss: 1.6877e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 32/32 [==============================] - 8s 249ms/step - loss: 3.2371e-05 - accuracy: 1.0000 - val_loss: 1.6632e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 32/32 [==============================] - 8s 247ms/step - loss: 3.1607e-05 - accuracy: 1.0000 - val_loss: 1.6366e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 32/32 [==============================] - 8s 247ms/step - loss: 3.0870e-05 - accuracy: 1.0000 - val_loss: 1.6127e-04 - val_accuracy: 1.0000
# Epoch 69/100
# 32/32 [==============================] - 8s 249ms/step - loss: 3.0159e-05 - accuracy: 1.0000 - val_loss: 1.5930e-04 - val_accuracy: 1.0000
# Epoch 70/100
# 32/32 [==============================] - 8s 247ms/step - loss: 2.9471e-05 - accuracy: 1.0000 - val_loss: 1.5627e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 32/32 [==============================] - 7s 234ms/step - loss: 2.8793e-05 - accuracy: 1.0000 - val_loss: 1.5806e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 32/32 [==============================] - 8s 248ms/step - loss: 2.8153e-05 - accuracy: 1.0000 - val_loss: 1.5336e-04 - val_accuracy: 1.0000
# Epoch 73/100
# 32/32 [==============================] - 7s 232ms/step - loss: 2.7503e-05 - accuracy: 1.0000 - val_loss: 1.5360e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.6892e-05 - accuracy: 1.0000 - val_loss: 1.5055e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 32/32 [==============================] - 7s 233ms/step - loss: 2.6283e-05 - accuracy: 1.0000 - val_loss: 1.5093e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.5713e-05 - accuracy: 1.0000 - val_loss: 1.4759e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 32/32 [==============================] - 8s 246ms/step - loss: 2.5155e-05 - accuracy: 1.0000 - val_loss: 1.4503e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.4618e-05 - accuracy: 1.0000 - val_loss: 1.4471e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.4085e-05 - accuracy: 1.0000 - val_loss: 1.4287e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.3561e-05 - accuracy: 1.0000 - val_loss: 1.4282e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.3063e-05 - accuracy: 1.0000 - val_loss: 1.4011e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 32/32 [==============================] - 7s 234ms/step - loss: 2.2573e-05 - accuracy: 1.0000 - val_loss: 1.4068e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 32/32 [==============================] - 8s 248ms/step - loss: 2.2110e-05 - accuracy: 1.0000 - val_loss: 1.3864e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.1639e-05 - accuracy: 1.0000 - val_loss: 1.3616e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 32/32 [==============================] - 8s 248ms/step - loss: 2.1193e-05 - accuracy: 1.0000 - val_loss: 1.3542e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.0750e-05 - accuracy: 1.0000 - val_loss: 1.3431e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 32/32 [==============================] - 7s 233ms/step - loss: 2.0326e-05 - accuracy: 1.0000 - val_loss: 1.3466e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 32/32 [==============================] - 8s 245ms/step - loss: 1.9914e-05 - accuracy: 1.0000 - val_loss: 1.3382e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 32/32 [==============================] - 8s 248ms/step - loss: 1.9508e-05 - accuracy: 1.0000 - val_loss: 1.3162e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 32/32 [==============================] - 8s 245ms/step - loss: 1.9105e-05 - accuracy: 1.0000 - val_loss: 1.3075e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 32/32 [==============================] - 8s 247ms/step - loss: 1.8719e-05 - accuracy: 1.0000 - val_loss: 1.2764e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 32/32 [==============================] - 7s 234ms/step - loss: 1.8335e-05 - accuracy: 1.0000 - val_loss: 1.2801e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.7971e-05 - accuracy: 1.0000 - val_loss: 1.2738e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.7621e-05 - accuracy: 1.0000 - val_loss: 1.2565e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 32/32 [==============================] - 8s 245ms/step - loss: 1.7260e-05 - accuracy: 1.0000 - val_loss: 1.2417e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 32/32 [==============================] - 7s 234ms/step - loss: 1.6916e-05 - accuracy: 1.0000 - val_loss: 1.2550e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.6604e-05 - accuracy: 1.0000 - val_loss: 1.2306e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 32/32 [==============================] - 8s 235ms/step - loss: 1.6261e-05 - accuracy: 1.0000 - val_loss: 1.2331e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 32/32 [==============================] - 7s 234ms/step - loss: 1.5951e-05 - accuracy: 1.0000 - val_loss: 1.2445e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 32/32 [==============================] - 7s 234ms/step - loss: 1.5638e-05 - accuracy: 1.0000 - val_loss: 1.2951e-04 - val_accuracy: 1.0000
# 7/7 [==============================] - 1s 111ms/step - loss: 1.2951e-04 - accuracy: 1.0000
# Fold: 10
# Epoch 1/100
# 32/32 [==============================] - 8s 253ms/step - loss: 3.1239e-05 - accuracy: 1.0000 - val_loss: 1.0682e-05 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.1116e-05 - accuracy: 1.0000 - val_loss: 1.0309e-05 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 [==============================] - 8s 248ms/step - loss: 1.7976e-05 - accuracy: 1.0000 - val_loss: 1.0094e-05 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.8329e-05 - accuracy: 1.0000 - val_loss: 1.0088e-05 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 [==============================] - 8s 247ms/step - loss: 1.7122e-05 - accuracy: 1.0000 - val_loss: 9.9285e-06 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.6507e-05 - accuracy: 1.0000 - val_loss: 9.7447e-06 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.5855e-05 - accuracy: 1.0000 - val_loss: 9.5590e-06 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.5404e-05 - accuracy: 1.0000 - val_loss: 9.3744e-06 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.4991e-05 - accuracy: 1.0000 - val_loss: 9.1987e-06 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.4601e-05 - accuracy: 1.0000 - val_loss: 9.0181e-06 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.4222e-05 - accuracy: 1.0000 - val_loss: 8.8364e-06 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.3878e-05 - accuracy: 1.0000 - val_loss: 8.6681e-06 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.3535e-05 - accuracy: 1.0000 - val_loss: 8.5057e-06 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.3230e-05 - accuracy: 1.0000 - val_loss: 8.3521e-06 - val_accuracy: 1.0000
# Epoch 15/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.2894e-05 - accuracy: 1.0000 - val_loss: 8.1924e-06 - val_accuracy: 1.0000
# Epoch 16/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.2597e-05 - accuracy: 1.0000 - val_loss: 8.0392e-06 - val_accuracy: 1.0000
# Epoch 17/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.2313e-05 - accuracy: 1.0000 - val_loss: 7.8928e-06 - val_accuracy: 1.0000
# Epoch 18/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.2041e-05 - accuracy: 1.0000 - val_loss: 7.7476e-06 - val_accuracy: 1.0000
# Epoch 19/100
# 32/32 [==============================] - 8s 250ms/step - loss: 1.1779e-05 - accuracy: 1.0000 - val_loss: 7.6078e-06 - val_accuracy: 1.0000
# Epoch 20/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.1526e-05 - accuracy: 1.0000 - val_loss: 7.4664e-06 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 [==============================] - 8s 248ms/step - loss: 1.1287e-05 - accuracy: 1.0000 - val_loss: 7.3307e-06 - val_accuracy: 1.0000
# Epoch 22/100
# 32/32 [==============================] - 8s 249ms/step - loss: 1.1043e-05 - accuracy: 1.0000 - val_loss: 7.1961e-06 - val_accuracy: 1.0000
# Epoch 23/100
# 32/32 [==============================] - 8s 247ms/step - loss: 1.0818e-05 - accuracy: 1.0000 - val_loss: 7.0656e-06 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.0600e-05 - accuracy: 1.0000 - val_loss: 6.9387e-06 - val_accuracy: 1.0000
# Epoch 25/100
# 32/32 [==============================] - 8s 251ms/step - loss: 1.0378e-05 - accuracy: 1.0000 - val_loss: 6.8132e-06 - val_accuracy: 1.0000
# Epoch 26/100
# 32/32 [==============================] - 8s 243ms/step - loss: 1.0168e-05 - accuracy: 1.0000 - val_loss: 6.6920e-06 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 [==============================] - 8s 246ms/step - loss: 9.9701e-06 - accuracy: 1.0000 - val_loss: 6.5702e-06 - val_accuracy: 1.0000
# Epoch 28/100
# 32/32 [==============================] - 8s 250ms/step - loss: 9.7662e-06 - accuracy: 1.0000 - val_loss: 6.4524e-06 - val_accuracy: 1.0000
# Epoch 29/100
# 32/32 [==============================] - 8s 249ms/step - loss: 9.5808e-06 - accuracy: 1.0000 - val_loss: 6.3391e-06 - val_accuracy: 1.0000
# Epoch 30/100
# 32/32 [==============================] - 8s 250ms/step - loss: 9.3784e-06 - accuracy: 1.0000 - val_loss: 6.2276e-06 - val_accuracy: 1.0000
# Epoch 31/100
# 32/32 [==============================] - 8s 251ms/step - loss: 9.1962e-06 - accuracy: 1.0000 - val_loss: 6.1185e-06 - val_accuracy: 1.0000
# Epoch 32/100
# 32/32 [==============================] - 8s 250ms/step - loss: 9.0203e-06 - accuracy: 1.0000 - val_loss: 6.0090e-06 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 [==============================] - 8s 250ms/step - loss: 8.8493e-06 - accuracy: 1.0000 - val_loss: 5.9015e-06 - val_accuracy: 1.0000
# Epoch 34/100
# 32/32 [==============================] - 8s 251ms/step - loss: 8.6811e-06 - accuracy: 1.0000 - val_loss: 5.7973e-06 - val_accuracy: 1.0000
# Epoch 35/100
# 32/32 [==============================] - 8s 252ms/step - loss: 8.5177e-06 - accuracy: 1.0000 - val_loss: 5.6963e-06 - val_accuracy: 1.0000
# Epoch 36/100
# 32/32 [==============================] - 8s 250ms/step - loss: 8.3541e-06 - accuracy: 1.0000 - val_loss: 5.5971e-06 - val_accuracy: 1.0000
# Epoch 37/100
# 32/32 [==============================] - 8s 249ms/step - loss: 8.1941e-06 - accuracy: 1.0000 - val_loss: 5.4998e-06 - val_accuracy: 1.0000
# Epoch 38/100
# 32/32 [==============================] - 8s 248ms/step - loss: 8.0429e-06 - accuracy: 1.0000 - val_loss: 5.4027e-06 - val_accuracy: 1.0000
# Epoch 39/100
# 32/32 [==============================] - 8s 250ms/step - loss: 7.8929e-06 - accuracy: 1.0000 - val_loss: 5.3098e-06 - val_accuracy: 1.0000
# Epoch 40/100
# 32/32 [==============================] - 8s 251ms/step - loss: 7.7461e-06 - accuracy: 1.0000 - val_loss: 5.2163e-06 - val_accuracy: 1.0000
# Epoch 41/100
# 32/32 [==============================] - 8s 247ms/step - loss: 7.6003e-06 - accuracy: 1.0000 - val_loss: 5.1253e-06 - val_accuracy: 1.0000
# Epoch 42/100
# 32/32 [==============================] - 8s 250ms/step - loss: 7.4623e-06 - accuracy: 1.0000 - val_loss: 5.0373e-06 - val_accuracy: 1.0000
# Epoch 43/100
# 32/32 [==============================] - 8s 250ms/step - loss: 7.3249e-06 - accuracy: 1.0000 - val_loss: 4.9494e-06 - val_accuracy: 1.0000
# Epoch 44/100
# 32/32 [==============================] - 8s 249ms/step - loss: 7.1900e-06 - accuracy: 1.0000 - val_loss: 4.8650e-06 - val_accuracy: 1.0000
# Epoch 45/100
# 32/32 [==============================] - 8s 249ms/step - loss: 7.0595e-06 - accuracy: 1.0000 - val_loss: 4.7826e-06 - val_accuracy: 1.0000
# Epoch 46/100
# 32/32 [==============================] - 8s 246ms/step - loss: 6.9341e-06 - accuracy: 1.0000 - val_loss: 4.7016e-06 - val_accuracy: 1.0000
# Epoch 47/100
# 32/32 [==============================] - 8s 248ms/step - loss: 6.8041e-06 - accuracy: 1.0000 - val_loss: 4.6223e-06 - val_accuracy: 1.0000
# Epoch 48/100
# 32/32 [==============================] - 8s 251ms/step - loss: 6.6811e-06 - accuracy: 1.0000 - val_loss: 4.5424e-06 - val_accuracy: 1.0000
# Epoch 49/100
# 32/32 [==============================] - 8s 250ms/step - loss: 6.5632e-06 - accuracy: 1.0000 - val_loss: 4.4648e-06 - val_accuracy: 1.0000
# Epoch 50/100
# 32/32 [==============================] - 8s 249ms/step - loss: 6.4441e-06 - accuracy: 1.0000 - val_loss: 4.3887e-06 - val_accuracy: 1.0000
# Epoch 51/100
# 32/32 [==============================] - 8s 249ms/step - loss: 6.3306e-06 - accuracy: 1.0000 - val_loss: 4.3149e-06 - val_accuracy: 1.0000
# Epoch 52/100
# 32/32 [==============================] - 8s 248ms/step - loss: 6.2154e-06 - accuracy: 1.0000 - val_loss: 4.2420e-06 - val_accuracy: 1.0000
# Epoch 53/100
# 32/32 [==============================] - 8s 250ms/step - loss: 6.1034e-06 - accuracy: 1.0000 - val_loss: 4.1704e-06 - val_accuracy: 1.0000
# Epoch 54/100
# 32/32 [==============================] - 8s 248ms/step - loss: 5.9957e-06 - accuracy: 1.0000 - val_loss: 4.0999e-06 - val_accuracy: 1.0000
# Epoch 55/100
# 32/32 [==============================] - 8s 250ms/step - loss: 5.8876e-06 - accuracy: 1.0000 - val_loss: 4.0314e-06 - val_accuracy: 1.0000
# Epoch 56/100
# 32/32 [==============================] - 8s 251ms/step - loss: 5.7848e-06 - accuracy: 1.0000 - val_loss: 3.9617e-06 - val_accuracy: 1.0000
# Epoch 57/100
# 32/32 [==============================] - 8s 250ms/step - loss: 5.6832e-06 - accuracy: 1.0000 - val_loss: 3.8964e-06 - val_accuracy: 1.0000
# Epoch 58/100
# 32/32 [==============================] - 8s 247ms/step - loss: 5.5825e-06 - accuracy: 1.0000 - val_loss: 3.8326e-06 - val_accuracy: 1.0000
# Epoch 59/100
# 32/32 [==============================] - 8s 251ms/step - loss: 5.4861e-06 - accuracy: 1.0000 - val_loss: 3.7672e-06 - val_accuracy: 1.0000
# Epoch 60/100
# 32/32 [==============================] - 8s 250ms/step - loss: 5.3901e-06 - accuracy: 1.0000 - val_loss: 3.7039e-06 - val_accuracy: 1.0000
# Epoch 61/100
# 32/32 [==============================] - 8s 247ms/step - loss: 5.2971e-06 - accuracy: 1.0000 - val_loss: 3.6468e-06 - val_accuracy: 1.0000
# Epoch 62/100
# 32/32 [==============================] - 8s 250ms/step - loss: 5.2059e-06 - accuracy: 1.0000 - val_loss: 3.5800e-06 - val_accuracy: 1.0000
# Epoch 63/100
# 32/32 [==============================] - 8s 250ms/step - loss: 5.1134e-06 - accuracy: 1.0000 - val_loss: 3.5213e-06 - val_accuracy: 1.0000
# Epoch 64/100
# 32/32 [==============================] - 8s 251ms/step - loss: 5.0251e-06 - accuracy: 1.0000 - val_loss: 3.4646e-06 - val_accuracy: 1.0000
# Epoch 65/100
# 32/32 [==============================] - 8s 246ms/step - loss: 4.9383e-06 - accuracy: 1.0000 - val_loss: 3.4067e-06 - val_accuracy: 1.0000
# Epoch 66/100
# 32/32 [==============================] - 8s 251ms/step - loss: 4.8516e-06 - accuracy: 1.0000 - val_loss: 3.3522e-06 - val_accuracy: 1.0000
# Epoch 67/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.7701e-06 - accuracy: 1.0000 - val_loss: 3.2954e-06 - val_accuracy: 1.0000
# Epoch 68/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.6865e-06 - accuracy: 1.0000 - val_loss: 3.2420e-06 - val_accuracy: 1.0000
# Epoch 69/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.6064e-06 - accuracy: 1.0000 - val_loss: 3.1870e-06 - val_accuracy: 1.0000
# Epoch 70/100
# 32/32 [==============================] - 8s 251ms/step - loss: 4.5305e-06 - accuracy: 1.0000 - val_loss: 3.1335e-06 - val_accuracy: 1.0000
# Epoch 71/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.4514e-06 - accuracy: 1.0000 - val_loss: 3.0818e-06 - val_accuracy: 1.0000
# Epoch 72/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.3753e-06 - accuracy: 1.0000 - val_loss: 3.0314e-06 - val_accuracy: 1.0000
# Epoch 73/100
# 32/32 [==============================] - 8s 251ms/step - loss: 4.2981e-06 - accuracy: 1.0000 - val_loss: 2.9863e-06 - val_accuracy: 1.0000
# Epoch 74/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.2268e-06 - accuracy: 1.0000 - val_loss: 2.9306e-06 - val_accuracy: 1.0000
# Epoch 75/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.1569e-06 - accuracy: 1.0000 - val_loss: 2.8842e-06 - val_accuracy: 1.0000
# Epoch 76/100
# 32/32 [==============================] - 8s 250ms/step - loss: 4.0816e-06 - accuracy: 1.0000 - val_loss: 2.8371e-06 - val_accuracy: 1.0000
# Epoch 77/100
# 32/32 [==============================] - 8s 249ms/step - loss: 4.0132e-06 - accuracy: 1.0000 - val_loss: 2.7923e-06 - val_accuracy: 1.0000
# Epoch 78/100
# 32/32 [==============================] - 8s 246ms/step - loss: 3.9475e-06 - accuracy: 1.0000 - val_loss: 2.7421e-06 - val_accuracy: 1.0000
# Epoch 79/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.8831e-06 - accuracy: 1.0000 - val_loss: 2.6993e-06 - val_accuracy: 1.0000
# Epoch 80/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.8140e-06 - accuracy: 1.0000 - val_loss: 2.6567e-06 - val_accuracy: 1.0000
# Epoch 81/100
# 32/32 [==============================] - 8s 249ms/step - loss: 3.7500e-06 - accuracy: 1.0000 - val_loss: 2.6120e-06 - val_accuracy: 1.0000
# Epoch 82/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.6882e-06 - accuracy: 1.0000 - val_loss: 2.5686e-06 - val_accuracy: 1.0000
# Epoch 83/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.6245e-06 - accuracy: 1.0000 - val_loss: 2.5293e-06 - val_accuracy: 1.0000
# Epoch 84/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.5632e-06 - accuracy: 1.0000 - val_loss: 2.4870e-06 - val_accuracy: 1.0000
# Epoch 85/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.5035e-06 - accuracy: 1.0000 - val_loss: 2.4474e-06 - val_accuracy: 1.0000
# Epoch 86/100
# 32/32 [==============================] - 8s 244ms/step - loss: 3.4453e-06 - accuracy: 1.0000 - val_loss: 2.4054e-06 - val_accuracy: 1.0000
# Epoch 87/100
# 32/32 [==============================] - 8s 249ms/step - loss: 3.3882e-06 - accuracy: 1.0000 - val_loss: 2.3687e-06 - val_accuracy: 1.0000
# Epoch 88/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.3306e-06 - accuracy: 1.0000 - val_loss: 2.3303e-06 - val_accuracy: 1.0000
# Epoch 89/100
# 32/32 [==============================] - 8s 248ms/step - loss: 3.2797e-06 - accuracy: 1.0000 - val_loss: 2.2891e-06 - val_accuracy: 1.0000
# Epoch 90/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.2193e-06 - accuracy: 1.0000 - val_loss: 2.2541e-06 - val_accuracy: 1.0000
# Epoch 91/100
# 32/32 [==============================] - 8s 251ms/step - loss: 3.1641e-06 - accuracy: 1.0000 - val_loss: 2.2180e-06 - val_accuracy: 1.0000
# Epoch 92/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.1111e-06 - accuracy: 1.0000 - val_loss: 2.1822e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 32/32 [==============================] - 8s 250ms/step - loss: 3.0589e-06 - accuracy: 1.0000 - val_loss: 2.1472e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 32/32 [==============================] - 8s 248ms/step - loss: 3.0084e-06 - accuracy: 1.0000 - val_loss: 2.1128e-06 - val_accuracy: 1.0000
# Epoch 95/100
# 32/32 [==============================] - 8s 245ms/step - loss: 2.9607e-06 - accuracy: 1.0000 - val_loss: 2.0761e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.9122e-06 - accuracy: 1.0000 - val_loss: 2.0435e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 32/32 [==============================] - 8s 244ms/step - loss: 2.8608e-06 - accuracy: 1.0000 - val_loss: 2.0114e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.8168e-06 - accuracy: 1.0000 - val_loss: 1.9783e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 32/32 [==============================] - 8s 250ms/step - loss: 2.7700e-06 - accuracy: 1.0000 - val_loss: 1.9453e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 32/32 [==============================] - 8s 249ms/step - loss: 2.7217e-06 - accuracy: 1.0000 - val_loss: 1.9151e-06 - val_accuracy: 1.0000
# 7/7 [==============================] - 1s 109ms/step - loss: 1.9151e-06 - accuracy: 1.0000
# Accuracy for Fold 1: 0.9155555367469788
# Accuracy for Fold 2: 0.9688888788223267
# Accuracy for Fold 3: 0.9911110997200012
# Accuracy for Fold 4: 0.995555579662323
# Accuracy for Fold 5: 1.0
# Accuracy for Fold 6: 0.995555579662323
# Accuracy for Fold 7: 0.9688888788223267
# Accuracy for Fold 8: 0.9955357313156128
# Accuracy for Fold 9: 1.0
# Accuracy for Fold 10: 1.0
# Average Accuracy: 0.9831091284751892
# 31/31 [==============================] - 3s 96ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97       462
#          1.0       0.98      0.97      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[451  11]
#  [ 14 487]]
# 44/44 [==============================] - 4s 93ms/step

# %%
expected_first_692 = [1] * 692
expected_last_685 = [0] * 685

matches_first_692 = sum(1 for a, e in zip(test_pred[:692], expected_first_692) if a == e)
matches_last_685 = sum(1 for a, e in zip(test_pred[692:], expected_last_685) if a == e)

accuracy_first_692 = (matches_first_692 / len(expected_first_692)) * 100
accuracy_last_685 = (matches_last_685 / len(expected_last_685)) * 100

total_matches = matches_first_692 + matches_last_685
total_accuracy = (total_matches / len(test_pred)) * 100

print(f"Accuracy for the first 692 elements: {accuracy_first_692:.2f}%")
print(f"Accuracy for the last 685 elements: {accuracy_last_685:.2f}%")
print(f"Total Accuracy: {total_accuracy:.2f}%")
# Out:
# Accuracy for the first 692 elements: 92.49%
# Accuracy for the last 685 elements: 96.79%
# Total Accuracy: 94.63%

# %% [markdown]
# # HyperParameter Optimization Word2Vec

# %%
import os
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle
from gensim.models import Word2Vec

import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from scikeras.wrappers import KerasClassifier


######################################################################################
import os

def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list

def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):

    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index

X_train, X_test, y_train, y_test, test_codes = load_data()



# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

########################################################################################

def load_embedding_model(embedding_dim):
    file_path = f'/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_{embedding_dim}_model.pkl'

    with open(file_path, 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(embedding_dim, vocab_size=359414, max_sequence_length= X_train_padded.shape[1]):
    embedding_model = load_embedding_model(embedding_dim)

    # Create the embedding matrix
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]

    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(LSTM(units=128))
    model.add(Dense(units=1, activation='sigmoid'))
    return model



seed = 7
tf.random.set_seed(seed)


model = KerasClassifier(model=create_model, loss='binary_crossentropy', metrics=['accuracy'], epochs=50, verbose=0)
optimizers = ['Adam']

# Define a list of embedding dimensions to search through
embedding_dimensions = [150]
learn_rate = [0.001]
momentum = [0.0, 0.3, 0.6, 0.8]
param_grid = dict(model__embedding_dim=embedding_dimensions, optimizer=optimizers, optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_train_padded,y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" %(mean, stdev, param))
# Out:
# 2024-02-08 04:23:47.508961: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 04:23:47.667982: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-08 04:23:48.398821: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shaurya/miniconda3/envs/tf/lib/
# 2024-02-08 04:23:48.398928: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shaurya/miniconda3/envs/tf/lib/
# 2024-02-08 04:23:48.398936: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # Hyperparameter Optimisation Fasttext

# %%
import os
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle
from gensim.models import Word2Vec

import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from scikeras.wrappers import KerasClassifier


######################################################################################
import os

def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list

def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):

    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index

X_train, X_test, y_train, y_test, test_codes = load_data()



# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)

########################################################################################

def load_embedding_model(embedding_dim):
    file_path = f'/home/shaurya/BTP/1/Outputs/Embedding Models/FastText/fasttext_{embedding_dim}_model.pkl'

    with open(file_path, 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model

def create_model(embedding_dim, vocab_size=359414, max_sequence_length= X_train_padded.shape[1]):
    embedding_model = load_embedding_model(embedding_dim)

    # Create the embedding matrix
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]

    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(LSTM(units=128))
    model.add(Dense(units=1, activation='sigmoid'))
    return model



seed = 7
tf.random.set_seed(seed)


model = KerasClassifier(model=create_model, loss='binary_crossentropy', metrics=['accuracy'], epochs=50, verbose=0)
optimizer = ['SGD', 'RMSprop', 'Adam']

# Define a list of embedding dimensions to search through
embedding_dimensions = [50, 100, 150,200]
# embedding_matrices = [embedding_matrix]
param_grid = {'model__embedding_dim': embedding_dimensions, 'optimizer':optimizer}

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_train_padded,y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" %(mean, stdev, param))
# Out:
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# 2023-10-09 08:31:07.513290: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-09 08:31:11.313934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3757 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1b:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.314811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 24 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1d:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.315721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 10405 MB memory:  -> device: 2, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:1e:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.316696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 7090 MB memory:  -> device: 3, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3d:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.317552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 8022 MB memory:  -> device: 4, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3f:00.0, compute capability: 6.1
# 2023-10-09 08:31:11.318429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 10405 MB memory:  -> device: 5, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:41:00.0, compute capability: 6.1
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# 2023-10-09 08:31:12.589718: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# DEBUG:tensorflow:Layer lstm_2 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_6 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_7 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_8 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_9 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_10 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_11 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_12 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_13 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_14 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_15 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_16 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_17 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_18 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_19 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_20 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_21 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_22 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_23 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_24 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_25 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_26 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_27 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_28 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_29 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_30 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_31 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_32 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_33 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_34 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_35 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_36 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_37 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_38 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_39 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_40 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_41 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_42 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_43 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_44 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_45 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_46 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_47 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_48 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_49 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_50 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_51 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_52 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_53 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_54 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_55 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_56 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_57 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_58 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_59 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_60 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_61 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_62 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_63 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_64 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_65 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_66 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_67 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_68 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_69 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_70 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_71 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_72 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_73 will use cuDNN kernels when running on GPU.
# Best: 0.960437 using {'model__embedding_dim': 50, 'optimizer': 'Adam'}
# 0.953161 (0.006135) with: {'model__embedding_dim': 50, 'optimizer': 'SGD'}
# 0.959527 (0.002319) with: {'model__embedding_dim': 50, 'optimizer': 'RMSprop'}
# 0.960437 (0.003859) with: {'model__embedding_dim': 50, 'optimizer': 'Adam'}
# 0.950887 (0.005894) with: {'model__embedding_dim': 100, 'optimizer': 'SGD'}
# 0.959982 (0.006334) with: {'model__embedding_dim': 100, 'optimizer': 'RMSprop'}
# 0.957253 (0.005607) with: {'model__embedding_dim': 100, 'optimizer': 'Adam'}
# 0.952251 (0.004456) with: {'model__embedding_dim': 150, 'optimizer': 'SGD'}
# 0.956344 (0.007797) with: {'model__embedding_dim': 150, 'optimizer': 'RMSprop'}
# 0.959072 (0.008410) with: {'model__embedding_dim': 150, 'optimizer': 'Adam'}
# 0.950887 (0.004855) with: {'model__embedding_dim': 200, 'optimizer': 'SGD'}
# 0.960437 (0.005570) with: {'model__embedding_dim': 200, 'optimizer': 'RMSprop'}
# 0.956799 (0.005495) with: {'model__embedding_dim': 200, 'optimizer': 'Adam'}

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score, ConfusionMatrixDisplay
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='LSTM_W2V_EL'))
    model.add(LSTM(units=128, return_sequences=True, name='LSTM_W2V_1'))
    model.add(LSTM(units=128, name='LSTM_W2V_2'))
    model.add(Dense(units=1, activation='sigmoid', name='LSTM_W2V_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
  fold = 1
  accuracies = []

  for train_index, val_index in skf.split(X_train_padded, y_train):
    print(f"Fold: {fold}")
    fold += 1

    X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5"
    checkpoint = ModelCheckpoint(
        checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
    )

    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])

    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    _, accuracy = model.evaluate(X_val_fold, y_val_fold)
    accuracies.append(accuracy)

  return accuracies
    
def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    class_names = {0: "Non-vulnerable", 1: "Vulnerable"}  # Example mapping for binary classes
    labels = list(class_names.values())

    disp = ConfusionMatrixDisplay(confusion_matrix = confusion, display_labels = labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def load_all_models(i=0):
    all_models = list()

    folder_path = '/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec'
    if i == 0:
        model_files = [f for f in os.listdir(folder_path) if f.endswith('w2v.keras')]
    else:
        model_files = [f for f in os.listdir(folder_path) if f.endswith('ft.keras')]
    
    for filename in model_files:
        model_path = os.path.join(folder_path, filename)
        model = load_model(model_path)
        all_models.append(model)
        print(f'> Loaded {model_path}')

    return all_models

def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)


members = load_all_models(0)


for model in members:
    evaluate_model(X_test_padded, y_test, model)
# Out:
# 2024-03-19 02:45:25.050224: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 02:45:25.237330: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-19 02:45:26.058384: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-19 02:45:26.058548: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-19 02:45:26.058561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# DEBUG:tensorflow:Layer GRU_W2V will use cuDNN kernels when running on GPU.
# 2024-03-19 02:45:33.787018: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 02:45:36.309859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1326 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:3b:00.0, compute capability: 6.0
# 2024-03-19 02:45:36.311031: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6016 MB memory:  -> device: 1, name: Tesla P100-PCIE-12GB, pci bus id: 0000:af:00.0, compute capability: 6.0
# 2024-03-19 02:45:36.312028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 4724 MB memory:  -> device: 2, name: Tesla P100-PCIE-12GB, pci bus id: 0000:d8:00.0, compute capability: 6.0
# > Loaded /home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/GRU_w2v.keras
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# > Loaded /home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/BLSTM_w2v.keras
# DEBUG:tensorflow:Layer LSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer LSTM_W2V_2 will use cuDNN kernels when running on GPU.
# > Loaded /home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/LSTM_w2v.keras
#  2/31 [>.............................] - ETA: 1s
# 2024-03-19 02:45:42.119131: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 31/31 [==============================] - 2s 49ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97       462
#          1.0       0.99      0.96      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[456   6]
#  [ 21 480]]
# 31/31 [==============================] - 6s 178ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96       462
#          1.0       0.97      0.96      0.96       501
#
#     accuracy                           0.96       963
#    macro avg       0.96      0.96      0.96       963
# weighted avg       0.96      0.96      0.96       963
#
# Confusion Matrix:
# [[447  15]
#  [ 20 481]]
# 31/31 [==============================] - 3s 96ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       462
#          1.0       0.97      0.97      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[449  13]
#  [ 14 487]]

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score, ConfusionMatrixDisplay
import tensorflow as tf
tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


# Function to load files from a directory
def load_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".c"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as file_content:
                    file_text = file_content.read()
                file_list.append(file_text)
    return file_list
# Load training and test files for vulnerable and non-vulnerable classes
def load_data():
    dataset_dir = '/home/shaurya/BTP/1/Dataset/Code/C'
    vulnerable_dir = os.path.join(dataset_dir, 'Vulnerable')
    non_vulnerable_dir = os.path.join(dataset_dir, 'Non_vulnerable')

    vulnerable_train_files = load_files(os.path.join(vulnerable_dir, 'TRAIN'))
    vulnerable_test_files = load_files(os.path.join(vulnerable_dir, 'TEST'))
    non_vulnerable_train_files = load_files(os.path.join(non_vulnerable_dir, 'TRAIN'))
    non_vulnerable_test_files = load_files(os.path.join(non_vulnerable_dir, 'TEST'))

    train_codes = vulnerable_train_files + non_vulnerable_train_files
    test_codes = vulnerable_test_files + non_vulnerable_test_files

    labels = np.concatenate((np.ones(len(vulnerable_train_files)), np.zeros(len(non_vulnerable_train_files))), axis=0)

    X_train, X_test, y_train, y_test = train_test_split(train_codes, labels, test_size=0.3, random_state=42)

    return X_train, X_test, y_train, y_test, test_codes


def tokenize_sequences(X_train, X_test, test_codes):
    tokenizer = Tokenizer(num_words=359414, split=' ')
    tokenizer.fit_on_texts(X_train)
    X_train_sequences = tokenizer.texts_to_sequences(X_train)
    X_test_sequences = tokenizer.texts_to_sequences(X_test)
    test_sequences = tokenizer.texts_to_sequences(test_codes)

    average_sequence_length = int(np.mean([len(seq) for seq in X_train_sequences]))

    X_train_padded = pad_sequences(X_train_sequences, maxlen=average_sequence_length)
    X_test_padded = pad_sequences(X_test_sequences, maxlen=average_sequence_length)
    test_padded = pad_sequences(test_sequences, maxlen=average_sequence_length)

    return X_train_padded, X_test_padded, test_padded, tokenizer.word_index


def load_embedding_model():
    with open('/home/shaurya/BTP/1/Outputs/Embedding Models/Word2vec/word2vec_150_model.pkl', 'rb') as f:
        embedding_model = pickle.load(f)

    return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='LSTM_W2V_EL'))
    model.add(LSTM(units=128, return_sequences=True, name='LSTM_W2V_1'))
    model.add(LSTM(units=128, name='LSTM_W2V_2'))
    model.add(Dense(units=1, activation='sigmoid', name='LSTM_W2V_OL'))
    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def perform_cross_validation(X_train_padded, y_train, model, skf):
  fold = 1
  accuracies = []

  for train_index, val_index in skf.split(X_train_padded, y_train):
    print(f"Fold: {fold}")
    fold += 1

    X_train_fold, X_val_fold = X_train_padded[train_index], X_train_padded[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    checkpoint_path = f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5"
    checkpoint = ModelCheckpoint(
        checkpoint_path, monitor="val_loss", save_best_only=True, save_weights_only=False
    )

    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop, checkpoint])

    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    _, accuracy = model.evaluate(X_val_fold, y_val_fold)
    accuracies.append(accuracy)

  return accuracies
    
def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)
    y_pred = (y_pred_prob > 0.5).astype(int)
    report = classification_report(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    class_names = {0: "Non-vulnerable", 1: "Vulnerable"}  # Example mapping for binary classes
    labels = list(class_names.values())

    disp = ConfusionMatrixDisplay(confusion_matrix = confusion, display_labels = labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()
    print(report)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def load_all_models(i=0):
    all_models = list()

    folder_path = '/home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec'
    if i == 0:
        model_files = [f for f in os.listdir(folder_path) if f.endswith('w2v.keras')]
    else:
        model_files = [f for f in os.listdir(folder_path) if f.endswith('ft.keras')]
    
    for filename in model_files:
        model_path = os.path.join(folder_path, filename)
        model = load_model(model_path)
        all_models.append(model)
        print(f'> Loaded {model_path}')

    return all_models

def save_model(model, fold):
    model.save(f"/home/shaurya/BTP/1/Outputs/Checkpoints/Sentence/LSTM/Word2vec/model10k_fold_{fold}.h5")


# Load the data
X_train, X_test, y_train, y_test, test_codes = load_data()

# Tokenize the sequences
X_train_padded, X_test_padded, test_padded, word_index = tokenize_sequences(X_train, X_test, test_codes)


members = load_all_models(1)


for model in members:
    evaluate_model(X_test_padded, y_test, model)
# Out:
# 2024-03-19 02:46:32.064341: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 02:46:32.254525: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-19 02:46:33.107706: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-19 02:46:33.107832: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-19 02:46:33.107846: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# 2024-03-19 02:46:40.720065: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 02:46:43.219777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1326 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:3b:00.0, compute capability: 6.0
# 2024-03-19 02:46:43.220989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6016 MB memory:  -> device: 1, name: Tesla P100-PCIE-12GB, pci bus id: 0000:af:00.0, compute capability: 6.0
# 2024-03-19 02:46:43.222040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 4724 MB memory:  -> device: 2, name: Tesla P100-PCIE-12GB, pci bus id: 0000:d8:00.0, compute capability: 6.0
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_1 will use cuDNN kernels when running on GPU.
# > Loaded /home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/BLSTM_ft.keras
# DEBUG:tensorflow:Layer GRU_FT will use cuDNN kernels when running on GPU.
# > Loaded /home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/GRU_ft.keras
# DEBUG:tensorflow:Layer LSTM_FT_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer LSTM_FT_2 will use cuDNN kernels when running on GPU.
# > Loaded /home/shaurya/BTP/1/Outputs/Models/LSTM/word2vec/LSTM_ft.keras
# 2024-03-19 02:46:49.220198: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 31/31 [==============================] - 6s 175ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97       462
#          1.0       0.98      0.97      0.98       501
#
#     accuracy                           0.98       963
#    macro avg       0.97      0.98      0.98       963
# weighted avg       0.98      0.98      0.98       963
#
# Confusion Matrix:
# [[452  10]
#  [ 14 487]]
# 31/31 [==============================] - 2s 48ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96       462
#          1.0       0.97      0.96      0.96       501
#
#     accuracy                           0.96       963
#    macro avg       0.96      0.96      0.96       963
# weighted avg       0.96      0.96      0.96       963
#
# Confusion Matrix:
# [[449  13]
#  [ 22 479]]
# 31/31 [==============================] - 3s 92ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97       462
#          1.0       0.98      0.97      0.97       501
#
#     accuracy                           0.97       963
#    macro avg       0.97      0.97      0.97       963
# weighted avg       0.97      0.97      0.97       963
#
# Confusion Matrix:
# [[451  11]
#  [ 14 487]]
