# %%
import code_tokenize
import re
def my_tokenizer(text):
    text = re.sub(r'\b\d+\.\d+\b', lambda x: str(float(x.group())), text)
    tokens = code_tokenize.tokenize(text, lang="c", syntax_error="ignore")
    tokens_list = [str(x) for x in tokens]
    return tokens_list

# %%
# tokenize the data that can be used by embeddings
from tensorflow.keras.preprocessing.text import Tokenizer
import os
import pickle


tokenizer_path = "F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//tokenizer.pkl"
retrain = False
if os.path.exists(tokenizer_path) and not retrain:
    print("[INFO] Loading saved tokenizer")
    with open(tokenizer_path, "rb") as tokenizer_file:
        tokenizer = pickle.load(tokenizer_file)
else:
    t0 = time()
    print("[INFO] fitting tokenizer on TRAIN data...")
    tokenizer = Tokenizer(lower=False, analyzer = my_tokenizer)  # used in the research paper
    tokenizer.fit_on_texts(X_train.apply(lambda x: np.str_(x)))
    # save the tokenizer for future use
    with open(tokenizer_path, "wb") as tokenizer_file:
        pickle.dump(tokenizer, tokenizer_file, protocol=pickle.HIGHEST_PROTOCOL)
        # pickle.HIGHEST_PROTOCOL is highest protocol version available
    print(f"time taken to fit and save the tokenizer: {time()-t0} s")
# Out:
# [INFO] Loading saved tokenizer

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score,ConfusionMatrixDisplay
from sklearn.utils import shuffle

import pandas as pd


os.environ['TF_FORCE_UNIFIED_MEMORY']='1'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='2.0'
#os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH ']='true' # as I understood, this is redundant with the set_memory_growth part :)

import tensorflow as tf    
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      print(gpu)
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from keras.models import load_model
from keras.utils import to_categorical
from numpy import dstack



import pickle
from gensim.models import Word2Vec

def tokenize_sequences(X_train, X_test, X_val, tokenizer):
    X_train = [str(code) for code in X_train]  # Convert any non-string elements to string
    X_train = tokenizer.texts_to_sequences(X_train)

    X_val = [str(code) for code in X_val]  # Convert any non-string elements to string
    X_val = tokenizer.texts_to_sequences(X_val)

    X_test = [str(code) for code in X_test]  # Convert any non-string elements to string
    X_test = tokenizer.texts_to_sequences(X_test)

    max_length_train = max(len(sequence) for sequence in X_train)
    max_length_val = max(len(sequence) for sequence in X_val)
    max_length_test = max(len(sequence) for sequence in X_test)

    maxlen = 1000

    X_train = pad_sequences(X_train, padding="post", maxlen=maxlen)
    X_val = pad_sequences(X_val, padding="post", maxlen=maxlen)
    X_test = pad_sequences(X_test, padding="post", maxlen=maxlen)

    return X_train, X_val, X_test

def load_data():
    df = pd.read_csv('F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//CSVs//preprocessed_df_100k.csv')
    df_target_0 = df[df['target'] == 0]
    df_target_1 = df[df['target'] == 1]

    df_filtered = pd.concat([df_target_0, df_target_1], ignore_index=True)
    
    # Shuffle the data
    df_filtered = shuffle(df_filtered, random_state=42)
    
    # Determine the indices for splitting
    total_samples = len(df_filtered)
    train_end_index = int(total_samples * 0.7)
    val_end_index = int(train_end_index + (total_samples * 0.2))

    X_train = df_filtered['func'][:train_end_index]
    X_val = df_filtered['func'][train_end_index:val_end_index]
    X_test = df_filtered['func'][val_end_index:]

    y_train = df_filtered['target'][:train_end_index]
    y_val = df_filtered['target'][train_end_index:val_end_index]
    y_test = df_filtered['target'][val_end_index:]

    return X_train, X_val, X_test, y_train, y_val, y_test
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
from keras.models import load_model
from keras.utils import plot_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

import sys
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt

import os

def load_all_models(i=0):
    all_models = list()

    folder_path = 'F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//Diversevul'
    if i == 0:
        model_files = [f for f in os.listdir(folder_path) if f.endswith('.keras')]
    else:
        model_files = [f for f in os.listdir(folder_path) if f.endswith('.keras')]
    
    for filename in model_files:
        model_path = os.path.join(folder_path, filename)
        model = load_model(model_path)
        all_models.append(model)
        print(f'> Loaded {model_path}')

    return all_models


def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
        # make prediction
        yhat = model.predict(inputX, verbose=0)
        # stack predictions into [rows, members, probabilities]
        if stackX is None:
            stackX = yhat
        else:
            stackX = np.dstack((stackX, yhat))
    
    print("Sample of stackX before reshaping:")
    for i in range(min(3, stackX.shape[0])):
        print(np.round(stackX[i], decimals=4))
        
    print("Shape of stackX before reshaping:", stackX.shape)
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    print("Shape of stackX after reshaping:", stackX.shape)
    
    print("Sample of stackX after reshaping:")
    for i in range(min(3, stackX.shape[0])):
        print(np.round(stackX[i], decimals=4))

    return stackX



def fit_stacked_model(members, inputX, inputy):
    stackedX = stacked_dataset(members, inputX)
    
    train_acc_list = []
    val_acc_list = []
    fold = 1

    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    model = Sequential([
        Dense(128, activation='relu', input_shape=(stackedX.shape[1],)),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    for train_index, val_index in skf.split(stackedX, inputy):
        print(f"Fold: {fold}")
        fold += 1
        X_train_fold, X_val_fold = stackedX[train_index], stackedX[val_index]
        y_train_fold, y_val_fold = inputy.iloc[train_index], inputy.iloc[val_index]       

        history = model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=64, verbose=1, validation_data=(X_val_fold, y_val_fold))

        train_acc_list.append(history.history['accuracy'])
        val_acc_list.append(history.history['val_accuracy'])

        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Loss across Epochs (Fold {fold - 1})')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title(f'Accuracy across Epochs (Fold {fold - 1})')
        plt.legend()

        plt.tight_layout()
        plt.show()

    return model

def plot_fold_results(history, fold):
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'Fold {fold}: Training and Validation Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'Fold {fold}: Training and Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()




# def evaluate_model(X_test_padded, y_test, model):
#     stackedX = stacked_dataset(members, inputX)
#     y_pred_prob = model.predict(X_test_padded)
#     y_pred = (y_pred_prob > 0.5).astype(int)
#     report = classification_report(y_test, y_pred)
#     confusion = confusion_matrix(y_test, y_pred)
#     class_names = {0: "Non-vulnerable", 1: "Vulnerable"}  # Example mapping for binary classes
#     labels = list(class_names.values())

#     disp = ConfusionMatrixDisplay(confusion_matrix = confusion, display_labels = labels)
#     disp.plot(cmap=plt.cm.Blues)
#     plt.show()
#     print(report)
#     print("Confusion Matrix:")
#     print(confusion)
    
def stacked_prediction(members, model, inputX, y_test, threshold=0.5):
    stackedX = stacked_dataset(members, inputX)
    yhat = model.predict(stackedX)
    yhat_binary = (yhat > threshold).astype(int)
    report = classification_report(y_test, yhat_binary)

    confusion = confusion_matrix(y_test, yhat_binary)
    class_names = {0: "Non-vulnerable", 1: "Vulnerable"}  # Example mapping for binary classes
    labels = list(class_names.values())

    tn, fp, fn, tp = confusion.ravel()
    fpr = fp / (fp + tn)
    fnr = fn / (fn + tp)
    
    disp = ConfusionMatrixDisplay(confusion_matrix = confusion, display_labels = labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()
    print(report)
    print("Confusion Matrix:")
    print(confusion)
    print("False Positive Rate (FPR):", fpr)
    print("False Negative Rate (FNR):", fnr)
    
    return yhat_binary

X_train, X_val, X_test, y_train, y_val, y_test = load_data()
# y_train = to_categorical(y_train)
# y_val = to_categorical(y_val)
# y_test = to_categorical(y_test)

X_train_padded, X_val_padded, test_padded = tokenize_sequences(X_train, X_test, X_val, tokenizer)

import itertools

members = load_all_models(0)
# for model in members:
#    _, acc = model.evaluate(X_test_padded, y_test, verbose=0)
#    print('Model Accuracy: %.3f' % acc

# fit stacked model using the ensemble
model = fit_stacked_model(members, test_padded, y_test)

# evaluate model on test set
# yhat = stacked_prediction(members, model, test_padded, y_test)
# print("Sample of y_test:")
# print(y_test[:5])  # Print the first 5 elements of y_test

# print("Sample of yhat:")
# print(yhat[:5])  # Print the first 5 elements of yhat


# acc = accuracy_score(y_test, yhat)
# print('Stacked Test Accuracy: %.3f' % acc)
# # evaluate_model(X_test_padded, y_test, model)
# Out:
# C:\Users\shaur\miniconda3\envs\tf\lib\site-packages\tree_sitter\__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# > Loaded F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//Diversevul\GRU_w2v_50.keras
# > Loaded F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//Diversevul\LSTM_ft_50.keras
# > Loaded F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//Diversevul\LSTM_w2v_50.keras
# Sample of stackX before reshaping:
# [[0.9987 1.     1.    ]
#  [0.0013 0.     0.    ]]
# [[9.984e-01 9.999e-01 1.000e+00]
#  [1.600e-03 1.000e-04 0.000e+00]]
# [[0.5422 0.0293 0.0052]
#  [0.4578 0.9707 0.9948]]
# Shape of stackX before reshaping: (11895, 2, 3)
# Shape of stackX after reshaping: (11895, 6)
# Sample of stackX after reshaping:
# [0.9987 1.     1.     0.0013 0.     0.    ]
# [9.984e-01 9.999e-01 1.000e+00 1.600e-03 1.000e-04 0.000e+00]
# [0.5422 0.0293 0.0052 0.4578 0.9707 0.9948]
# Fold: 1
# Epoch 1/50
# 168/168 [==============================] - 1s 5ms/step - loss: 0.3593 - accuracy: 0.8856 - val_loss: 0.3279 - val_accuracy: 0.8756
# Epoch 2/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.3018 - accuracy: 0.8904 - val_loss: 0.3281 - val_accuracy: 0.8756
# Epoch 3/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.3015 - accuracy: 0.8897 - val_loss: 0.3284 - val_accuracy: 0.8765
# Epoch 4/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.3011 - accuracy: 0.8904 - val_loss: 0.3278 - val_accuracy: 0.8765
# Epoch 5/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.3006 - accuracy: 0.8906 - val_loss: 0.3269 - val_accuracy: 0.8765
# Epoch 6/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.3005 - accuracy: 0.8910 - val_loss: 0.3271 - val_accuracy: 0.8756
# Epoch 7/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2999 - accuracy: 0.8901 - val_loss: 0.3268 - val_accuracy: 0.8765
# Epoch 8/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2995 - accuracy: 0.8905 - val_loss: 0.3266 - val_accuracy: 0.8765
# Epoch 9/50
# 168/168 [==============================] - 1s 5ms/step - loss: 0.2992 - accuracy: 0.8900 - val_loss: 0.3256 - val_accuracy: 0.8756
# Epoch 10/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2984 - accuracy: 0.8909 - val_loss: 0.3259 - val_accuracy: 0.8756
# Epoch 11/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2979 - accuracy: 0.8916 - val_loss: 0.3247 - val_accuracy: 0.8773
# Epoch 12/50
# 168/168 [==============================] - 1s 5ms/step - loss: 0.2973 - accuracy: 0.8898 - val_loss: 0.3257 - val_accuracy: 0.8782
# Epoch 13/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2976 - accuracy: 0.8913 - val_loss: 0.3256 - val_accuracy: 0.8765
# Epoch 14/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2965 - accuracy: 0.8904 - val_loss: 0.3237 - val_accuracy: 0.8773
# Epoch 15/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2964 - accuracy: 0.8903 - val_loss: 0.3229 - val_accuracy: 0.8756
# Epoch 16/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2956 - accuracy: 0.8905 - val_loss: 0.3218 - val_accuracy: 0.8756
# Epoch 17/50
# 168/168 [==============================] - 1s 5ms/step - loss: 0.2952 - accuracy: 0.8912 - val_loss: 0.3242 - val_accuracy: 0.8765
# Epoch 18/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2943 - accuracy: 0.8911 - val_loss: 0.3229 - val_accuracy: 0.8756
# Epoch 19/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2942 - accuracy: 0.8904 - val_loss: 0.3226 - val_accuracy: 0.8765
# Epoch 20/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2934 - accuracy: 0.8910 - val_loss: 0.3230 - val_accuracy: 0.8765
# Epoch 21/50
# 168/168 [==============================] - 1s 5ms/step - loss: 0.2932 - accuracy: 0.8908 - val_loss: 0.3230 - val_accuracy: 0.8798
# Epoch 22/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2928 - accuracy: 0.8918 - val_loss: 0.3210 - val_accuracy: 0.8756
# Epoch 23/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.
50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2827 - accuracy: 0.8917 - val_loss: 0.2730 - val_accuracy: 0.9024
# Epoch 21/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2832 - accuracy: 0.8914 - val_loss: 0.2731 - val_accuracy: 0.9024
# Epoch 22/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2824 - accuracy: 0.8922 - val_loss: 0.2731 - val_accuracy: 0.9041
# Epoch 23/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2825 - accuracy: 0.8918 - val_loss: 0.2735 - val_accuracy: 0.9008
# Epoch 24/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2826 - accuracy: 0.8912 - val_loss: 0.2731 - val_accuracy: 0.8999
# Epoch 25/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2825 - accuracy: 0.8917 - val_loss: 0.2738 - val_accuracy: 0.9016
# Epoch 26/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2830 - accuracy: 0.8924 - val_loss: 0.2731 - val_accuracy: 0.9008
# Epoch 27/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2826 - accuracy: 0.8917 - val_loss: 0.2732 - val_accuracy: 0.9008
# Epoch 28/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2824 - accuracy: 0.8917 - val_loss: 0.2744 - val_accuracy: 0.8991
# Epoch 29/50
# ...
# Epoch 40/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2787 - accuracy: 0.8939 - val_loss: 0.3027 - val_accuracy: 0.8814
# Epoch 41/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2782 - accuracy: 0.8943 - val_loss: 0.3023 - val_accuracy: 0.8823
# Epoch 42/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2784 - accuracy: 0.8938 - val_loss: 0.3028 - val_accuracy: 0.8814
# Epoch 43/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2783 - accuracy: 0.8939 - val_loss: 0.3021 - val_accuracy: 0.8823
# Epoch 44/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2786 - accuracy: 0.8939 - val_loss: 0.3025 - val_accuracy: 0.8814
# Epoch 45/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2784 - accuracy: 0.8929 - val_loss: 0.3024 - val_accuracy: 0.8823
# Epoch 46/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2785 - accuracy: 0.8945 - val_loss: 0.3012 - val_accuracy: 0.8823
# Epoch 47/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2780 - accuracy: 0.8937 - val_loss: 0.3023 - val_accuracy: 0.8823
# Epoch 48/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2785 - accuracy: 0.8947 - val_loss: 0.3030 - val_accuracy: 0.8814
# Epoch 49/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2781 - accuracy: 0.8937 - val_loss: 0.3043 - val_accuracy: 0.8823
# Epoch 50/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2782 - accuracy: 0.8942 - val_loss: 0.3025 - val_accuracy: 0.8814
# Fold: 9
# Epoch 1/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2817 - accuracy: 0.8925 - val_loss: 0.2727 - val_accuracy: 0.8982
# Epoch 2/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2817 - accuracy: 0.8920 - val_loss: 0.2720 - val_accuracy: 0.8999
# Epoch 3/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2818 - accuracy: 0.8917 - val_loss: 0.2708 - val_accuracy: 0.8982
# Epoch 4/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.8921 - val_loss: 0.2721 - val_accuracy: 0.8999
# Epoch 5/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2817 - accuracy: 0.8920 - val_loss: 0.2713 - val_accuracy: 0.8991
# Epoch 6/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8921 - val_loss: 0.2715 - val_accuracy: 0.8982
# Epoch 7/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8921 - val_loss: 0.2720 - val_accuracy: 0.8982
# Epoch 8/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8923 - val_loss: 0.2719 - val_accuracy: 0.8966
# Epoch 9/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8917 - val_loss: 0.2741 - val_accuracy: 0.8982
# Epoch 10/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8916 - val_loss: 0.2734 - val_accuracy: 0.8991
# Epoch 11/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8917 - val_loss: 0.2740 - val_accuracy: 0.8974
# Epoch 12/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8927 - val_loss: 0.2711 - val_accuracy: 0.8974
# Epoch 13/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8925 - val_loss: 0.2724 - val_accuracy: 0.8974
# Epoch 14/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8926 - val_loss: 0.2734 - val_accuracy: 0.8974
# Epoch 15/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8923 - val_loss: 0.2742 - val_accuracy: 0.8966
# Epoch 16/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8928 - val_loss: 0.2732 - val_accuracy: 0.8974
# Epoch 17/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8923 - val_loss: 0.2736 - val_accuracy: 0.8966
# Epoch 18/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8928 - val_loss: 0.2730 - val_accuracy: 0.8974
# Epoch 19/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2808 - accuracy: 0.8919 - val_loss: 0.2750 - val_accuracy: 0.8966
# Epoch 20/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2818 - accuracy: 0.8920 - val_loss: 0.2732 - val_accuracy: 0.8974
# Epoch 21/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8928 - val_loss: 0.2741 - val_accuracy: 0.8974
# Epoch 22/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8923 - val_loss: 0.2723 - val_accuracy: 0.8966
# Epoch 23/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8928 - val_loss: 0.2736 - val_accuracy: 0.8974
# Epoch 24/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2807 - accuracy: 0.8922 - val_loss: 0.2724 - val_accuracy: 0.8982
# Epoch 25/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2817 - accuracy: 0.8921 - val_loss: 0.2734 - val_accuracy: 0.8974
# Epoch 26/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8924 - val_loss: 0.2735 - val_accuracy: 0.8966
# Epoch 27/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8925 - val_loss: 0.2731 - val_accuracy: 0.8982
# Epoch 28/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8924 - val_loss: 0.2732 - val_accuracy: 0.8966
# Epoch 29/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8929 - val_loss: 0.2762 - val_accuracy: 0.8949
# Epoch 30/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8922 - val_loss: 0.2724 - val_accuracy: 0.8949
# Epoch 31/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8929 - val_loss: 0.2738 - val_accuracy: 0.8982
# Epoch 32/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8925 - val_loss: 0.2736 - val_accuracy: 0.8974
# Epoch 33/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8924 - val_loss: 0.2743 - val_accuracy: 0.8966
# Epoch 34/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8923 - val_loss: 0.2739 - val_accuracy: 0.8966
# Epoch 35/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8917 - val_loss: 0.2746 - val_accuracy: 0.8957
# Epoch 36/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8923 - val_loss: 0.2743 - val_accuracy: 0.8949
# Epoch 37/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2807 - accuracy: 0.8924 - val_loss: 0.2735 - val_accuracy: 0.8966
# Epoch 38/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8923 - val_loss: 0.2751 - val_accuracy: 0.8957
# Epoch 39/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8922 - val_loss: 0.2740 - val_accuracy: 0.8974
# Epoch 40/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2806 - accuracy: 0.8923 - val_loss: 0.2735 - val_accuracy: 0.8966
# Epoch 41/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2807 - accuracy: 0.8916 - val_loss: 0.2745 - val_accuracy: 0.8966
# Epoch 42/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8924 - val_loss: 0.2751 - val_accuracy: 0.8949
# Epoch 43/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2808 - accuracy: 0.8922 - val_loss: 0.2730 - val_accuracy: 0.8974
# Epoch 44/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2808 - accuracy: 0.8923 - val_loss: 0.2746 - val_accuracy: 0.8966
# Epoch 45/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8921 - val_loss: 0.2743 - val_accuracy: 0.8982
# Epoch 46/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8928 - val_loss: 0.2778 - val_accuracy: 0.8974
# Epoch 47/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8924 - val_loss: 0.2724 - val_accuracy: 0.8974
# Epoch 48/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8923 - val_loss: 0.2738 - val_accuracy: 0.8957
# Epoch 49/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2807 - accuracy: 0.8926 - val_loss: 0.2738 - val_accuracy: 0.8957
# Epoch 50/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2806 - accuracy: 0.8924 - val_loss: 0.2758 - val_accuracy: 0.8974
# Fold: 10
# Epoch 1/50
# 168/168 [==============================] - 1s 5ms/step - loss: 0.2820 - accuracy: 0.8917 - val_loss: 0.2645 - val_accuracy: 0.9024
# Epoch 2/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2818 - accuracy: 0.8918 - val_loss: 0.2642 - val_accuracy: 0.9016
# Epoch 3/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2822 - accuracy: 0.8924 - val_loss: 0.2645 - val_accuracy: 0.9024
# Epoch 4/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.8924 - val_loss: 0.2644 - val_accuracy: 0.9008
# Epoch 5/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8922 - val_loss: 0.2652 - val_accuracy: 0.9024
# Epoch 6/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2818 - accuracy: 0.8917 - val_loss: 0.2654 - val_accuracy: 0.8999
# Epoch 7/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8918 - val_loss: 0.2639 - val_accuracy: 0.9024
# Epoch 8/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2821 - accuracy: 0.8930 - val_loss: 0.2640 - val_accuracy: 0.9008
# Epoch 9/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8927 - val_loss: 0.2655 - val_accuracy: 0.9024
# Epoch 10/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8925 - val_loss: 0.2672 - val_accuracy: 0.9016
# Epoch 11/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.8925 - val_loss: 0.2648 - val_accuracy: 0.9024
# Epoch 12/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8919 - val_loss: 0.2664 - val_accuracy: 0.9008
# Epoch 13/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8928 - val_loss: 0.2666 - val_accuracy: 0.9008
# Epoch 14/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2817 - accuracy: 0.8911 - val_loss: 0.2692 - val_accuracy: 0.9016
# Epoch 15/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8925 - val_loss: 0.2692 - val_accuracy: 0.9008
# Epoch 16/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8923 - val_loss: 0.2659 - val_accuracy: 0.8999
# Epoch 17/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2822 - accuracy: 0.8927 - val_loss: 0.2674 - val_accuracy: 0.9016
# Epoch 18/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8931 - val_loss: 0.2662 - val_accuracy: 0.9016
# Epoch 19/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8922 - val_loss: 0.2676 - val_accuracy: 0.9008
# Epoch 20/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8917 - val_loss: 0.2668 - val_accuracy: 0.8966
# Epoch 21/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8924 - val_loss: 0.2661 - val_accuracy: 0.9008
# Epoch 22/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.8921 - val_loss: 0.2662 - val_accuracy: 0.9008
# Epoch 23/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8920 - val_loss: 0.2664 - val_accuracy: 0.8999
# Epoch 24/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8929 - val_loss: 0.2647 - val_accuracy: 0.9016
# Epoch 25/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8918 - val_loss: 0.2683 - val_accuracy: 0.9008
# Epoch 26/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8926 - val_loss: 0.2661 - val_accuracy: 0.9008
# Epoch 27/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8924 - val_loss: 0.2659 - val_accuracy: 0.8974
# Epoch 28/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8920 - val_loss: 0.2653 - val_accuracy: 0.9024
# Epoch 29/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.8925 - val_loss: 0.2686 - val_accuracy: 0.9008
# Epoch 30/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8924 - val_loss: 0.2679 - val_accuracy: 0.8991
# Epoch 31/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8931 - val_loss: 0.2659 - val_accuracy: 0.9016
# Epoch 32/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8920 - val_loss: 0.2678 - val_accuracy: 0.8999
# Epoch 33/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8922 - val_loss: 0.2663 - val_accuracy: 0.9008
# Epoch 34/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2817 - accuracy: 0.8923 - val_loss: 0.2686 - val_accuracy: 0.9008
# Epoch 35/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8923 - val_loss: 0.2666 - val_accuracy: 0.8999
# Epoch 36/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8930 - val_loss: 0.2668 - val_accuracy: 0.8991
# Epoch 37/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2813 - accuracy: 0.8928 - val_loss: 0.2668 - val_accuracy: 0.8999
# Epoch 38/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8927 - val_loss: 0.2667 - val_accuracy: 0.9024
# Epoch 39/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8928 - val_loss: 0.2687 - val_accuracy: 0.8991
# Epoch 40/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8922 - val_loss: 0.2701 - val_accuracy: 0.8999
# Epoch 41/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8930 - val_loss: 0.2668 - val_accuracy: 0.9008
# Epoch 42/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2814 - accuracy: 0.8929 - val_loss: 0.2685 - val_accuracy: 0.9008
# Epoch 43/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.8931 - val_loss: 0.2679 - val_accuracy: 0.8991
# Epoch 44/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2816 - accuracy: 0.8931 - val_loss: 0.2676 - val_accuracy: 0.8999
# Epoch 45/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2810 - accuracy: 0.8928 - val_loss: 0.2685 - val_accuracy: 0.9016
# Epoch 46/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8921 - val_loss: 0.2671 - val_accuracy: 0.9008
# Epoch 47/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8924 - val_loss: 0.2681 - val_accuracy: 0.9008
# Epoch 48/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8924 - val_loss: 0.2664 - val_accuracy: 0.8991
# Epoch 49/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2812 - accuracy: 0.8928 - val_loss: 0.2661 - val_accuracy: 0.9016
# Epoch 50/50
# 168/168 [==============================] - 1s 4ms/step - loss: 0.2811 - accuracy: 0.8924 - val_loss: 0.2707 - val_accuracy: 0.8991
