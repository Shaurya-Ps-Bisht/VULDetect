# %%
import code_tokenize
import re
def my_tokenizer(text):
    text = re.sub(r'\b\d+\.\d+\b', lambda x: str(float(x.group())), text)
    tokens = code_tokenize.tokenize(text, lang="c", syntax_error="ignore")
    tokens_list = [str(x) for x in tokens]
    return tokens_list

# %%
# tokenize the data that can be used by embeddings
from tensorflow.keras.preprocessing.text import Tokenizer
import os
import pickle


tokenizer_path = "F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//tokenizerClubbed.pkl"
retrain = False
if os.path.exists(tokenizer_path) and not retrain:
    print("[INFO] Loading saved tokenizer")
    with open(tokenizer_path, "rb") as tokenizer_file:
        tokenizer = pickle.load(tokenizer_file)
else:
    print("Wrong address")
# Out:
# Wrong address

# %%
import os
import pandas as pd
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils import shuffle
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2



os.environ['TF_FORCE_UNIFIED_MEMORY']='1'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='2.0'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH ']='true' # as I understood, this is redundant with the set_memory_growth part :)

import tensorflow as tf    
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      print(gpu)
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


def tokenize_sequences(X_train, X_test, X_val, tokenizer):
    X_train = [str(code) for code in X_train]  # Convert any non-string elements to string
    X_train = tokenizer.texts_to_sequences(X_train)

    X_val = [str(code) for code in X_val]  # Convert any non-string elements to string
    X_val = tokenizer.texts_to_sequences(X_val)

    X_test = [str(code) for code in X_test]  # Convert any non-string elements to string
    X_test = tokenizer.texts_to_sequences(X_test)

    max_length_train = max(len(sequence) for sequence in X_train)
    max_length_val = max(len(sequence) for sequence in X_val)
    max_length_test = max(len(sequence) for sequence in X_test)

    maxlen = 1000

    X_train = pad_sequences(X_train, padding="post", maxlen=maxlen)
    X_val = pad_sequences(X_val, padding="post", maxlen=maxlen)
    X_test = pad_sequences(X_test, padding="post", maxlen=maxlen)

    return X_train, X_val, X_test
    
def load_data():
    df = pd.read_csv('F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//CSVs//preprocessed_df_100k.csv')
    df_target_0 = df[df['target'] == 0]
    df_target_1 = df[df['target'] == 1]

    df_filtered = pd.concat([df_target_0, df_target_1], ignore_index=True)
    
    # Shuffle the data
    df_filtered = shuffle(df_filtered, random_state=42)
    
    # Determine the indices for splitting
    total_samples = len(df_filtered)
    train_end_index = int(total_samples * 0.7)
    val_end_index = int(train_end_index + (total_samples * 0.2))

    X_train = df_filtered['func'][:train_end_index]
    X_val = df_filtered['func'][train_end_index:val_end_index]
    X_test = df_filtered['func'][val_end_index:]

    y_train = df_filtered['target'][:train_end_index]
    y_val = df_filtered['target'][train_end_index:val_end_index]
    y_test = df_filtered['target'][val_end_index:]

    return X_train, X_val, X_test, y_train, y_val, y_test





def load_embedding_model(x):
  filename = f'F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Embedding Models 3//Word2vec//word2vec_{x}_model.pkl'

  with open(filename, 'rb') as f:
    embedding_model = pickle.load(f)

  return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='BLSTM_W2V_EL'))
    model.add(Bidirectional(LSTM(units=128, return_sequences=True, name='BLSTM_W2V_1', dropout=0.4)))
    model.add(Bidirectional(LSTM(units=128), name='BLSTM_W2V_2'))
    model.add(Dense(units=2, activation='softmax', name='BLSTM_W2V_OL'))    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)  

    y_pred = np.argmax(y_pred_prob, axis=1)

    if y_test.shape[1] > 1:
        y_test = np.argmax(y_test, axis=1)

    report = classification_report(y_test, y_pred)
    print(report)

    confusion = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Checkpoints//Sentence//LSTM//Word2vec//model10k_fold_{fold}.h5")

def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points



print("1")
# Tokenize the sequences
X_train, X_val, X_test, y_train, y_val, y_test = load_data()
print("2")

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)



X_train_padded, X_val_padded, test_padded = tokenize_sequences(X_train, X_test, X_val, tokenizer)
print("3")


embedding_dims = [50]

for embedding_dim in embedding_dims:
    print("4")

    embedding_model = load_embedding_model(embedding_dim)
    print("5")

    
    # Create the embedding matrix
    embedding_dim = embedding_dim
    vocab_size = 559321
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in tokenizer.word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]
    print("6")
    # Create a sequential model
    model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])
          
    
    history = model.fit(X_train_padded, y_train, epochs=30, batch_size=64, validation_data=(X_val_padded, y_val))
    model.summary()
    
    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    smoothed_loss = smooth_curve(history.history['loss'])
    smoothed_val_loss = smooth_curve(history.history['val_loss'])
    plt.plot(smoothed_loss, label='Smoothed Training Loss')
    plt.plot(smoothed_val_loss, label='Smoothed Validation Loss')
    plt.title('Smoothed Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    smoothed_acc = smooth_curve(history.history['accuracy'])
    smoothed_val_acc = smooth_curve(history.history['val_accuracy'])
    plt.plot(smoothed_acc, label='Smoothed Training Accuracy')
    plt.plot(smoothed_val_acc, label='Smoothed Validation Accuracy')
    plt.title('Smoothed Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    # Evaluate the model using the test set
    evaluate_model(test_padded, y_test, model)
    
    # Predict on the additional test set
    # test_pred = predict_additional_data(test_padded, model)        
        
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//Diversevul/BILSTM_w2v_{embedding_dim}.keras")
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# 1
# 2
# C:\Users\shaur\miniconda3\envs\tf\lib\site-packages\tree_sitter\__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# 3
# 4
# 5
# 6
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm will use cuDNN kernels when running on GPU.
# Epoch 1/30
# 1301/1301 [==============================] - 429s 329ms/step - loss: 0.3796 - accuracy: 0.8498 - val_loss: 0.3528 - val_accuracy: 0.8578
# Epoch 2/30
# 1301/1301 [==============================] - 512s 394ms/step - loss: 0.3513 - accuracy: 0.8602 - val_loss: 0.3448 - val_accuracy: 0.8637
# Epoch 3/30
# 1301/1301 [==============================] - 476s 366ms/step - loss: 0.3393 - accuracy: 0.8668 - val_loss: 0.3407 - val_accuracy: 0.8678
# Epoch 4/30
# 1301/1301 [==============================] - 425s 326ms/step - loss: 0.3290 - accuracy: 0.8706 - val_loss: 0.3199 - val_accuracy: 0.8715
# Epoch 5/30
# 1301/1301 [==============================] - 425s 327ms/step - loss: 0.3193 - accuracy: 0.8739 - val_loss: 0.3112 - val_accuracy: 0.8784
# Epoch 6/30
# 1301/1301 [==============================] - 425s 327ms/step - loss: 0.3127 - accuracy: 0.8779 - val_loss: 0.3140 - val_accuracy: 0.8767
# Epoch 7/30
# 1301/1301 [==============================] - 425s 326ms/step - loss: 0.3067 - accuracy: 0.8800 - val_loss: 0.3067 - val_accuracy: 0.8797
# Epoch 8/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.3052 - accuracy: 0.8825 - val_loss: 0.3117 - val_accuracy: 0.8797
# Epoch 9/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2969 - accuracy: 0.8860 - val_loss: 0.2985 - val_accuracy: 0.8839
# Epoch 10/30
# 1301/1301 [==============================] - 428s 329ms/step - loss: 0.2912 - accuracy: 0.8877 - val_loss: 0.3121 - val_accuracy: 0.8814
# Epoch 11/30
# 1301/1301 [==============================] - 451s 347ms/step - loss: 0.2864 - accuracy: 0.8888 - val_loss: 0.3009 - val_accuracy: 0.8845
# Epoch 12/30
# 1301/1301 [==============================] - 453s 348ms/step - loss: 0.2805 - accuracy: 0.8906 - val_loss: 0.3033 - val_accuracy: 0.8844
# Epoch 13/30
# 1301/1301 [==============================] - 449s 345ms/step - loss: 0.2783 - accuracy: 0.8921 - val_loss: 0.2967 - val_accuracy: 0.8853
# Epoch 14/30
# 1301/1301 [==============================] - 452s 348ms/step - loss: 0.2738 - accuracy: 0.8928 - val_loss: 0.2946 - val_accuracy: 0.8865
# Epoch 15/30
# 1301/1301 [==============================] - 427s 328ms/step - loss: 0.2691 - accuracy: 0.8950 - val_loss: 0.2979 - val_accuracy: 0.8848
# Epoch 16/30
# 1301/1301 [==============================] - 426s 327ms/step - loss: 0.2645 - accuracy: 0.8976 - val_loss: 0.3024 - val_accuracy: 0.8803
# Epoch 17/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2614 - accuracy: 0.8975 - val_loss: 0.2968 - val_accuracy: 0.8857
# Epoch 18/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2578 - accuracy: 0.8985 - val_loss: 0.2946 - val_accuracy: 0.8852
# Epoch 19/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2547 - accuracy: 0.9003 - val_loss: 0.2983 - val_accuracy: 0.8847
# Epoch 20/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2509 - accuracy: 0.9015 - val_loss: 0.2952 - val_accuracy: 0.8857
# Epoch 21/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2484 - accuracy: 0.9023 - val_loss: 0.3036 - val_accuracy: 0.8844
# Epoch 22/30
# 1301/1301 [==============================] - 425s 327ms/step - loss: 0.2449 - accuracy: 0.9036 - val_loss: 0.3050 - val_accuracy: 0.8839
# Epoch 23/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2427 - accuracy: 0.9040 - val_loss: 0.3010 - val_accuracy: 0.8857
# Epoch 24/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2387 - accuracy: 0.9055 - val_loss: 0.2974 - val_accuracy: 0.8839
# Epoch 25/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2356 - accuracy: 0.9069 - val_loss: 0.3035 - val_accuracy: 0.8831
# Epoch 26/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2326 - accuracy: 0.9087 - val_loss: 0.2983 - val_accuracy: 0.8857
# Epoch 27/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2313 - accuracy: 0.9086 - val_loss: 0.2993 - val_accuracy: 0.8834
# Epoch 28/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2268 - accuracy: 0.9092 - val_loss: 0.3055 - val_accuracy: 0.8829
# Epoch 29/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2247 - accuracy: 0.9115 - val_loss: 0.3085 - val_accuracy: 0.8827
# Epoch 30/30
# 1301/1301 [==============================] - 424s 326ms/step - loss: 0.2243 - accuracy: 0.9111 - val_loss: 0.3057 - val_accuracy: 0.8826
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  BLSTM_W2V_EL (Embedding)    (None, 1000, 50)          27966050
#
#  bidirectional (Bidirectiona  (None, 1000, 256)        183296
#  l)
#
#  BLSTM_W2V_2 (Bidirectional)  (None, 256)              394240
#
#  BLSTM_W2V_OL (Dense)        (None, 2)                 514
#
# =================================================================
# Total params: 28,544,100
# Trainable params: 578,050
# Non-trainable params: 27,966,050
# _________________________________________________________________
# 372/372 [==============================] - 29s 79ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93     10015
#            1       0.67      0.50      0.57      1880
#
#     accuracy                           0.88     11895
#    macro avg       0.79      0.73      0.75     11895
# weighted avg       0.87      0.88      0.87     11895
#
# Confusion Matrix:
# [[9555  460]
#  [ 947  933]]

# %%
import os
import pandas as pd
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils import shuffle
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2



os.environ['TF_FORCE_UNIFIED_MEMORY']='1'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='2.0'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH ']='true' # as I understood, this is redundant with the set_memory_growth part :)

import tensorflow as tf    
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      print(gpu)
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


tf.data.experimental.enable_debug_mode()
tf.config.run_functions_eagerly(True)
tf.get_logger().setLevel(tf.compat.v1.logging.DEBUG)
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Embedding, GRU, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.optimizers import Adam

import pickle
from gensim.models import Word2Vec

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val


def tokenize_sequences(X_train, X_test, X_val, tokenizer):
    X_train = [str(code) for code in X_train]  # Convert any non-string elements to string
    X_train = tokenizer.texts_to_sequences(X_train)

    X_val = [str(code) for code in X_val]  # Convert any non-string elements to string
    X_val = tokenizer.texts_to_sequences(X_val)

    X_test = [str(code) for code in X_test]  # Convert any non-string elements to string
    X_test = tokenizer.texts_to_sequences(X_test)

    max_length_train = max(len(sequence) for sequence in X_train)
    max_length_val = max(len(sequence) for sequence in X_val)
    max_length_test = max(len(sequence) for sequence in X_test)

    maxlen = 1000

    X_train = pad_sequences(X_train, padding="post", maxlen=maxlen)
    X_val = pad_sequences(X_val, padding="post", maxlen=maxlen)
    X_test = pad_sequences(X_test, padding="post", maxlen=maxlen)

    return X_train, X_val, X_test
    
def load_data():
    df = pd.read_csv('F://Development_//Deep Learning//Basic Dataset//BTP//1//Dataset//CSVs//preprocessed_df_100k.csv')
    df_target_0 = df[df['target'] == 0]
    df_target_1 = df[df['target'] == 1]

    df_filtered = pd.concat([df_target_0, df_target_1], ignore_index=True)
    
    # Shuffle the data
    df_filtered = shuffle(df_filtered, random_state=42)
    
    # Determine the indices for splitting
    total_samples = len(df_filtered)
    train_end_index = int(total_samples * 0.7)
    val_end_index = int(train_end_index + (total_samples * 0.2))

    X_train = df_filtered['func'][:train_end_index]
    X_val = df_filtered['func'][train_end_index:val_end_index]
    X_test = df_filtered['func'][val_end_index:]

    y_train = df_filtered['target'][:train_end_index]
    y_val = df_filtered['target'][train_end_index:val_end_index]
    y_test = df_filtered['target'][val_end_index:]

    return X_train, X_val, X_test, y_train, y_val, y_test





def load_embedding_model(x):
  filename = f'F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Embedding Models 3//Word2vec//word2vec_{x}_model.pkl'

  with open(filename, 'rb') as f:
    embedding_model = pickle.load(f)

  return embedding_model


def create_model(vocab_size, embedding_dim, embedding_matrix, max_sequence_length):
    # Create an Adam optimizer with the desired learning rate
    adam_optimizer = Adam(learning_rate=0.001)
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False, name='BLSTM_W2V_EL'))
    model.add(Bidirectional(LSTM(units=128, return_sequences=True, name='BLSTM_W2V_1', dropout=0.4)))
    model.add(Bidirectional(LSTM(units=128), name='BLSTM_W2V_2'))
    model.add(Dense(units=2, activation='softmax', name='BLSTM_W2V_OL'))    
    # Compile the model with the custom optimizer
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    return model



def evaluate_model(X_test_padded, y_test, model):
    y_pred_prob = model.predict(X_test_padded)  

    y_pred = np.argmax(y_pred_prob, axis=1)

    if y_test.shape[1] > 1:
        y_test = np.argmax(y_test, axis=1)

    report = classification_report(y_test, y_pred)
    print(report)

    confusion = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(confusion)


def predict_additional_data(test_padded, model):
    test_pred_prob = model.predict(test_padded)
    test_pred = (test_pred_prob > 0.5).astype(int)
    return test_pred


def save_model(model, fold):
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Checkpoints//Sentence//LSTM//Word2vec//model10k_fold_{fold}.h5")

def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points



print("1")
# Tokenize the sequences
X_train, X_val, X_test, y_train, y_val, y_test = load_data()
print("2")

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)



X_train_padded, X_val_padded, test_padded = tokenize_sequences(X_train, X_test, X_val, tokenizer)
print("3")


embedding_dims = [50]

for embedding_dim in embedding_dims:
    print("4")

    embedding_model = load_embedding_model(embedding_dim)
    print("5")

    
    # Create the embedding matrix
    embedding_dim = embedding_dim
    vocab_size = 559321
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in tokenizer.word_index.items():
        if i < vocab_size and word in embedding_model.wv:
            embedding_matrix[i] = embedding_model.wv[word]
    print("6")
    # Create a sequential model
    model = create_model(vocab_size, embedding_dim, embedding_matrix, X_train_padded.shape[1])
          
    
    history = model.fit(X_train_padded, y_train, epochs=30, batch_size=64, validation_data=(X_val_padded, y_val))
    model.summary()
    
    # Plot both loss and accuracy
    plt.figure(figsize=(10, 5))  # Adjust figure size as desired
    plt.subplot(1, 2, 1)  # Create subplot for loss
    smoothed_loss = smooth_curve(history.history['loss'])
    smoothed_val_loss = smooth_curve(history.history['val_loss'])
    plt.plot(smoothed_loss, label='Smoothed Training Loss')
    plt.plot(smoothed_val_loss, label='Smoothed Validation Loss')
    plt.title('Smoothed Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)  # Create subplot for accuracy
    smoothed_acc = smooth_curve(history.history['accuracy'])
    smoothed_val_acc = smooth_curve(history.history['val_accuracy'])
    plt.plot(smoothed_acc, label='Smoothed Training Accuracy')
    plt.plot(smoothed_val_acc, label='Smoothed Validation Accuracy')
    plt.title('Smoothed Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

    # Evaluate the model using the test set
    evaluate_model(test_padded, y_test, model)
    
    # Predict on the additional test set
    # test_pred = predict_additional_data(test_padded, model)        
        
    model.save(f"F://Development_//Deep Learning//Basic Dataset//BTP//1//Outputs//Models//Diversevul/BILSTM_ft_{embedding_dim}.keras")
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 1 Physical GPUs, 1 Logical GPUs
# 1
# 2
# C:\Users\shaur\miniconda3\envs\tf\lib\site-packages\tree_sitter\__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# 3
# 4
# 5
# 6
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_3 will use cuDNN kernels when running on GPU.
# Epoch 1/10
# 493/493 [==============================] - 139s 282ms/step - loss: 0.5601 - accuracy: 0.7327 - val_loss: 0.4853 - val_accuracy: 0.7752
# Epoch 2/10
# 493/493 [==============================] - 140s 284ms/step - loss: 0.4760 - accuracy: 0.7824 - val_loss: 0.4551 - val_accuracy: 0.7960
# Epoch 3/10
# 493/493 [==============================] - 140s 284ms/step - loss: 0.4474 - accuracy: 0.7986 - val_loss: 0.4290 - val_accuracy: 0.8183
# Epoch 4/10
# 493/493 [==============================] - 141s 286ms/step - loss: 0.4242 - accuracy: 0.8144 - val_loss: 0.4016 - val_accuracy: 0.8294
# Epoch 5/10
# 493/493 [==============================] - 140s 284ms/step - loss: 0.4055 - accuracy: 0.8226 - val_loss: 0.3941 - val_accuracy: 0.8317
# Epoch 6/10
# 493/493 [==============================] - 141s 285ms/step - loss: 0.3931 - accuracy: 0.8307 - val_loss: 0.3850 - val_accuracy: 0.8348
# Epoch 7/10
# 493/493 [==============================] - 140s 285ms/step - loss: 0.3819 - accuracy: 0.8396 - val_loss: 0.3789 - val_accuracy: 0.8374
# Epoch 8/10
# 493/493 [==============================] - 140s 285ms/step - loss: 0.3742 - accuracy: 0.8411 - val_loss: 0.3627 - val_accuracy: 0.8536
# Epoch 9/10
# 493/493 [==============================] - 140s 285ms/step - loss: 0.3592 - accuracy: 0.8488 - val_loss: 0.3951 - val_accuracy: 0.8302
# Epoch 10/10
# 493/493 [==============================] - 141s 285ms/step - loss: 0.3587 - accuracy: 0.8505 - val_loss: 0.3742 - val_accuracy: 0.8462
# 122/122 [==============================] - 9s 77ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      2000
#            1       0.91      0.76      0.83      1895
#
#     accuracy                           0.84      3895
#    macro avg       0.85      0.84      0.84      3895
# weighted avg       0.85      0.84      0.84      3895
#
# Confusion Matrix:
# [[1853  147]
#  [ 459 1436]]
# 4
# 5
# 6
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_4 will use cuDNN kernels when running on GPU.
# Epoch 1/10
# 493/493 [==============================] - 148s 301ms/step - loss: 0.5558 - accuracy: 0.7345 - val_loss: 0.4743 - val_accuracy: 0.7897
# Epoch 2/10
# 493/493 [==============================] - 150s 304ms/step - loss: 0.4637 - accuracy: 0.7904 - val_loss: 0.4388 - val_accuracy: 0.8106
# Epoch 3/10
# 493/493 [==============================] - 157s 318ms/step - loss: 0.4271 - accuracy: 0.8120 - val_loss: 0.4039 - val_accuracy: 0.8302
# Epoch 4/10
# 493/493 [==============================] - 155s 314ms/step - loss: 0.3977 - accuracy: 0.8300 - val_loss: 0.3947 - val_accuracy: 0.8274
# Epoch 5/10
# 493/493 [==============================] - 158s 321ms/step - loss: 0.3799 - accuracy: 0.8406 - val_loss: 0.3640 - val_accuracy: 0.8496
# Epoch 6/10
# 493/493 [==============================] - 154s 313ms/step - loss: 0.3606 - accuracy: 0.8510 - val_loss: 0.3740 - val_accuracy: 0.8474
# Epoch 7/10
# 493/493 [==============================] - 151s 306ms/step - loss: 0.3486 - accuracy: 0.8566 - val_loss: 0.3519 - val_accuracy: 0.8548
# Epoch 8/10
# 493/493 [==============================] - 150s 304ms/step - loss: 0.3361 - accuracy: 0.8610 - val_loss: 0.3490 - val_accuracy: 0.8536
# Epoch 9/10
# 493/493 [==============================] - 149s 303ms/step - loss: 0.3221 - accuracy: 0.8683 - val_loss: 0.3504 - val_accuracy: 0.8633
# Epoch 10/10
# 493/493 [==============================] - 149s 302ms/step - loss: 0.3107 - accuracy: 0.8770 - val_loss: 0.3282 - val_accuracy: 0.8770
# 122/122 [==============================] - 9s 76ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      2000
#            1       0.89      0.84      0.86      1895
#
#     accuracy                           0.87      3895
#    macro avg       0.87      0.87      0.87      3895
# weighted avg       0.87      0.87      0.87      3895
#
# Confusion Matrix:
# [[1810  190]
#  [ 312 1583]]
# 4
# 5
# 6
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer BLSTM_W2V_1 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# DEBUG:tensorflow:Layer lstm_5 will use cuDNN kernels when running on GPU.
# Epoch 1/10
# 493/493 [==============================] - 158s 321ms/step - loss: 0.5499 - accuracy: 0.7461 - val_loss: 0.4634 - val_accuracy: 0.7934
# Epoch 2/10
# 493/493 [==============================] - 159s 322ms/step - loss: 0.4454 - accuracy: 0.8052 - val_loss: 0.4234 - val_accuracy: 0.8240
# Epoch 3/10
# 493/493 [==============================] - 158s 321ms/step - loss: 0.4108 - accuracy: 0.8244 - val_loss: 0.3960 - val_accuracy: 0.8331
# Epoch 4/10
# 493/493 [==============================] - 159s 323ms/step - loss: 0.3898 - accuracy: 0.8374 - val_loss: 0.3746 - val_accuracy: 0.8451
# Epoch 5/10
# 493/493 [==============================] - 159s 322ms/step - loss: 0.3612 - accuracy: 0.8510 - val_loss: 0.3609 - val_accuracy: 0.8525
# Epoch 6/10
# 493/493 [==============================] - 158s 321ms/step - loss: 0.3425 - accuracy: 0.8586 - val_loss: 0.3444 - val_accuracy: 0.8585
# Epoch 7/10
# 493/493 [==============================] - 158s 321ms/step - loss: 0.3233 - accuracy: 0.8693 - val_loss: 0.3514 - val_accuracy: 0.8596
# Epoch 8/10
# 493/493 [==============================] - 159s 323ms/step - loss: 0.3127 - accuracy: 0.8747 - val_loss: 0.3188 - val_accuracy: 0.8702
# Epoch 9/10
# 493/493 [==============================] - 156s 317ms/step - loss: 0.2945 - accuracy: 0.8849 - val_loss: 0.3199 - val_accuracy: 0.8725
# Epoch 10/10
# 493/493 [==============================] - 156s 317ms/step - loss: 0.2878 - accuracy: 0.8862 - val_loss: 0.3118 - val_accuracy: 0.8776
# 122/122 [==============================] - 9s 77ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      2000
#            1       0.92      0.82      0.87      1895
#
#     accuracy                           0.88      3895
#    macro avg       0.89      0.88      0.88      3895
# weighted avg       0.88      0.88      0.88      3895
#
# Confusion Matrix:
# [[1869  131]
#  [ 333 1562]]
