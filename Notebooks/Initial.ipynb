# %%
import os
import re

def preprocess_c_program(c_program):
    preprocessed_program = re.sub(r'\/\*[\s\S]*?\*\/|\/\/.*', '', c_program)  
    preprocessed_program = re.sub(r'#.*', '', preprocessed_program)          
    preprocessed_program = preprocessed_program.strip()                       
    return preprocessed_program

def preprocess_c_programs_in_directory(directory_path):
    total_files = 0
    for filename in os.listdir(directory_path):
        file_path = os.path.join(directory_path, filename)
        if filename.endswith(".c"):
            total_files += 1
            with open(file_path, 'r', encoding='utf-8', errors='replace') as file:
                c_program = file.read()

                preprocessed_program = preprocess_c_program(c_program)

            with open(file_path, 'w') as file:
                file.write(preprocessed_program)

            print(f"Preprocessed {file_path}")

    return total_files

# Dataset directory
dataset_directory = "/home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw"

# Preprocess code snippets in the Vulnerable directory
vulnerable_directory = os.path.join(dataset_directory, "Vulnerable")
total_vulnerable_files = preprocess_c_programs_in_directory(vulnerable_directory)

# Preprocess code snippets in the Non-vulnerable directory
non_vulnerable_directory = os.path.join(dataset_directory, "Non_vulnerable")
total_non_vulnerable_files = preprocess_c_programs_in_directory(non_vulnerable_directory)

# Print total files preprocessed for each directory
print(f"Total Vulnerable files preprocessed: {total_vulnerable_files}")
print(f"Total Non-vulnerable files preprocessed: {total_non_vulnerable_files}")
# Out:
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/PavanNikhilesh_dpdk-drivers2Fnet2Fena2Fena_ethdev.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_53d.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/ssocopsacc_openldap-serveradm-libraries2Fliblber2Fbprint.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/iprouteold-ip2Fipxfrm.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/binutils-bfd2Fpeigen.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/iproutenewver-misc2Fnstat.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/rdesktop-integration-integration-printer.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/PavanNikhilesh_dpdk-lib2Flibrte_power2Frte_power_empty_poll.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE193_char_alloca_cpy_44.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/juliet-cpp-CWE401_Memory_Leak__char_realloc_54a.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/procps123-pmap.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/makepatchxen-arscan.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/findutilsxenial-test2Fdemo_termcap.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/bashxenial-lib2Freadline2Fdisplay.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/juliet-cpp-CWE401_Memory_Leak__char_calloc_41.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/iproutenewver-ip2Ftcp_metrics.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/iproutenewver-ip2Fipnetns.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/vimdebstretche-src2Fscreen.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/ncursesubuntuxenial6.0-test2Fview.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/ssocopsacc_openldap-libraries2Flibldap_r2Fldif.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/findoldversion-gl2Flib2Fidcache.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/vimxenial-src2Fgetchar.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/e2fsprogsources-lib2Fext2fs2Fdupfs.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/sysvinittrusty-src2Fmountpoint.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/test_openssl-crypto2Fbio2Fb_sock.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/C_Prueba_04_CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory-CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory__w32_char_68a.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/e2fsprogtrusty-debugfs2Fset_fields.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/CVE-2008-5276.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_09.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/kek-123-libhfs_iso2Fhfs.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/iproute2xenpatch-lib2Fll_map.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/gawkxenpatch-src2Fwindow.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/readlinedebianstretche7.0-tilde.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/gdbmdebstretche-gdbmopen.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/vimartful-src2Fspellfile.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/e2fsprogsxenpatch-lib2Fblkid2Fdevname.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/testclang-BOFstrcpy_NoLocal.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/lifelines_lifelines-src2Fliflines2Fshow.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/bind-9.11.0-lib2Flwres2Fgethost.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/bashxenpatch-alias.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable
c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/mrFast1-MrFAST.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/bind-9.11.0-bin2Fdig2Fdig.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/e2fsprogtrusty-debugfs2Fdebugfs.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/e2fsprogartful-lib2Fet2Ferror_message.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/e2fsprogsxenpatch-lib2Fext2fs2Finode_io.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/C_Prueba_04_CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory-CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory__w32_char_53a.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/vimartful-src2Fgui_athena.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/C_Prueba_04_CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory-CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory__w32_char_06.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/openssl1-crypto2Fhmac2Fhmactest.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/iproutenewver-lib2Futils.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/Pixhawk-build2Fnuttx_px4fmu-v5_default2FNuttX2Fapps2Fnshlib2Fnsh_envcmds.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/CVE-2015-5949.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/vimdebstretche-src2Fspellfile.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/gitlab_gimp_master-gimp2Fplug-ins2Fimagemap2Fimap_statusbar.c
# ...
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/subpicture.c_subpicture_region_ChainDelete.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlm.c_vlm_ControlMediaClear.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ts.c_MuxStreams.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-gnutls.c_ssl_gnutls_handshake_cb.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-gnutls.c_x509_crtdata_addref.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/thread.c_mdate_tick.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/sslconn.c_purple_ssl_connect_with_host_fd.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xiph.c_xiph_header.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc_vdpau.c_vdp_create_x11.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/unicode.c_utf8_fprintf.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/update.c_update_DownloadReal.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlmshell.c_ExecuteIsMedia.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/sslconn.c_ssl_init.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/unity.c_message_source_activated.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stun.c_do_test2.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/winpidgin.c_get_win32_error_message.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tlv.c_aim_tlvlist_add_8.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vorbis.c_OpenEncoder.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stream_output.c_sout_AccessOutDelete.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vdr.c_ScanDirectory.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/status.c_purple_presence_new_for_conv.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-gnutls.c_x509_copy_certificate.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/update_crypto.c_parse_public_key_packet.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vmem.c_Pool.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/status.c_purple_status_type_is_saveable.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/wasapi.c_Play.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/subsdelay.c_SubpicValidateWrapper.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/wb.c_silcpurple_wb_set_brush.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/video_output.c_ThreadChangeAspectRatio.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/status.c_purple_presence_get_status.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xcb_apps.c_AddApp.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/video_epg.c_vout_OSDEpgSlider.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/useravatar.c_remove_avatar_0_12_nodes.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-nss.c_ssl_nss_connect.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/transport.c_jingle_transport_parse_internal.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-gnutls.c_x509_certificate_signed_by.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_signals.c_tcl_signal_handler_free.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stringref.c_purple_stringref_new_noref.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xvideo.c_Manage.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/unity.c_alert_config_cb.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/thread.c_vlc_cond_broadcast.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/video.c_EncoderThread.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ts.c_Close.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_glib.c_tcl_kick.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stream_memory.c_Delete.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl.c_tcl_unload_plugin.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stroke.c__gstroke_bin.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/udev.c_OpenALSA.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/yuvp.c_Yuv2Rgb.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vvconfig.c_get_plugin_frame.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/thread.c_SelectClockSource.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/timestamp_format.c_textview_emission_hook.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stl.c_ParseTextTimeCode.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vhs.c_Open.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/subsdelay.c_SubsdelayEntryNewStopValueUpdated.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/twolame.c_CloseEncoder.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vorbis.c_OpenDecoder.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc_vdpau.c_vdp_output_surface_destroy.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vout_subpictures.c_spu_area_overlap.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/substx3g.c_SegmentDoSplit.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xmppdisco.c_got_items_cb.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/status.c_purple_presence_new_for_account.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/unicode.c_ToCharset.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc.c_vlclua_scripts_batch_execute.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ticker.c_buddy_signon_cb.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/winpidgin.c_dll_prep.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/theme-manager.c_purple_theme_manager_get_type.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/text_style.c_text_style_Copy.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/winpidgin.c_handle_protocol.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_cmds.c_tcl_cmd_cmd.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stereo_widen.c_paramCallback.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_signals.c_tcl_signal_cleanup.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vda.c_Extract.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/strtoll.c_strtoll.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/strings.c_str_format_time.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlm.c_vlm_MediaDescriptionCheck.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/yuv_rgb.c_NV12_RGBA.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/text_renderer.c_GetStyleFromFontStack.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/zephyr.c_zephyr_get_signature.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/subpicture.c_subpicture_New.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vobsub.c_Demux.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/status.c_purple_status_attr_get_name.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/timestamp.c_set_timestamp.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xmppdisco.c_disco_type_from_string.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xmlnode.c_xmlnode_to_formatted_str.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-nss.c_x509_copy_certificate.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/win32dep.c_wpurple_install_dir.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/transport.c_jingle_transport_set_property.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/value.c_purple_value_get_boxed.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc_vdpau.c_vdp_presentation_queue_target_create_x11.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-nss.c_x509_times.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vvconfig.c_threshold_value_format_cb.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/wspell.c_winpidgin_spell_init.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vaapi.c_Delete.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/wall.c_Close.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/zephyr.c_zephyr_inithosts.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/va.c_vlc_va_Stop.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/srtp.c_srtcp_recv.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_cmds.c_tcl_cmd_send_im.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlmshell.c_vlm_ScheduleDelete.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/status.c_purple_presence_new.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/video_widgets.c_OSDSlider.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/wmadeci.c_wma_decode_init.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc_vdpau.c_vdp_bitmap_surface_query_capabilities.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/win32text.c_RenderText.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tlv.c_aim_tlv_getstr.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vout_wrapper.c_vout_ManageWrapper.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/textdomain.c_vlc_gettext.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl-nss.c_ssl_auth_cert.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/stream_output.c_sout_stream_url_to_chain.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlm_event.c_vlm_SendEventMediaInstanceState.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_signals.c_new_cb_namespace.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/win32dep.c_wpurple_get_tz_offset.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/srtp.c_hexdigit.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc_vdpau.c_vdp_output_surface_get_bits_native.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/update_crypto.c_hash_finish.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlm.c_InputEventPreparse.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xdg.c_Inhibit.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vout_subpictures.c_UpdateSPU.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/value.c_purple_value_get_object.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tvbuff.c_gg_tvbuff_close.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/swscale.c_Init.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vobsub.c_TextUnload.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/telx.c_bytereverse.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/xmppconsole.c_plugin_unload.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl.c_tcl_load_plugin.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vpx.c_Open.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vlc_vdpau.c_vdp_video_mixer_query_parameter_support.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/themeedit-icon.c_change_stock_image.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/wmadeci.c_wma_decode_frame.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl.c_tcl_load.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tcl_cmds.c_tcl_validate_conversation.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/swab.c_swab.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/video_output.c_ThreadReset.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/themeedit.c_init_plugin.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/udev.c_Close.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/ssl.c_plugin_load.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/vnc.c_DemuxThread.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/tlv.c_createtlv.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/whiteboard.c_purple_whiteboard_draw_list_destroy.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/update_crypto.c_read_mpi.c
# Preprocessed /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Non_vulnerable/winprefs.c_blist_create_cb.c
# Total Vulnerable files preprocessed: 2306
# Total Non-vulnerable files preprocessed: 2281

# %%
import os
import random
import shutil

# Set paths for source and destination directories
source_directory = dataset_directory + '/Vulnerable'  # Change this to the path of your dataset
train_directory = dataset_directory + '/Vulnerable/TRAIN'
test_directory = dataset_directory + '/Vulnerable/TEST'

# Check if source directory exists
if not os.path.exists(source_directory):
    print("Source directory does not exist:", source_directory)
else:
    # Create destination directories if they don't exist
    os.makedirs(train_directory, exist_ok=True)
    os.makedirs(test_directory, exist_ok=True)
    print("Destination directories created")

    # Get a list of all C files in the source directory
    c_files = [file for file in os.listdir(source_directory) if file.endswith('.c')]
    print(len(c_files))

    # Shuffle the list of C files
    random.shuffle(c_files)

    # Calculate the index to split the files
    split_index = int(0.7 * len(c_files))

    # Divide files into training and testing sets
    train_files = c_files[:split_index]
    test_files = c_files[split_index:]

    # Move training files to the train directory
    for file in train_files:
        print("ah")
        source_path = os.path.join(source_directory, file)
        destination_path = os.path.join(train_directory, file)
        shutil.move(source_path, destination_path)
        print("Moved", file, "to", train_directory)

    # # Move testing files to the test directory
    for file in test_files:
        source_path = os.path.join(source_directory, file)
        destination_path = os.path.join(test_directory, file)
        shutil.move(source_path, destination_path)
        print("Moved", file, "to", test_directory)

    print("Dataset divided into train and test sets.")
# Out:
# Destination directories created
# 2306
# ah
# Moved rodinia_heartwall_orig-AVI2Favilib.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_65b.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved vimxenial-src2Fnetbeans.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogtrusty-lib2Fe2p2Fuuid.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved _CVE-2010-1624.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved libav-libavformat2Frtpdec_amr.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_radiusclient-src2Fradius.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved cve-2007-5629-3.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogdebstretche-lib2Fe2p2Ffeature.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_67a.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved makedebianstretche4.1-arscan.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bashxenpatch-variables.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogdebstretche-lib2Fext2fs2Fdupfs.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved CVE-2011-3623-1.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved rrockru_b-utility2Fio2Flibuv2Fsrc2Finet.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsxenpatch-debugfs2Fdebugfs.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_11.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved iproute2xenpatch-ip2Fipntable.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bashsources-bracecomp.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_calloc_07.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved vimdebstretche-src2Fops.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved procps123-proc2Fdevname.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved procps123-proc2Freadproc.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_68a.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved binutils-ld2Flexsup.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved iproutexen-ip2Fipnetns.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogartful-misc2Flogsave.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved binutils-gas2Fapp.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogartful-lib2Fext2fs2Fgen_bitmap.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved procps123-proc2Falloc.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved readlinexenialubuntu7.0-histexpand.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved matejak_openscap-src2FOVAL2Foval_sysItem.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved key_bes-modules2Fhdf5_handler2Fgctp2Fsrc2Fazimfor.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved lifelines_lifelines-src2Ftools2Flldump.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved procps123-pgrep.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved matejak_openscap-src2FCVSS2Fcvss.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bzip2jessie-bzlib.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogdebstretche-lib2Fe2p2Fhashstr.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved makesources4.1-main.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsxenpatch-misc2Fe2image.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved iproutenewver-ip2Fipntable.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogdebstretche-lib2Fe2p2Fuuid.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsources-lib2Fext2fs2Fdupfs.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_13.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_gsoap-gsoap2Fsrc2Fsoapcpp2.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ffmpeg-3.1.3-libavformat2Fsrtdec.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved cve-2004-0597-3.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved patchsource-lib2Flocalcharset.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved flexsources2.6.1-src2Fgen.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved binutils-ld2Ftestplug3.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_32.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved cve-2007-2445.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsxenpatch-lib2Fe2p2Fmntopts.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Mo
c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved iproute2xenpatch-misc2Farpd.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved cve-2006-5793.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsources-e2fsck2Fpass3.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved minimap2-1-index.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved findutilsxenial-test2Fdemo_forms.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_gsoap-gsoap2Fsrc2Fsoapcpp2_lex.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bluca_dpdk-app2Ftest-crypto-perf2Fcperf_test_vector_parsing.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved imgRead_libfuzzer.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved iproutexen-ip2Ftunnel.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_openldap-serveradm-libraries2Flibldap_r2Furl.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ffmpeg-3.1.3-ffserver.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved gawkxenpatch-src2Ftag.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved CVE-2010-3124.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved sysvinitdebstretche-src2Fsulogin.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved iproutenewver-ip2Fipnetns.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogartful-lib2Fext2fs2Fundo_io.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ppp1-tload.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE193_char_alloca_cpy_51b.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogtrusty-e2fsck2Fdirinfo.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bashxenial-assoc.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved makepatchxen-arscan.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsxenpatch-debugfs2Futil.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogtrusty-lib2Fext2fs2Ftest_io.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved lessdebian-optfunc.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved CVE-2016-3941.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved procps123-sysctl.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved binutils-libiberty2Fsimple-object-coff.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bcxenial-bc2Futil.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved CVE-2008-0984 .c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ncursesdebstretch-progs2Fdump_entry.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved test_openssl-crypto2Fts2Fts_rsp_verify.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved gawkxenpatch-src2Fmessage.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_malloc_52a.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved cve-2004-0599-2.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_52c.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bluca_dpdk-drivers2Fbus2Ffslmc2Ffslmc_bus.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved C_Prueba_04_CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory-CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory__w32_char_11.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_31.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved cve-2004-0597-1.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsxenpatch-lib2Fe2p2Ffeature.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved rdesktop-integration-integration-scard.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_radiusclient-lib2Fenv.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_openldap-serveradm-servers2Fslapd2Fsaslauthz.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved findutilsxenial-test2Fblue.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bashsources-lib2Fsh2Fstringlist.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ncursesxenpatch-test2Fdemo_panels.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved bind-9.11.0-lib2Fdns2Frdata2Fgeneric2Ftlsa_52.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved Format.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved MiBench-consumer-typeset-z33.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved CVE-2010-3907-2.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogsxenpatch-lib2Fext2fs2Ftest_io.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogartful-lib2Fuuid2Fgen_uuid.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved vimxenial-src2Ftag.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved test_openssl-test2Fhmactest.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ssocopsacc_openldap-serveradm-servers2Fslapd2Fback-monitor2Finit.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved libtiff-4.0.6-contrib2Fiptcutil2Fiptcutil.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__malloc_realloc_char_09.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_04.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved e2fsprogdebstretche-e2fsck2Fpass1.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved gawkxenpatch-src2Fversion.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved vimactualxenialpreviousversion-src2Fmbyte.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved vimartful-src2Fxxd2Fxxd.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# Moved ppp1-proc2Fwhattime.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TRAIN
# ah
# ...
# Moved e2fsprogsources-misc2Fbase_device.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ssocopsacc_piranha-lvsd.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsxenpatch-misc2Fbadblocks.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved test_openssl-ssl2Fstatem2Fstatem_lib.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved kbdartful-src2Fksyms.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved lessxenial-line.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogartful-lib2Fext2fs2Ftest_io.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashdebstretche-lib2Freadline2Fsavestring.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimactualxenialpreviousversion-src2Fmark.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet-cpp-CWE401_Memory_Leak__malloc_realloc_char_15.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gzipsources1.6-lib2Fvasnprintf.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ffg-raycast.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved binutils-binutils2Fsize.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bind-9.11.0-lib2Fisc2Funix2Fsocket.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved _CVE-2012-1178.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogartful-lib2Fext2fs2Fget_pathname.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved readlinexenialubuntu7.0-history.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved makepatchxen-function.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved findutilsxenial-ncurses2Fbase2Flib_screen.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimxenial-src2Fsyntax.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved binutils-binutils2Fobjdump.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimactualxenialpreviousversion-src2Fversion.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gawkxenpatch-src2Fif_xcmdsrv.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved readlinexenialubuntu7.0-text.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimxenial-src2Fspell.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved mprf4debstretche-src2Fget_str.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved findutilsxenial-test2Fcardfile.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved patchtrusty-lib2Fparse-datetime.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bluca_dpdk-app2Ftest2Ftest_event_eth_rx_adapter.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsources-misc2Fmke2fs.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashxenial-lib2Fsh2Fstringlist.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved Pixhawk-build2Fnuttx_px4fmu-v5_default2FNuttX2Fnuttx2Farch2Farm2Fsrc2Fchip2Fstm32_bbsram.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved kbdxenial-src2Fopenvt.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bind-9.11.0-lib2Fdns2Frdata2Fgeneric2Floc_29.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved jonbriem_vim-src2Fuserfunc.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ppp1-sysctl.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gmpxenpatch-gen-psqr.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved iproutenewver-lib2Fnames.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved lesstrusty-line.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashxenpatch-lib2Freadline2Fisearch.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved sysvinitdebstretche-src2Fdowall.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved _CVE-2011-3594.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimdebstretche-src2Fsearch.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashxenial-lib2Freadline2Ftilde.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet-cpp-CWE401_Memory_Leak__char_malloc_53a.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved aasysvinitxen-src2Fwall.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ssocopsacc_openldap-serveradm-servers2Fslapd2Fslapcommon.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogartful-lib2Fe2p2Fuuid.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsources-lib2Fe2p2Fls.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_21.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved sysvinittrusty-src2Fdowall.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogartful-e2fsck2Futil.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved oldversionprocps-proc2Fwhattime.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved minime-CWE426_Untrusted_Search_Path__char_popen_01.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bind-9.11.0-lib2Fdns2Frdata2Fgeneric2Frrsig_46.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved PavanNikhilesh_dpdk-drivers2Fnet2Fqede2Fqede_filter.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gitlab_gimp_master-gimp2Fapp2Fwidgets2Fgimpfileprocview.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet-cpp-CWE401_Memory_Leak__char_calloc_11.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved procpss-proc2Fpwcache.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved openssl1-test2Fmd5test.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved spring-AI2FSkirmish2FShard2Flib2Flua2Flobject.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimartful-src2Fmessage.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved sysvinitsources-src2Flast.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsources-misc2Fdumpe2fs.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsxenpatch-e2fsck2Funix.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bind-9.11.0-lib2Fdns2Frdata2Fgeneric2Fl64_106.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved C_Prueba_04_CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory-CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory__w32_char_10.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved test_openssl-test2Ftestutil2Fdriver.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashdebstretche-redir.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogtrusty-debugfs2Fdebugfs.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved tizenrt-webeng-3-net2Flwip2Fsrc2Fapi2Fsockets.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashdebstretche-bashhist.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved MiBench-consumer-typeset-z03.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashdebstretche-execute_cmd.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ssocopsacc_openldap-libraries2Flibldap_r2Furl.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved oldversionprocps-ps2Foutput.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gzipdebian-lib2Fvasnprintf.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogdebstretche-misc2Flsattr.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimactualxenialpreviousversion-src2Fex_eval.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashxenial-lib2Freadline2Fparse-colors.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ssocopsacc_openldap-serveradm-servers2Fslapd2Fback-mdb2Fidl.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved readlinexenialubuntu7.0-tilde.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved coreutilssources8.26-lib2Fbackupfile.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved binutils-bfd2Fsrec.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved preliminaryorbitdetermination-rv2coe.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet-cpp-CWE401_Memory_Leak__malloc_realloc_char_01.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet_testsuite_CWE121_S01-CWE121_Stack_Based_Buffer_Overflow__CWE135_42.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved binutils-ld2Fldlang.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogtrusty-lib2Fext2fs2Ffinddev.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved iproutexen-ip2Fip6tunnel.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved costalfy_darktable-src2Fimageio2Fstorage2Fgallery.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved C_Prueba_04_CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory-CWE591_Sensitive_Data_Storage_in_Improperly_Locked_Memory__w32_char_53a.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved sysvinitdebstretche-src2Fwall.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gitlab_gimp_master-gimp2Fplug-ins2Fcommon2Fplugin-browser.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ssocopsacc_openldap-serveradm-servers2Fslapd2Fsasl.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved blu-corner_sbf-src2Fcommon2FsbfLog.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogartful-lib2Fext2fs2Fmkjournal.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gdbmdebstretche-gdbmopen.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved kbdsource-src2Fsetfont.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bzip2patchxen-bzip2recover.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimactualxenialpreviousversion-src2Fgetchar.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved iproutenewver-tc2Fem_meta.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved libxslt-1.1.28-libxslt2Ffunctions.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved openscap-src2FOVAL2Foval_enumerations.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved iprouteold-misc2Fss.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogtrusty-lib2Fe2p2Ffeature.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogdebstretche-misc2Fe2image.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved Strcpy.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bashdebstretche-print_cmd.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved binutils-bfd2Felflink.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved android-kernel-htc-msm8974-travis-drivers2Fisdn2Fhardware2Feicon2Fdebug.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved bind-9.11.0-lib2Fdns2Fdst_api.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimxenial-src2Fgetchar.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved findutilsxenial-test2Ftclock.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsources-debugfs2Futil.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogsxenpatch-lib2Fext2fs2Finitialize.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved kbdxenial-src2Floadkeys.analyze.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved lessxenial-cmdbuf.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved cve-2015-0973.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved binutils-libiberty2Fcp-demangle.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved gitlab_gimp_master-gimp2Fplug-ins2Fcommon2Fcompose.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogtrusty-debugfs2Fls.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved openscap-src2FOVAL2Foval_state.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved oldversionprocps-w.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved diffutilssources-lib2Flocalcharset.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved CVE-2016-5108.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved CVE-2010-1443.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ssocopsacc_openldap-serveradm-libraries2Fliblutil2Fmeter.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved vimxenial-src2Fex_cmds2.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogtrusty-debugfs2Fdump.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved kek-123-libschily2Ffconv.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved flexnewver-src2Fgen.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved iproutexen-ip2Fiptuntap.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved juliet-cpp-CWE401_Memory_Leak__char_realloc_12.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved ncursessources6.0-progs2Fdump_entry.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved s4paneum_wrk-obj2Fopenssl-1.1.0g2Ftest2Frmdtest.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Moved e2fsprogtrusty-lib2Fext2fs2Fgen_bitmap64.c to /home/shaurya/BTP/1/Dataset/Raw/dataset 1/Dataset_raw/Vulnerable/TEST
# Dataset divided into train and test sets.
